# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from math import sqrt
from pypfopt.expected_returns import mean_historical_return
from pypfopt.risk_models import CovarianceShrinkage
from pypfopt.efficient_frontier import EfficientFrontier
from pypfopt.discrete_allocation import get_latest_prices
from dateutil.relativedelta import relativedelta
import copy
import warnings
warnings.filterwarnings('ignore')

tickers = ['AAPL', 'GOOG', 'MSFT', 'AMZN', 'INTC', 'AMD', 'NVDA', 'F', 'TSLA', 'JPM', 'MS', 'VOO']
data_for_portfolio_5y = yf.download(tickers, start='2016-01-01', end='2021-01-01')['Close'].dropna()
data_for_portfolio_5y.tail()
# Out:
# [*********************100%***********************]  12 of 12 completed
#                   AAPL        AMD        AMZN     F       GOOG       INTC  \
# Date
# 2020-12-24  131.970001  91.809998  158.634506  8.86  86.942497  47.070000
# 2020-12-28  136.690002  91.599998  164.197998  8.89  88.804497  47.070000
# 2020-12-29  134.869995  90.620003  166.100006  8.82  87.935997  49.389999
# 2020-12-30  133.720001  92.290001  164.292496  8.86  86.975998  48.750000
# 2020-12-31  132.690002  91.709999  162.846497  8.79  87.594002  49.820000
#
#                    JPM         MS        MSFT        NVDA        TSLA  \
# Date
# 2020-12-24  124.519997  68.089996  222.750000  129.937500  220.589996
# 2020-12-28  125.339996  68.050003  224.960007  129.000000  221.229996
# 2020-12-29  125.010002  67.709999  224.149994  129.432495  221.996674
# 2020-12-30  125.360001  67.839996  221.679993  131.457504  231.593338
# 2020-12-31  127.070000  68.529999  222.419998  130.550003  235.223328
#
#                    VOO
# Date
# 2020-12-24  339.160004
# 2020-12-28  342.109985
# 2020-12-29  341.390015
# 2020-12-30  341.850006
# 2020-12-31  343.690002

# %%
# Create initial portfolio
mu = mean_historical_return(data_for_portfolio_5y)
S = CovarianceShrinkage(data_for_portfolio_5y).ledoit_wolf()
ef = EfficientFrontier(mu, S, weight_bounds=(0,1))
weights = ef.max_sharpe()
initial_weights = ef.clean_weights()
print(initial_weights, '\n')

# Initial buy stocks
balance_usd = 100_000
balance_remain = balance_usd
stocks_initial = {}
latest_prices_data_dec_2020 = get_latest_prices(data_for_portfolio_5y)
for ticker in initial_weights:
    to_spend_usd = balance_usd * initial_weights[ticker]
    one_stock_price = latest_prices_data_dec_2020[ticker]
    stocks_number = to_spend_usd // one_stock_price
    stocks_initial[ticker] = stocks_number
    balance_remain = balance_remain - (stocks_number * one_stock_price)
print('Portfolio:', stocks_initial)
print('Remaining balance: USD', balance_remain)
# Out:
# OrderedDict([('AAPL', 0.1135), ('AMD', 0.27372), ('AMZN', 0.11721), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.0), ('NVDA', 0.28702), ('TSLA', 0.20854), ('VOO', 0.0)])
#
# Portfolio: {'AAPL': 85.0, 'AMD': 298.0, 'AMZN': 71.0, 'F': 0.0, 'GOOG': 0.0, 'INTC': 0.0, 'JPM': 0.0, 'MS': 0.0, 'MSFT': 0.0, 'NVDA': 219.0, 'TSLA': 88.0, 'VOO': 0.0}
# Remaining balance: USD 539.5653076171875

# %%
# Calculate MACD, RSI, and S&R signals.
data_2021 = yf.download(tickers, start='2020-12-12', end='2022-01-01')['Close'].dropna()

short_ma = 5                                       # 5 минулих днів для "короткого" МА 
long_ma = 12                                       # 12 минулих днів для "довгого" МА 
rsi_period = 14                                    # RSI рахується за 14 минулих днів 
rsi_oversold = 30                                  # Параметри для індикатора RSI 
rsi_overbought = 70 
sr_sell = 0.7                                      # Параметри для індикатора S&R
sr_buy = 0.3 
start = max(long_ma, rsi_period)

for ticker in data_2021.columns:
    data_2021['MA_' + ticker + str(short_ma)] = data_2021[ticker].rolling(short_ma).mean()
    data_2021['MA_' + ticker + str(long_ma)] = data_2021[ticker].rolling(long_ma).mean() 
    data_2021['return_' + ticker] = data_2021[ticker].pct_change() 
    data_2021['Up_' + ticker] = np.maximum(data_2021[ticker].diff(),0) 
    data_2021['Down_' + ticker] = np.maximum(-data_2021[ticker].diff(),0) 
    data_2021['RS_' + ticker] = data_2021['Up_' + ticker].rolling(rsi_period).mean()/data_2021['Down_' + ticker].rolling(rsi_period).mean() 
    data_2021['RSI_' + ticker] = 100 - 100/(1 + data_2021['RS_' + ticker]) 
    data_2021['S&R_' + ticker] = (data_2021[ticker]/(10**np.floor(np.log10(data_2021[ticker]))))%1 
    data_2021['MACD_signal_' + ticker] = 2*(data_2021['MA_' + ticker + str(short_ma)] > data_2021['MA_' + ticker + str(long_ma)]) -1 
    data_2021['RSI_signal_' + ticker] = 1*(data_2021['RSI_' + ticker] < rsi_oversold) -1*(data_2021['RSI_' + ticker] > rsi_overbought) 
    data_2021['S&R_signal_' + ticker] = 1*(data_2021['S&R_' + ticker] < sr_buy) -1*(data_2021['S&R_' + ticker] > sr_sell) 

data = data_2021.drop(data_2021.index[range(14)])
#print(data.to_string())
data.head(3)
# Out:
# [*********************100%***********************]  12 of 12 completed
#                   AAPL        AMD        AMZN     F       GOOG       INTC  \
# Date
# 2021-01-04  129.410004  92.300003  159.331497  8.52  86.412003  49.669998
# 2021-01-05  131.009995  92.769997  160.925507  8.65  87.045998  50.610001
# 2021-01-06  126.599998  90.330002  156.919006  8.84  86.764503  51.099998
#
#                    JPM         MS        MSFT        NVDA  ...    MA_VOO12  \
# Date                                                       ...
# 2021-01-04  125.870003  68.330002  217.690002  131.134995  ...  340.415003
# 2021-01-05  125.650002  69.489998  217.899994  134.047501  ...  340.506671
# 2021-01-06  131.550003  73.680000  212.250000  126.144997  ...  340.616669
#
#             return_VOO    Up_VOO  Down_VOO    RS_VOO    RSI_VOO  S&R_VOO  \
# Date
# 2021-01-04   -0.013559  0.000000  4.660004  1.217737  54.908985   0.3903
# 2021-01-05    0.006578  2.230011  0.000000  1.634519  62.042412   0.4126
# 2021-01-06    0.006066  2.069977  0.000000  1.374617  57.887952   0.4333
#
#             MACD_signal_VOO  RSI_signal_VOO  S&R_signal_VOO
# Date
# 2021-01-04                1               0               0
# 2021-01-05                1               0               0
# 2021-01-06                1               0               0
#
# [3 rows x 144 columns]

# %%
data.tail(3)
# Out:
#                   AAPL         AMD        AMZN          F        GOOG  \
# Date
# 2021-12-29  179.380005  148.259995  169.201004  20.559999  146.504501
# 2021-12-30  178.199997  145.149994  168.644501  20.469999  146.002502
# 2021-12-31  177.570007  143.899994  166.716995  20.770000  144.679504
#
#                  INTC         JPM         MS        MSFT        NVDA  ...  \
# Date                                                                  ...
# 2021-12-29  51.830002  158.559998  98.730003  341.950012  300.010010  ...
# 2021-12-30  51.740002  158.479996  98.800003  339.320007  295.859985  ...
# 2021-12-31  51.500000  158.350006  98.160004  336.320007  294.109985  ...
#
#               MA_VOO12  return_VOO    Up_VOO  Down_VOO    RS_VOO    RSI_VOO  \
# Date
# 2021-12-29  430.458336    0.001209  0.529999  0.000000  1.318102  56.861268
# 2021-12-30  431.188334   -0.002825  0.000000  1.240021  1.423401  58.735673
# 2021-12-31  432.061668   -0.002741  0.000000  1.199982  1.165480  53.820870
#
#             S&R_VOO  MACD_signal_VOO  RSI_signal_VOO  S&R_signal_VOO
# Date
# 2021-12-29   0.3901                1               0               0
# 2021-12-30   0.3777                1               0               0
# 2021-12-31   0.3657                1               0               0
#
# [3 rows x 144 columns]

# %%
def check_tickers_for_sell(tickers_sell, now, current_weights):
    ticker_percent_sell = {}
    end_date = now.strftime('%Y-%m-%d')
    start_date = (now - relativedelta(years=5)).strftime('%Y-%m-%d')
    # Get data for all tickers for last 5 years
    data_for_tickers = yf.download(tickers, start_date, end_date, progress=False)['Close'].dropna()
    
    # Generate portfolio on this data
    mu = mean_historical_return(data_for_tickers)
    S = CovarianceShrinkage(data_for_tickers).ledoit_wolf()
    ef = EfficientFrontier(mu, S, weight_bounds=(0,1))
    weights = ef.max_sharpe()
    new_weights = ef.clean_weights()
    
    for ticker in tickers_sell:
        if new_weights[ticker] == 0:
            ticker_percent_sell[ticker] = 100
        elif new_weights[ticker] < current_weights[ticker]:
            delta = current_weights[ticker] - new_weights[ticker]
            sell_percent = (delta * 100) // current_weights[ticker]
            ticker_percent_sell[ticker] = sell_percent
    return ticker_percent_sell

# %%
def select_ticker_for_sell(data, date, filtered_sell_tickers_with_percents, stocks_current):
    sell_ticker = ''
    sell_profit = 0
    stocks_to_sell = 0
    for ticker in filtered_sell_tickers_with_percents:
        no_of_stocks = stocks_current[ticker]
        #print(ticker, 'no_of_stocks', no_of_stocks)
        cur_price = data[ticker][date]
        #print(ticker, 'cur_price', cur_price)
        sell_percent = (filtered_sell_tickers_with_percents[ticker] / 100)
        #print(ticker, 'sell_percent', sell_percent)
        potentail_profit = no_of_stocks * cur_price * sell_percent
        #print(ticker, 'potentail_profit', potentail_profit)
        if potentail_profit > sell_profit:
            sell_profit = potentail_profit
            sell_ticker = ticker
            stocks_to_sell = no_of_stocks * sell_percent
    return [sell_ticker, sell_profit, stocks_to_sell]

# %%
def select_ticker_for_buy(tickers_buy, now):
    if len(tickers_buy) == 1:
        return tickers_buy[0]
    end_date = now.strftime('%Y-%m-%d')
    start_date = (now - relativedelta(years=5)).strftime('%Y-%m-%d')
    # Get data for all tickers for last 5 years period
    data_for_tickers_last_year = yf.download(tickers_buy, start_date, end_date, progress=False)['Close'].dropna()
    ticker_percent_delta = {}
    for t in tickers_buy:
        first_price = data_for_tickers_last_year[t][0]
        last_price = data_for_tickers_last_year[t][len(data_for_tickers_last_year[t]) - 1]
        delta = last_price - first_price
        delta_abs = abs(delta)
        percent = (delta_abs * 100) / first_price
        if delta > 0:
            ticker_percent_delta[t] = percent
        else:
            ticker_percent_delta[t] = -1 * percent
    sorted_by_delta = dict(sorted(ticker_percent_delta.items(), key=lambda x:x[1], reverse=True))
    return list(sorted_by_delta.keys())[0]

# %%
print('Start weights:', initial_weights)
clean_result = balance_remain
for stock in initial_weights:
    clean_result = clean_result + (stocks_initial[stock] * data[stock][len(data[stock]) - 1])
print('Without any changes balance on the end of 2021 would be', clean_result)
print('------------------------------------')
# Out:
# Start weights: OrderedDict([('AAPL', 0.1135), ('AMD', 0.27372), ('AMZN', 0.11721), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.0), ('NVDA', 0.28702), ('TSLA', 0.20854), ('VOO', 0.0)])
# Without any changes balance on the end of 2021 would be 165761.08842468262
# ------------------------------------

# %%
strategy = 'S&R_signal_'                  # MACD_signal_        or        RSI_signal_        or        S&R_signal_
strategy_weights = copy.deepcopy(initial_weights)
stocks_strategy = copy.deepcopy(stocks_initial)
balance_strategy = balance_remain

balance_buy_and_hold_dict = {}
balance_strategy_dict = {}

for d in data.index: 
    if d.weekday() == 4:                   # every Friday
        tickers_sell = []
        tickers_buy = []
        for t in strategy_weights:
            if data[strategy + t][d] == -1:
                tickers_sell.append(t)
            if data[strategy + t][d] == 1:
                tickers_buy.append(t)
        print(d, 'Sell candidates:', tickers_sell, 'Buy candidates:', tickers_buy)
        if len(tickers_sell) > 0 and len(tickers_buy) > 0:
            filtered_sell_tickers_with_percents = check_tickers_for_sell(tickers_sell, d, strategy_weights)
            print('Filtered sell candidates:', filtered_sell_tickers_with_percents)
            if len(filtered_sell_tickers_with_percents) > 0:
                ticker_for_sell_data = select_ticker_for_sell(data, d, filtered_sell_tickers_with_percents, stocks_strategy)
                will_receive_usd = ticker_for_sell_data[1]
                # If this ticker is present in current portfolio
                if will_receive_usd > 0:
                    ticker_for_sell = ticker_for_sell_data[0]
                    stocks_to_sell = ticker_for_sell_data[2]
                    sell_percents = filtered_sell_tickers_with_percents[ticker_for_sell]
                    ticker_for_buy = select_ticker_for_buy(tickers_buy, d)
                    # If we can buy other ticker on that money
                    if (will_receive_usd + balance_strategy) > data[ticker_for_buy][d]:
                        print('Will sell',ticker_for_sell,'and get',will_receive_usd,'$ after selling (',sell_percents,'% )')
                        print('Will buy', ticker_for_buy)
                        # Sell percent of ticker_for_sell and add that money to balance
                        stocks_strategy[ticker_for_sell] = stocks_strategy[ticker_for_sell] - stocks_to_sell
                        balance_strategy = balance_strategy + will_receive_usd
                        # Buy ticker_for_buy on all balance
                        no_of_buy_stocks = balance_strategy // data[ticker_for_buy][d]
                        stocks_strategy[ticker_for_buy] = stocks_strategy[ticker_for_buy] + no_of_buy_stocks
                        balance_strategy = balance_strategy - (data[ticker_for_buy][d] * no_of_buy_stocks)
                        # Recalculate new weights for all portfolio
                        # calculate all prices for now + balance - потом высчитать сколько в процентах сейчас каждый ФИ
                        cur_balance = balance_strategy
                        stock_usd = {}
                        for stock in stocks_strategy:
                            stock_usd[stock] = stocks_strategy[stock] * data[stock][d]
                            cur_balance = cur_balance + stock_usd[stock]
                        for stock in stocks_strategy:
                            strategy_weights[stock] = stock_usd[stock] / cur_balance
                        print('Current weights are', strategy_weights)
                        print('Current balance =', cur_balance)
                    else:
                        print("No changes because sell profit is not enough for buying at least one stock.")
                else:
                    print("No changes because all sell candidates are not present in current portfolio.")
            else:
                print("No changes because all sell candidates failed check.")
        else:
            print("No changes because no sell candidates or no buy candidates.")
        print('------------------------------------')
    # Calculate current balance for stocks_initial
    today_balance_buy_and_hold = balance_remain
    for stock in stocks_initial:
        today_balance_buy_and_hold = today_balance_buy_and_hold + (data[stock][d] * stocks_initial[stock])
    balance_buy_and_hold_dict[d] = today_balance_buy_and_hold
    # Calculate current balance for stocks_strategy
    today_balance_strategy = balance_strategy
    for stock in stocks_strategy:
        today_balance_strategy = today_balance_strategy + (data[stock][d] * stocks_strategy[stock])
    balance_strategy_dict[d] = today_balance_strategy

print('\nWith strategy final weights are:', strategy_weights)        
clean_result = balance_strategy
for stock in strategy_weights:
    clean_result = clean_result + (stocks_strategy[stock] * data[stock][len(data[stock]) - 1])
print('\nWith strategy balance on the end of 2021 would be', clean_result)
# Out:
# 2021-01-08 00:00:00 Sell candidates: ['TSLA'] Buy candidates: ['F', 'GOOG', 'INTC', 'MSFT']
# Filtered sell candidates: {}
# No changes because all sell candidates failed check.
# ------------------------------------
# 2021-01-15 00:00:00 Sell candidates: ['AMD', 'F', 'INTC', 'TSLA'] Buy candidates: ['AAPL', 'MSFT', 'NVDA']
# Filtered sell candidates: {'F': 100, 'INTC': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2021-01-22 00:00:00 Sell candidates: ['TSLA'] Buy candidates: ['AMD', 'F', 'MSFT']
# Filtered sell candidates: {}
# No changes because all sell candidates failed check.
# ------------------------------------
# 2021-01-29 00:00:00 Sell candidates: ['MS'] Buy candidates: ['F', 'GOOG', 'JPM', 'NVDA']
# Filtered sell candidates: {'MS': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2021-02-05 00:00:00 Sell candidates: ['AMD', 'INTC', 'TSLA'] Buy candidates: ['F', 'GOOG']
# Filtered sell candidates: {'AMD': 0.0, 'INTC': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2021-02-12 00:00:00 Sell candidates: ['TSLA'] Buy candidates: ['F', 'GOOG', 'INTC']
# Filtered sell candidates: {}
# No changes because all sell candidates failed check.
# ------------------------------------
# 2021-02-19 00:00:00 Sell candidates: ['AMD'] Buy candidates: ['AAPL', 'F', 'GOOG']
# Filtered sell candidates: {}
# No changes because all sell candidates failed check.
# ------------------------------------
# 2021-02-26 00:00:00 Sell candidates: [] Buy candidates: ['AAPL', 'F', 'GOOG', 'INTC', 'TSLA']
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2021-03-05 00:00:00 Sell candidates: ['AMD', 'TSLA'] Buy candidates: ['AAPL', 'F', 'GOOG', 'INTC', 'MS', 'NVDA']
# Filtered sell candidates: {}
# No changes because all sell candidates failed check.
# ------------------------------------
# 2021-03-12 00:00:00 Sell candidates: [] Buy candidates: ['AAPL', 'AMD', 'GOOG', 'INTC', 'NVDA']
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2021-03-19 00:00:00 Sell candidates: ['AMD'] Buy candidates: ['AAPL', 'F', 'GOOG', 'MS', 'NVDA', 'TSLA']
# Filtered sell candidates: {'AMD': 10.0}
# Will sell AMD and get 2355.987927246094 $ after selling ( 10.0 % )
# Will buy NVDA
# Current weights are OrderedDict([('AAPL', 0.11019387238593455), ('AMD', 0.22909153591997117), ('AMZN', 0.11794004813283751), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.0), ('NVDA', 0.33447987826859915), ('TSLA', 0.2075439000363771), ('VOO', 0.0)])
# Current balance = 92556.4153213501
# ------------------------------------
# 2021-03-26 00:00:00 Sell candidates: ['AMD', 'MS'] Buy candidates: ['AAPL', 'F', 'GOOG', 'NVDA', 'TSLA']
# Filtered sell candidates: {'MS': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2021-04-09 00:00:00 Sell candidates: ['INTC', 'VOO'] Buy candidates: ['AMD', 'F', 'GOOG', 'MS', 'TSLA']
# Filtered sell candidates: {'INTC': 100, 'VOO': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2021-04-16 00:00:00 Sell candidates: ['MS', 'VOO'] Buy candidates: ['AMD', 'F', 'GOOG']
# Filtered sell candidates: {'MS': 100, 'VOO': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2021-04-23 00:00:00 Sell candidates: ['INTC', 'VOO'] Buy candidates: ['AMD', 'F', 'GOOG', 'MS']
# Filtered sell candidates: {'INTC': 100, 'VOO': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2021-04-30 00:00:00 Sell candidates: ['AMZN', 'INTC', 'VOO'] Buy candidates: ['AMD', 'F', 'GOOG', 'MS']
# Filtered sell candidates: {'INTC': 100, 'VOO': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2021-05-07 00:00:00 Sell candidates: ['AMD', 'INTC', 'MS', 'VOO'] Buy candidates: ['F', 'GOOG', 'TSLA']
# Filtered sell candidates: {'AMD': 8.0, 'INTC': 100, 'MS': 100, 'VOO': 100}
# Will sell AMD and get 1690.9473076171873 $ after selling ( 8.0 % )
# Will buy TSLA
# Current weights are OrderedDict([('AAPL', 0.11136924954671468), ('AMD', 0.19567255736805447), ('AMZN', 0.11758143238260552), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.0), ('NVDA', 0.35920309915521836), ('TSLA', 0.21424598463614927), ('VOO', 0.0)])
# Current balance = 99379.77148742675
# ------------------------------------
# 2021-05-14 00:00:00 Sell candidates: ['MS', 'TSLA', 'VOO'] Buy candidates: ['AAPL', 'F', 'GOOG']
# Filtered sell candidates: {'MS': 100, 'TSLA': 15.0, 'VOO': 100}
# Will sell TSLA and get 2801.2650260925293 $ after selling ( 15.0 % )
# Will buy AAPL
# Current weights are OrderedDict([('AAPL', 0.1466323928103487), ('AMD', 0.19606204285691622), ('AMZN', 0.12188254997242871), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.0), ('NVDA', 0.3656662106647733), ('TSLA', 0.1691017891214868), ('VOO', 0.0)])
# Current balance = 93871.47960009766
# ------------------------------------
# 2021-05-21 00:00:00 Sell candidates: ['AMD', 'MS', 'TSLA', 'VOO'] Buy candidates: ['AAPL', 'GOOG']
# Filtered sell candidates: {'MS': 100, 'VOO': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2021-05-28 00:00:00 Sell candidates: ['INTC', 'VOO'] Buy candidates: ['AAPL', 'AMD', 'GOOG', 'MS', 'TSLA']
# Filtered sell candidates: {'INTC': 100, 'VOO': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2021-06-04 00:00:00 Sell candidates: ['INTC', 'NVDA', 'TSLA', 'VOO'] Buy candidates: ['AAPL', 'AMD', 'GOOG']
# Filtered sell candidates: {'INTC': 100, 'NVDA': 24.0, 'VOO': 100}
# Will sell NVDA and get 10167.259870605469 $ after selling ( 24.0 % )
# Will buy AMD
# Current weights are OrderedDict([('AAPL', 0.131164416339807), ('AMD', 0.29256927973258695), ('AMZN', 0.10980515481872596), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.0), ('NVDA', 0.31060419627321906), ('TSLA', 0.1555555085926393), ('VOO', 0.0)])
# Current balance = 103657.0764654541
# ------------------------------------
# 2021-06-11 00:00:00 Sell candidates: ['INTC', 'NVDA', 'VOO'] Buy candidates: ['AAPL', 'AMD', 'GOOG', 'MS', 'TSLA']
# Filtered sell candidates: {'INTC': 100, 'NVDA': 12.0, 'VOO': 100}
# Will sell NVDA and get 3917.8474016601563 $ after selling ( 12.0 % )
# Will buy AMD
# Current weights are OrderedDict([('AAPL', 0.13104132192359888), ('AMD', 0.3251726503922357), ('AMZN', 0.11320030325086973), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.0), ('NVDA', 0.2737376335441445), ('TSLA', 0.15640777699047098), ('VOO', 0.0)])
# Current balance = 104957.73114395142
# ------------------------------------
# 2021-06-18 00:00:00 Sell candidates: ['AMZN', 'NVDA', 'VOO'] Buy candidates: ['GOOG', 'TSLA']
# Filtered sell candidates: {'AMZN': 11.0, 'VOO': 100}
# Will sell AMZN and get 1361.6344595336914 $ after selling ( 11.0 % )
# Will buy TSLA
# Current weights are OrderedDict([('AAPL', 0.1294231426577583), ('AMD', 0.32637903670464474), ('AMZN', 0.10119723451551882), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.0), ('NVDA', 0.2759566551511588), ('TSLA', 0.16556293675812997), ('VOO', 0.0)])
# Current balance = 108865.23411315918
# ------------------------------------
# 2021-06-25 00:00:00 Sell candidates: ['AMZN', 'MS', 'NVDA', 'VOO'] Buy candidates: ['GOOG', 'TSLA']
# Filtered sell candidates: {'AMZN': 50.0, 'MS': 100, 'VOO': 100}
# Will sell AMZN and get 5373.456373291016 $ after selling ( 50.0 % )
# Will buy TSLA
# Current weights are OrderedDict([('AAPL', 0.129134264642602), ('AMD', 0.3228247230819031), ('AMZN', 0.048268164047856485), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.0), ('NVDA', 0.2755382929993509), ('TSLA', 0.22279979120800866), ('VOO', 0.0)])
# Current balance = 111325.06237368775
# ------------------------------------
# 2021-07-02 00:00:00 Sell candidates: ['AMZN', 'MSFT', 'VOO'] Buy candidates: ['GOOG', 'MS', 'NVDA', 'TSLA']
# Filtered sell candidates: {'AMZN': 100, 'VOO': 100}
# Will sell AMZN and get 5546.47052772522 $ after selling ( 100 % )
# Will buy NVDA
# Current weights are OrderedDict([('AAPL', 0.12739135503513435), ('AMD', 0.33500146701818345), ('AMZN', 0.0), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.0), ('NVDA', 0.3249121220260596), ('TSLA', 0.21122267661936991), ('VOO', 0.0)])
# Current balance = 118655.46701288148
# ------------------------------------
# 2021-07-09 00:00:00 Sell candidates: ['AMZN', 'MSFT'] Buy candidates: ['AMD', 'GOOG', 'MS', 'NVDA', 'TSLA', 'VOO']
# Filtered sell candidates: {}
# No changes because all sell candidates failed check.
# ------------------------------------
# 2021-07-16 00:00:00 Sell candidates: ['AMZN', 'MSFT', 'NVDA', 'VOO'] Buy candidates: ['MS', 'TSLA']
# Filtered sell candidates: {'NVDA': 39.0, 'VOO': 100}
# Will sell NVDA and get 13328.450929114015 $ after selling ( 39.0 % )
# Will buy TSLA
# Current weights are OrderedDict([('AAPL', 0.14373540802857004), ('AMD', 0.3277598092720642), ('AMZN', 0.0), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.0), ('NVDA', 0.18952805557943256), ('TSLA', 0.33725594784970747), ('VOO', 0.0)])
# Current balance = 109994.60850272523
# ------------------------------------
# 2021-07-23 00:00:00 Sell candidates: ['AMZN', 'MSFT', 'NVDA'] Buy candidates: ['AMD', 'INTC', 'TSLA', 'VOO']
# Filtered sell candidates: {}
# No changes because all sell candidates failed check.
# ------------------------------------
# 2021-07-30 00:00:00 Sell candidates: ['MSFT', 'NVDA'] Buy candidates: ['AMD', 'TSLA', 'VOO']
# Filtered sell candidates: {}
# No changes because all sell candidates failed check.
# ------------------------------------
# 2021-08-06 00:00:00 Sell candidates: ['MS', 'MSFT'] Buy candidates: ['AMD', 'NVDA', 'VOO']
# Filtered sell candidates: {'MS': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2021-08-13 00:00:00 Sell candidates: ['MSFT'] Buy candidates: ['AMD', 'MS', 'NVDA', 'VOO']
# Filtered sell candidates: {}
# No changes because all sell candidates failed check.
# ------------------------------------
# 2021-08-20 00:00:00 Sell candidates: [] Buy candidates: ['AMD', 'F', 'INTC', 'MS', 'MSFT', 'NVDA', 'TSLA', 'VOO']
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2021-08-27 00:00:00 Sell candidates: ['MSFT'] Buy candidates: ['AMD', 'MS', 'NVDA', 'VOO']
# Filtered sell candidates: {}
# No changes because all sell candidates failed check.
# ------------------------------------
# 2021-09-03 00:00:00 Sell candidates: ['AMZN'] Buy candidates: ['AMD', 'F', 'MS', 'MSFT', 'NVDA', 'VOO']
# Filtered sell candidates: {'AMZN': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2021-09-10 00:00:00 Sell candidates: ['AMZN', 'MSFT'] Buy candidates: ['AMD', 'F', 'MS', 'NVDA', 'VOO']
# Filtered sell candidates: {'AMZN': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2021-09-17 00:00:00 Sell candidates: ['AMZN', 'MSFT'] Buy candidates: ['AMD', 'MS', 'NVDA', 'VOO']
# Filtered sell candidates: {'AMZN': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2021-09-24 00:00:00 Sell candidates: ['AMZN', 'MSFT'] Buy candidates: ['AMD', 'MS', 'NVDA', 'VOO']
# Filtered sell candidates: {'AMZN': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2021-10-01 00:00:00 Sell candidates: ['MS', 'MSFT', 'VOO'] Buy candidates: ['AMD', 'NVDA']
# Filtered sell candidates: {'MS': 100, 'VOO': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2021-10-08 00:00:00 Sell candidates: ['JPM', 'MSFT'] Buy candidates: ['AMD', 'MS', 'NVDA', 'VOO']
# Filtered sell candidates: {'JPM': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2021-10-15 00:00:00 Sell candidates: ['AMZN', 'TSLA'] Buy candidates: ['AMD', 'MS', 'MSFT', 'NVDA', 'VOO']
# Filtered sell candidates: {'AMZN': 100, 'TSLA': 15.0}
# Will sell TSLA and get 7281.671878051758 $ after selling ( 15.0 % )
# Will buy AMD
# Current weights are OrderedDict([('AAPL', 0.11457045475046376), ('AMD', 0.39888795355482654), ('AMZN', 0.0), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.0), ('NVDA', 0.18380418774066123), ('TSLA', 0.3022171794417824), ('VOO', 0.0)])
# Current balance = 136533.62586857384
# ------------------------------------
# 2021-10-22 00:00:00 Sell candidates: ['INTC', 'JPM'] Buy candidates: ['AMD', 'MS', 'MSFT', 'NVDA', 'TSLA', 'VOO']
# Filtered sell candidates: {'INTC': 100, 'JPM': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2021-10-29 00:00:00 Sell candidates: ['F', 'INTC', 'TSLA'] Buy candidates: ['AMD', 'MS', 'VOO']
# Filtered sell candidates: {'F': 100, 'INTC': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2021-11-05 00:00:00 Sell candidates: ['AMZN', 'F', 'MS', 'NVDA'] Buy candidates: ['INTC', 'TSLA']
# Filtered sell candidates: {'AMZN': 100, 'F': 100, 'MS': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2021-11-12 00:00:00 Sell candidates: ['AMZN', 'F', 'MS'] Buy candidates: ['INTC', 'NVDA', 'VOO']
# Filtered sell candidates: {'AMZN': 100, 'F': 100, 'MS': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2021-11-19 00:00:00 Sell candidates: ['AMZN', 'F', 'INTC', 'TSLA'] Buy candidates: ['NVDA']
# Filtered sell candidates: {'AMZN': 100, 'F': 100, 'INTC': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2021-11-26 00:00:00 Sell candidates: ['AMZN', 'F', 'INTC', 'MS'] Buy candidates: ['MSFT', 'NVDA', 'VOO']
# Filtered sell candidates: {'AMZN': 100, 'F': 100, 'INTC': 100, 'MS': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2021-12-03 00:00:00 Sell candidates: ['F', 'INTC', 'MS'] Buy candidates: ['MSFT', 'NVDA', 'VOO']
# Filtered sell candidates: {'F': 100, 'INTC': 100, 'MS': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2021-12-10 00:00:00 Sell candidates: ['AAPL', 'AMZN', 'MS'] Buy candidates: ['F', 'INTC', 'NVDA']
# Filtered sell candidates: {'AMZN': 100, 'MS': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2021-12-17 00:00:00 Sell candidates: ['AAPL', 'AMZN', 'F', 'MS', 'NVDA'] Buy candidates: ['INTC', 'MSFT', 'TSLA', 'VOO']
# Filtered sell candidates: {'AMZN': 100, 'F': 100, 'MS': 100, 'NVDA': 50.0}
# Will sell NVDA and get 15956.424543939454 $ after selling ( 50.0 % )
# Will buy TSLA
# Current weights are OrderedDict([('AAPL', 0.11337692525928543), ('AMD', 0.41043883446267204), ('AMZN', 0.0), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.0), ('NVDA', 0.0978779751132692), ('TSLA', 0.3772403886525099), ('VOO', 0.0)])
# Current balance = 163023.64781733474
# ------------------------------------
# 2021-12-31 00:00:00 Sell candidates: ['AAPL', 'MS', 'NVDA'] Buy candidates: ['F', 'INTC']
# Filtered sell candidates: {'MS': 100, 'NVDA': 37.0}
# Will sell NVDA and get 6245.779435603604 $ after selling ( 37.0 % )
# Will buy F
# Current weights are OrderedDict([('AAPL', 0.10907459086996614), ('AMD', 0.39755612137662744), ('AMZN', 0.0), ('F', 0.03650271856984674), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.0), ('NVDA', 0.060486115354071335), ('TSLA', 0.3963712832815487), ('VOO', 0.0)])
# Current balance = 175820.60714651918
# ------------------------------------
#
# With strategy final weights are: OrderedDict([('AAPL', 0.10907459086996614), ('AMD', 0.39755612137662744), ('AMZN', 0.0), ('F', 0.03650271856984674), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.0), ('NVDA', 0.060486115354071335), ('TSLA', 0.3963712832815487), ('VOO', 0.0)])
#
# With strategy balance on the end of 2021 would be 175820.60714651918

# %%
high_buy_and_hold = 0
low_buy_and_hold = 1_000_000_000
high_strategy = 0
low_strategy = 1_000_000_000
biggest_delta = 0
biggest_delta_day = ''
final_delta_usd = 0
final_delta_percent = 0

for d in balance_buy_and_hold_dict:
    if balance_buy_and_hold_dict[d] > high_buy_and_hold:
        high_buy_and_hold = balance_buy_and_hold_dict[d]
    if balance_buy_and_hold_dict[d] < low_buy_and_hold:
        low_buy_and_hold = balance_buy_and_hold_dict[d]
    if balance_strategy_dict[d] > high_strategy:
        high_strategy = balance_strategy_dict[d]
    if balance_strategy_dict[d] < low_strategy:
        low_strategy = balance_strategy_dict[d]
    delta = balance_strategy_dict[d] - balance_buy_and_hold_dict[d]
    delta_abs = abs(delta)
    percent = delta_abs / balance_buy_and_hold_dict[d]
    percent_change = percent
    if delta < 0:
        percent_change = -1 * percent_change
    if percent > abs(biggest_delta):
        biggest_delta = percent_change
        biggest_delta_day = d
    final_delta_usd = balance_strategy_dict[d] - balance_buy_and_hold_dict[d]
    final_delta_percent = percent_change
    print(d.strftime('%Y-%m-%d'), '\tBuy and hold balance:\t', "{:.2f}".format(balance_buy_and_hold_dict[d]), 
          '\tStrategy balance:\t', "{:.2f}".format(balance_strategy_dict[d]), 
          '\tDelta:\t', "{:.6f}".format(percent_change))

print('\nhigh_buy_and_hold', high_buy_and_hold)
print('low_buy_and_hold', low_buy_and_hold)
print('\nhigh_strategy', high_strategy)
print('low_strategy', low_strategy)
print('\nbiggest_delta', biggest_delta)
print('biggest_delta_day', biggest_delta_day)
print('\nfinal_delta_usd', final_delta_usd)
print('final_delta_percent', final_delta_percent)
# Out:
# 2021-01-04 	Buy and hold balance:	 100482.50 	Strategy balance:	 100482.50 	Delta:	 0.000000
# 2021-01-05 	Buy and hold balance:	 101666.21 	Strategy balance:	 101666.21 	Delta:	 0.000000
# 2021-01-06 	Buy and hold balance:	 99161.32 	Strategy balance:	 99161.32 	Delta:	 0.000000
# 2021-01-07 	Buy and hold balance:	 104411.65 	Strategy balance:	 104411.65 	Delta:	 0.000000
# 2021-01-08 	Buy and hold balance:	 106137.24 	Strategy balance:	 106137.24 	Delta:	 0.000000
# 2021-01-11 	Buy and hold balance:	 105164.80 	Strategy balance:	 105164.80 	Delta:	 0.000000
# 2021-01-12 	Buy and hold balance:	 105432.30 	Strategy balance:	 105432.30 	Delta:	 0.000000
# 2021-01-13 	Buy and hold balance:	 104951.79 	Strategy balance:	 104951.79 	Delta:	 0.000000
# 2021-01-14 	Buy and hold balance:	 103350.07 	Strategy balance:	 103350.07 	Delta:	 0.000000
# 2021-01-15 	Buy and hold balance:	 101049.46 	Strategy balance:	 101049.46 	Delta:	 0.000000
# 2021-01-19 	Buy and hold balance:	 102438.68 	Strategy balance:	 102438.68 	Delta:	 0.000000
# 2021-01-20 	Buy and hold balance:	 104012.14 	Strategy balance:	 104012.14 	Delta:	 0.000000
# 2021-01-21 	Buy and hold balance:	 106345.47 	Strategy balance:	 106345.47 	Delta:	 0.000000
# 2021-01-22 	Buy and hold balance:	 106564.50 	Strategy balance:	 106564.50 	Delta:	 0.000000
# 2021-01-25 	Buy and hold balance:	 108169.62 	Strategy balance:	 108169.62 	Delta:	 0.000000
# 2021-01-26 	Buy and hold balance:	 108066.68 	Strategy balance:	 108066.68 	Delta:	 0.000000
# 2021-01-27 	Buy and hold balance:	 104203.21 	Strategy balance:	 104203.21 	Delta:	 0.000000
# 2021-01-28 	Buy and hold balance:	 102854.36 	Strategy balance:	 102854.36 	Delta:	 0.000000
# 2021-01-29 	Buy and hold balance:	 100383.33 	Strategy balance:	 100383.33 	Delta:	 0.000000
# 2021-02-01 	Buy and hold balance:	 103554.83 	Strategy balance:	 103554.83 	Delta:	 0.000000
# 2021-02-02 	Buy and hold balance:	 105784.12 	Strategy balance:	 105784.12 	Delta:	 0.000000
# 2021-02-03 	Buy and hold balance:	 104577.87 	Strategy balance:	 104577.87 	Delta:	 0.000000
# 2021-02-04 	Buy and hold balance:	 105076.83 	Strategy balance:	 105076.83 	Delta:	 0.000000
# 2021-02-05 	Buy and hold balance:	 105021.53 	Strategy balance:	 105021.53 	Delta:	 0.000000
# 2021-02-08 	Buy and hold balance:	 108179.26 	Strategy balance:	 108179.26 	Delta:	 0.000000
# 2021-02-09 	Buy and hold balance:	 107078.36 	Strategy balance:	 107078.36 	Delta:	 0.000000
# 2021-02-10 	Buy and hold balance:	 107177.14 	Strategy balance:	 107177.14 	Delta:	 0.000000
# 2021-02-11 	Buy and hold balance:	 108426.70 	Strategy balance:	 108426.70 	Delta:	 0.000000
# 2021-02-12 	Buy and hold balance:	 108330.00 	Strategy balance:	 108330.00 	Delta:	 0.000000
# 2021-02-16 	Buy and hold balance:	 107649.60 	Strategy balance:	 107649.60 	Delta:	 0.000000
# 2021-02-17 	Buy and hold balance:	 106265.30 	Strategy balance:	 106265.30 	Delta:	 0.000000
# 2021-02-18 	Buy and hold balance:	 105366.84 	Strategy balance:	 105366.84 	Delta:	 0.000000
# 2021-02-19 	Buy and hold balance:	 105417.67 	Strategy balance:	 105417.67 	Delta:	 0.000000
# 2021-02-22 	Buy and hold balance:	 100379.21 	Strategy balance:	 100379.21 	Delta:	 0.000000
# 2021-02-23 	Buy and hold balance:	 99300.95 	Strategy balance:	 99300.95 	Delta:	 0.000000
# 2021-02-24 	Buy and hold balance:	 101837.50 	Strategy balance:	 101837.50 	Delta:	 0.000000
# 2021-02-25 	Buy and hold balance:	 95393.00 	Strategy balance:	 95393.00 	Delta:	 0.000000
# 2021-02-26 	Buy and hold balance:	 96859.97 	Strategy balance:	 96859.97 	Delta:	 0.000000
# 2021-03-01 	Buy and hold balance:	 99702.11 	Strategy balance:	 99702.11 	Delta:	 0.000000
# 2021-03-02 	Buy and hold balance:	 96726.35 	Strategy balance:	 96726.35 	Delta:	 0.000000
# 2021-03-03 	Buy and hold balance:	 92881.63 	Strategy balance:	 92881.63 	Delta:	 0.000000
# 2021-03-04 	Buy and hold balance:	 89810.24 	Strategy balance:	 89810.24 	Delta:	 0.000000
# 2021-03-05 	Buy and hold balance:	 89741.41 	Strategy balance:	 89741.41 	Delta:	 0.000000
# 2021-03-08 	Buy and hold balance:	 84853.55 	Strategy balance:	 84853.55 	Delta:	 0.000000
# 2021-03-09 	Buy and hold balance:	 92284.97 	Strategy balance:	 92284.97 	Delta:	 0.000000
# 2021-03-10 	Buy and hold balance:	 91595.34 	Strategy balance:	 91595.34 	Delta:	 0.000000
# 2021-03-11 	Buy and hold balance:	 95143.32 	Strategy balance:	 95143.32 	Delta:	 0.000000
# 2021-03-12 	Buy and hold balance:	 94451.76 	Strategy balance:	 94451.76 	Delta:	 0.000000
# 2021-03-15 	Buy and hold balance:	 96258.76 	Strategy balance:	 96258.76 	Delta:	 0.000000
# 2021-03-16 	Buy and hold balance:	 95811.60 	Strategy balance:	 95811.60 	Delta:	 0.000000
# 2021-03-17 	Buy and hold balance:	 96703.51 	Strategy balance:	 96703.51 	Delta:	 0.000000
# 2021-03-18 	Buy and hold balance:	 91835.38 	Strategy balance:	 91835.38 	Delta:	 0.000000
# 2021-03-19 	Buy and hold balance:	 92556.42 	Strategy balance:	 92556.42 	Delta:	 0.000000
# 2021-03-22 	Buy and hold balance:	 94531.93 	Strategy balance:	 94569.88 	Delta:	 0.000402
# 2021-03-23 	Buy and hold balance:	 93499.13 	Strategy balance:	 93568.90 	Delta:	 0.000746
# 2021-03-24 	Buy and hold balance:	 90673.44 	Strategy balance:	 90705.72 	Delta:	 0.000356
# 2021-03-25 	Buy and hold balance:	 90554.47 	Strategy balance:	 90570.79 	Delta:	 0.000180
# 2021-03-26 	Buy and hold balance:	 91012.09 	Strategy balance:	 91059.83 	Delta:	 0.000525
# 2021-03-29 	Buy and hold balance:	 91052.12 	Strategy balance:	 91131.88 	Delta:	 0.000876
# 2021-03-30 	Buy and hold balance:	 91059.33 	Strategy balance:	 91156.24 	Delta:	 0.001064
# 2021-03-31 	Buy and hold balance:	 94124.58 	Strategy balance:	 94251.82 	Delta:	 0.001352
# 2021-04-01 	Buy and hold balance:	 96040.00 	Strategy balance:	 96192.02 	Delta:	 0.001583
# 2021-04-05 	Buy and hold balance:	 97865.52 	Strategy balance:	 98046.08 	Delta:	 0.001845
# 2021-04-06 	Buy and hold balance:	 97625.30 	Strategy balance:	 97777.84 	Delta:	 0.001563
# 2021-04-07 	Buy and hold balance:	 98204.55 	Strategy balance:	 98396.48 	Delta:	 0.001954
# 2021-04-08 	Buy and hold balance:	 99583.34 	Strategy balance:	 99779.18 	Delta:	 0.001967
# 2021-04-09 	Buy and hold balance:	 99873.61 	Strategy balance:	 100105.28 	Delta:	 0.002320
# 2021-04-12 	Buy and hold balance:	 101007.76 	Strategy balance:	 101541.98 	Delta:	 0.005289
# 2021-04-13 	Buy and hold balance:	 104632.23 	Strategy balance:	 105221.98 	Delta:	 0.005636
# 2021-04-14 	Buy and hold balance:	 101937.54 	Strategy balance:	 102487.62 	Delta:	 0.005396
# 2021-04-15 	Buy and hold balance:	 105718.33 	Strategy balance:	 106324.75 	Delta:	 0.005736
# 2021-04-16 	Buy and hold balance:	 105040.47 	Strategy balance:	 105623.07 	Delta:	 0.005546
# 2021-04-19 	Buy and hold balance:	 102747.09 	Strategy balance:	 103239.52 	Delta:	 0.004793
# 2021-04-20 	Buy and hold balance:	 101629.93 	Strategy balance:	 102135.28 	Delta:	 0.004972
# 2021-04-21 	Buy and hold balance:	 103609.03 	Strategy balance:	 104086.28 	Delta:	 0.004606
# 2021-04-22 	Buy and hold balance:	 100694.39 	Strategy balance:	 101135.38 	Delta:	 0.004379
# 2021-04-23 	Buy and hold balance:	 103306.00 	Strategy balance:	 103728.03 	Delta:	 0.004085
# 2021-04-26 	Buy and hold balance:	 105095.58 	Strategy balance:	 105485.45 	Delta:	 0.003710
# 2021-04-27 	Buy and hold balance:	 103845.58 	Strategy balance:	 104220.23 	Delta:	 0.003608
# 2021-04-28 	Buy and hold balance:	 103034.65 	Strategy balance:	 103421.66 	Delta:	 0.003756
# 2021-04-29 	Buy and hold balance:	 102633.57 	Strategy balance:	 103034.42 	Delta:	 0.003906
# 2021-04-30 	Buy and hold balance:	 102026.81 	Strategy balance:	 102426.55 	Delta:	 0.003918
# 2021-05-03 	Buy and hold balance:	 99818.29 	Strategy balance:	 100271.50 	Delta:	 0.004540
# 2021-05-04 	Buy and hold balance:	 97777.91 	Strategy balance:	 98122.52 	Delta:	 0.003525
# 2021-05-05 	Buy and hold balance:	 97576.85 	Strategy balance:	 97968.30 	Delta:	 0.004012
# 2021-05-06 	Buy and hold balance:	 97785.51 	Strategy balance:	 98189.37 	Delta:	 0.004130
# 2021-05-07 	Buy and hold balance:	 98939.69 	Strategy balance:	 99379.77 	Delta:	 0.004448
# 2021-05-10 	Buy and hold balance:	 94986.91 	Strategy balance:	 95350.19 	Delta:	 0.003825
# 2021-05-11 	Buy and hold balance:	 95017.36 	Strategy balance:	 95318.87 	Delta:	 0.003173
# 2021-05-12 	Buy and hold balance:	 91841.68 	Strategy balance:	 92071.22 	Delta:	 0.002499
# 2021-05-13 	Buy and hold balance:	 90862.52 	Strategy balance:	 91108.53 	Delta:	 0.002707
# 2021-05-14 	Buy and hold balance:	 93533.14 	Strategy balance:	 93871.48 	Delta:	 0.003617
# 2021-05-17 	Buy and hold balance:	 93070.89 	Strategy balance:	 93393.17 	Delta:	 0.003463
# 2021-05-18 	Buy and hold balance:	 92454.88 	Strategy balance:	 92719.80 	Delta:	 0.002865
# 2021-05-19 	Buy and hold balance:	 92659.80 	Strategy balance:	 92875.12 	Delta:	 0.002324
# 2021-05-20 	Buy and hold balance:	 95365.65 	Strategy balance:	 95611.35 	Delta:	 0.002576
# 2021-05-21 	Buy and hold balance:	 95439.79 	Strategy balance:	 95785.57 	Delta:	 0.003623
# 2021-05-24 	Buy and hold balance:	 97919.09 	Strategy balance:	 98364.12 	Delta:	 0.004545
# 2021-05-25 	Buy and hold balance:	 98104.12 	Strategy balance:	 98535.12 	Delta:	 0.004393
# 2021-05-26 	Buy and hold balance:	 98802.60 	Strategy balance:	 99184.44 	Delta:	 0.003865
# 2021-05-27 	Buy and hold balance:	 98448.07 	Strategy balance:	 98714.74 	Delta:	 0.002709
# 2021-05-28 	Buy and hold balance:	 100352.40 	Strategy balance:	 100698.61 	Delta:	 0.003450
# 2021-06-01 	Buy and hold balance:	 100531.27 	Strategy balance:	 100840.07 	Delta:	 0.003072
# 2021-06-02 	Buy and hold balance:	 101571.94 	Strategy balance:	 101997.63 	Delta:	 0.004191
# 2021-06-03 	Buy and hold balance:	 100244.85 	Strategy balance:	 100842.34 	Delta:	 0.005960
# 2021-06-04 	Buy and hold balance:	 103001.64 	Strategy balance:	 103657.08 	Delta:	 0.006363
# 2021-06-07 	Buy and hold balance:	 103172.39 	Strategy balance:	 103781.80 	Delta:	 0.005907
# 2021-06-08 	Buy and hold balance:	 102941.41 	Strategy balance:	 103598.00 	Delta:	 0.006378
# 2021-06-09 	Buy and hold balance:	 102400.56 	Strategy balance:	 103044.55 	Delta:	 0.006289
# 2021-06-10 	Buy and hold balance:	 103512.66 	Strategy balance:	 104199.85 	Delta:	 0.006639
# 2021-06-11 	Buy and hold balance:	 104403.35 	Strategy balance:	 104957.73 	Delta:	 0.005310
# 2021-06-14 	Buy and hold balance:	 105524.97 	Strategy balance:	 106049.84 	Delta:	 0.004974
# 2021-06-15 	Buy and hold balance:	 104087.18 	Strategy balance:	 104638.66 	Delta:	 0.005298
# 2021-06-16 	Buy and hold balance:	 104346.53 	Strategy balance:	 104840.03 	Delta:	 0.004729
# 2021-06-17 	Buy and hold balance:	 108273.71 	Strategy balance:	 108828.61 	Delta:	 0.005125
# 2021-06-18 	Buy and hold balance:	 108335.48 	Strategy balance:	 108865.23 	Delta:	 0.004890
# 2021-06-21 	Buy and hold balance:	 107225.13 	Strategy balance:	 107682.59 	Delta:	 0.004266
# 2021-06-22 	Buy and hold balance:	 108936.49 	Strategy balance:	 109266.14 	Delta:	 0.003026
# 2021-06-23 	Buy and hold balance:	 110315.75 	Strategy balance:	 110556.53 	Delta:	 0.002183
# 2021-06-24 	Buy and hold balance:	 111782.88 	Strategy balance:	 112220.54 	Delta:	 0.003915
# 2021-06-25 	Buy and hold balance:	 110829.94 	Strategy balance:	 111325.06 	Delta:	 0.004467
# 2021-06-28 	Buy and hold balance:	 114141.12 	Strategy balance:	 114344.99 	Delta:	 0.001786
# 2021-06-29 	Buy and hold balance:	 114873.01 	Strategy balance:	 115316.71 	Delta:	 0.003863
# 2021-06-30 	Buy and hold balance:	 116128.21 	Strategy balance:	 117145.00 	Delta:	 0.008756
# 2021-07-01 	Buy and hold balance:	 116350.87 	Strategy balance:	 117178.84 	Delta:	 0.007116
# 2021-07-02 	Buy and hold balance:	 117901.67 	Strategy balance:	 118655.47 	Delta:	 0.006393
# 2021-07-06 	Buy and hold balance:	 118489.60 	Strategy balance:	 118466.18 	Delta:	 -0.000198
# 2021-07-07 	Buy and hold balance:	 116455.66 	Strategy balance:	 115925.94 	Delta:	 -0.004549
# 2021-07-08 	Buy and hold balance:	 115440.11 	Strategy balance:	 114865.17 	Delta:	 -0.004980
# 2021-07-09 	Buy and hold balance:	 116346.35 	Strategy balance:	 115984.44 	Delta:	 -0.003111
# 2021-07-12 	Buy and hold balance:	 118120.54 	Strategy balance:	 117812.00 	Delta:	 -0.002612
# 2021-07-13 	Buy and hold balance:	 116829.08 	Strategy balance:	 116576.80 	Delta:	 -0.002159
# 2021-07-14 	Buy and hold balance:	 115442.88 	Strategy balance:	 115119.61 	Delta:	 -0.002800
# 2021-07-15 	Buy and hold balance:	 112576.62 	Strategy balance:	 112407.72 	Delta:	 -0.001500
# 2021-07-16 	Buy and hold balance:	 109934.03 	Strategy balance:	 109994.61 	Delta:	 0.000551
# 2021-07-19 	Buy and hold balance:	 111133.14 	Strategy balance:	 110684.14 	Delta:	 -0.004040
# 2021-07-20 	Buy and hold balance:	 111740.87 	Strategy balance:	 111935.94 	Delta:	 0.001746
# 2021-07-21 	Buy and hold balance:	 113999.95 	Strategy balance:	 113436.37 	Delta:	 -0.004944
# 2021-07-22 	Buy and hold balance:	 115068.97 	Strategy balance:	 114207.09 	Delta:	 -0.007490
# 2021-07-23 	Buy and hold balance:	 115313.44 	Strategy balance:	 114411.82 	Delta:	 -0.007819
# 2021-07-26 	Buy and hold balance:	 115244.48 	Strategy balance:	 114836.68 	Delta:	 -0.003539
# 2021-07-27 	Buy and hold balance:	 113994.71 	Strategy balance:	 113427.23 	Delta:	 -0.004978
# 2021-07-28 	Buy and hold balance:	 116623.29 	Strategy balance:	 116595.46 	Delta:	 -0.000239
# 2021-07-29 	Buy and hold balance:	 119306.49 	Strategy balance:	 120705.18 	Delta:	 0.011723
# 2021-07-30 	Buy and hold balance:	 119255.91 	Strategy balance:	 122469.00 	Delta:	 0.026943
# 2021-08-02 	Buy and hold balance:	 121176.75 	Strategy balance:	 125038.47 	Delta:	 0.031869
# 2021-08-03 	Buy and hold balance:	 122772.09 	Strategy balance:	 126965.43 	Delta:	 0.034156
# 2021-08-04 	Buy and hold balance:	 125586.74 	Strategy balance:	 130122.60 	Delta:	 0.036117
# 2021-08-05 	Buy and hold balance:	 124662.24 	Strategy balance:	 128070.04 	Delta:	 0.027336
# 2021-08-06 	Buy and hold balance:	 122757.26 	Strategy balance:	 125825.11 	Delta:	 0.024991
# 2021-08-09 	Buy and hold balance:	 122262.70 	Strategy balance:	 125520.42 	Delta:	 0.026645
# 2021-08-10 	Buy and hold balance:	 120921.23 	Strategy balance:	 124376.60 	Delta:	 0.028575
# 2021-08-11 	Buy and hold balance:	 120616.83 	Strategy balance:	 124511.37 	Delta:	 0.032289
# 2021-08-12 	Buy and hold balance:	 121437.59 	Strategy balance:	 125410.70 	Delta:	 0.032717
# 2021-08-13 	Buy and hold balance:	 123099.27 	Strategy balance:	 127165.68 	Delta:	 0.033034
# 2021-08-16 	Buy and hold balance:	 120943.37 	Strategy balance:	 124036.94 	Delta:	 0.025579
# 2021-08-17 	Buy and hold balance:	 119008.07 	Strategy balance:	 122227.16 	Delta:	 0.027049
# 2021-08-18 	Buy and hold balance:	 117077.59 	Strategy balance:	 120944.89 	Delta:	 0.033032
# 2021-08-19 	Buy and hold balance:	 118340.92 	Strategy balance:	 121067.16 	Delta:	 0.023037
# 2021-08-20 	Buy and hold balance:	 121222.57 	Strategy balance:	 123186.39 	Delta:	 0.016200
# 2021-08-23 	Buy and hold balance:	 126078.37 	Strategy balance:	 127890.27 	Delta:	 0.014371
# 2021-08-24 	Buy and hold balance:	 125581.53 	Strategy balance:	 127347.14 	Delta:	 0.014060
# 2021-08-25 	Buy and hold balance:	 126643.99 	Strategy balance:	 128122.07 	Delta:	 0.011671
# 2021-08-26 	Buy and hold balance:	 125715.00 	Strategy balance:	 126856.58 	Delta:	 0.009081
# 2021-08-27 	Buy and hold balance:	 128714.78 	Strategy balance:	 129976.22 	Delta:	 0.009800
# 2021-08-30 	Buy and hold balance:	 130001.45 	Strategy balance:	 131583.99 	Delta:	 0.012173
# 2021-08-31 	Buy and hold balance:	 129365.25 	Strategy balance:	 131121.99 	Delta:	 0.013580
# 2021-09-01 	Buy and hold balance:	 129309.48 	Strategy balance:	 130859.44 	Delta:	 0.011986
# 2021-09-02 	Buy and hold balance:	 128966.17 	Strategy balance:	 130501.41 	Delta:	 0.011904
# 2021-09-03 	Buy and hold balance:	 130302.52 	Strategy balance:	 131454.89 	Delta:	 0.008844
# 2021-09-07 	Buy and hold balance:	 130558.33 	Strategy balance:	 132296.27 	Delta:	 0.013312
# 2021-09-08 	Buy and hold balance:	 128914.03 	Strategy balance:	 130558.72 	Delta:	 0.012758
# 2021-09-09 	Buy and hold balance:	 128347.17 	Strategy balance:	 130309.06 	Delta:	 0.015286
# 2021-09-10 	Buy and hold balance:	 127691.17 	Strategy balance:	 128634.55 	Delta:	 0.007388
# 2021-09-13 	Buy and hold balance:	 127062.22 	Strategy balance:	 128542.61 	Delta:	 0.011651
# 2021-09-14 	Buy and hold balance:	 127433.16 	Strategy balance:	 128967.64 	Delta:	 0.012041
# 2021-09-15 	Buy and hold balance:	 128112.77 	Strategy balance:	 129777.99 	Delta:	 0.012998
# 2021-09-16 	Buy and hold balance:	 128138.55 	Strategy balance:	 129965.47 	Delta:	 0.014257
# 2021-09-17 	Buy and hold balance:	 126442.22 	Strategy balance:	 128439.80 	Delta:	 0.015798
# 2021-09-20 	Buy and hold balance:	 122520.00 	Strategy balance:	 124533.10 	Delta:	 0.016431
# 2021-09-21 	Buy and hold balance:	 123458.58 	Strategy balance:	 125802.11 	Delta:	 0.018982
# 2021-09-22 	Buy and hold balance:	 126148.93 	Strategy balance:	 128239.30 	Delta:	 0.016571
# 2021-09-23 	Buy and hold balance:	 128121.97 	Strategy balance:	 129807.00 	Delta:	 0.013152
# 2021-09-24 	Buy and hold balance:	 127789.59 	Strategy balance:	 130404.35 	Delta:	 0.020461
# 2021-09-27 	Buy and hold balance:	 127866.91 	Strategy balance:	 131721.47 	Delta:	 0.030145
# 2021-09-28 	Buy and hold balance:	 122765.77 	Strategy balance:	 126662.91 	Delta:	 0.031744
# 2021-09-29 	Buy and hold balance:	 122154.05 	Strategy balance:	 126278.19 	Delta:	 0.033762
# 2021-09-30 	Buy and hold balance:	 123008.61 	Strategy balance:	 127097.62 	Delta:	 0.033242
# 2021-10-01 	Buy and hold balance:	 123015.25 	Strategy balance:	 127047.80 	Delta:	 0.032781
# 2021-10-04 	Buy and hold balance:	 119729.47 	Strategy balance:	 124987.03 	Delta:	 0.043912
# 2021-10-05 	Buy and hold balance:	 121992.84 	Strategy balance:	 126588.03 	Delta:	 0.037668
# 2021-10-06 	Buy and hold balance:	 123368.09 	Strategy balance:	 127862.49 	Delta:	 0.036431
# 2021-10-07 	Buy and hold balance:	 125598.42 	Strategy balance:	 130237.11 	Delta:	 0.036933
# 2021-10-08 	Buy and hold balance:	 124329.47 	Strategy balance:	 128863.87 	Delta:	 0.036471
# 2021-10-11 	Buy and hold balance:	 123949.71 	Strategy balance:	 128909.95 	Delta:	 0.040018
# 2021-10-12 	Buy and hold balance:	 124301.80 	Strategy balance:	 129686.61 	Delta:	 0.043320
# 2021-10-13 	Buy and hold balance:	 126353.88 	Strategy balance:	 131967.44 	Delta:	 0.044427
# 2021-10-14 	Buy and hold balance:	 129474.48 	Strategy balance:	 134806.38 	Delta:	 0.041181
# 2021-10-15 	Buy and hold balance:	 130971.41 	Strategy balance:	 136533.63 	Delta:	 0.042469
# 2021-10-18 	Buy and hold balance:	 134117.79 	Strategy balance:	 140550.56 	Delta:	 0.047964
# 2021-10-19 	Buy and hold balance:	 134244.26 	Strategy balance:	 140532.88 	Delta:	 0.046845
# 2021-10-20 	Buy and hold balance:	 133836.72 	Strategy balance:	 140476.25 	Delta:	 0.049609
# 2021-10-21 	Buy and hold balance:	 136919.47 	Strategy balance:	 143984.49 	Delta:	 0.051600
# 2021-10-22 	Buy and hold balance:	 137179.66 	Strategy balance:	 144943.68 	Delta:	 0.056597
# 2021-10-25 	Buy and hold balance:	 142220.66 	Strategy balance:	 152314.73 	Delta:	 0.070975
# 2021-10-26 	Buy and hold balance:	 145854.13 	Strategy balance:	 154130.72 	Delta:	 0.056746
# 2021-10-27 	Buy and hold balance:	 145666.18 	Strategy balance:	 154409.90 	Delta:	 0.060026
# 2021-10-28 	Buy and hold balance:	 148062.99 	Strategy balance:	 156747.80 	Delta:	 0.058656
# 2021-10-29 	Buy and hold balance:	 149742.30 	Strategy balance:	 158524.52 	Delta:	 0.058649
# 2021-11-01 	Buy and hold balance:	 154312.10 	Strategy balance:	 165790.76 	Delta:	 0.074386
# 2021-11-02 	Buy and hold balance:	 155282.13 	Strategy balance:	 165938.99 	Delta:	 0.068629
# 2021-11-03 	Buy and hold balance:	 158183.54 	Strategy balance:	 169781.42 	Delta:	 0.073319
# 2021-11-04 	Buy and hold balance:	 168031.07 	Strategy balance:	 177572.13 	Delta:	 0.056782
# 2021-11-05 	Buy and hold balance:	 167524.95 	Strategy balance:	 176604.22 	Delta:	 0.054197
# 2021-11-08 	Buy and hold balance:	 172034.19 	Strategy balance:	 181538.94 	Delta:	 0.055249
# 2021-11-09 	Buy and hold balance:	 167593.69 	Strategy balance:	 173982.82 	Delta:	 0.038123
# 2021-11-10 	Buy and hold balance:	 162997.04 	Strategy balance:	 170075.17 	Delta:	 0.043425
# 2021-11-11 	Buy and hold balance:	 166697.26 	Strategy balance:	 173903.62 	Delta:	 0.043230
# 2021-11-12 	Buy and hold balance:	 166741.97 	Strategy balance:	 173573.00 	Delta:	 0.040968
# 2021-11-15 	Buy and hold balance:	 165011.61 	Strategy balance:	 171494.67 	Delta:	 0.039289
# 2021-11-16 	Buy and hold balance:	 168457.47 	Strategy balance:	 176725.45 	Delta:	 0.049081
# 2021-11-17 	Buy and hold balance:	 167310.36 	Strategy balance:	 177051.73 	Delta:	 0.058223
# 2021-11-18 	Buy and hold balance:	 174804.22 	Strategy balance:	 182444.08 	Delta:	 0.043705
# 2021-11-19 	Buy and hold balance:	 179141.23 	Strategy balance:	 186417.83 	Delta:	 0.040619
# 2021-11-22 	Buy and hold balance:	 176278.34 	Strategy balance:	 184853.21 	Delta:	 0.048644
# 2021-11-23 	Buy and hold balance:	 173700.00 	Strategy balance:	 181049.77 	Delta:	 0.042313
# 2021-11-24 	Buy and hold balance:	 178331.38 	Strategy balance:	 186341.08 	Delta:	 0.044915
# 2021-11-26 	Buy and hold balance:	 173170.87 	Strategy balance:	 181322.40 	Delta:	 0.047072
# 2021-11-29 	Buy and hold balance:	 181497.87 	Strategy balance:	 189987.09 	Delta:	 0.046773
# 2021-11-30 	Buy and hold balance:	 179374.49 	Strategy balance:	 188390.81 	Delta:	 0.050265
# 2021-12-01 	Buy and hold balance:	 172167.65 	Strategy balance:	 179975.49 	Delta:	 0.045350
# 2021-12-02 	Buy and hold balance:	 173735.31 	Strategy balance:	 180913.19 	Delta:	 0.041315
# 2021-12-03 	Buy and hold balance:	 166234.82 	Strategy balance:	 172412.87 	Delta:	 0.037165
# 2021-12-06 	Buy and hold balance:	 163577.46 	Strategy balance:	 169339.54 	Delta:	 0.035225
# 2021-12-07 	Buy and hold balance:	 172629.31 	Strategy balance:	 177620.32 	Delta:	 0.028912
# 2021-12-08 	Buy and hold balance:	 172265.21 	Strategy balance:	 178383.43 	Delta:	 0.035516
# 2021-12-09 	Buy and hold balance:	 165115.01 	Strategy balance:	 170136.14 	Delta:	 0.030410
# 2021-12-10 	Buy and hold balance:	 165274.27 	Strategy balance:	 171195.22 	Delta:	 0.035825
# 2021-12-13 	Buy and hold balance:	 157409.77 	Strategy balance:	 163671.33 	Delta:	 0.039779
# 2021-12-14 	Buy and hold balance:	 157946.24 	Strategy balance:	 164208.75 	Delta:	 0.039650
# 2021-12-15 	Buy and hold balance:	 167076.68 	Strategy balance:	 173331.54 	Delta:	 0.037437
# 2021-12-16 	Buy and hold balance:	 157843.41 	Strategy balance:	 163973.04 	Delta:	 0.038834
# 2021-12-17 	Buy and hold balance:	 156446.79 	Strategy balance:	 163023.65 	Delta:	 0.042039
# 2021-12-20 	Buy and hold balance:	 154402.18 	Strategy balance:	 159727.46 	Delta:	 0.034490
# 2021-12-21 	Buy and hold balance:	 161534.29 	Strategy balance:	 167505.03 	Delta:	 0.036963
# 2021-12-22 	Buy and hold balance:	 164468.35 	Strategy balance:	 172436.68 	Delta:	 0.048449
# 2021-12-23 	Buy and hold balance:	 167429.21 	Strategy balance:	 177574.75 	Delta:	 0.060596
# 2021-12-27 	Buy and hold balance:	 173771.89 	Strategy balance:	 184530.56 	Delta:	 0.061913
# 2021-12-28 	Buy and hold balance:	 171868.48 	Strategy balance:	 183112.19 	Delta:	 0.065420
# 2021-12-29 	Buy and hold balance:	 169545.38 	Strategy balance:	 180412.03 	Delta:	 0.064093
# 2021-12-30 	Buy and hold balance:	 167105.00 	Strategy balance:	 177490.49 	Delta:	 0.062149
# 2021-12-31 	Buy and hold balance:	 165761.09 	Strategy balance:	 175820.61 	Delta:	 0.060687
#
# high_buy_and_hold 181497.8702392578
# low_buy_and_hold 84853.55306243896
#
# high_strategy 189987.093252302
# low_strategy 84853.55306243896
#
# biggest_delta 0.07438603229951786
# biggest_delta_day 2021-11-01 00:00:00
#
# final_delta_usd 10059.51872183656
# final_delta_percent 0.06068685249015685
