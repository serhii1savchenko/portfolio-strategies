# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from math import sqrt
from pypfopt.expected_returns import mean_historical_return
from pypfopt.risk_models import CovarianceShrinkage
from pypfopt.efficient_frontier import EfficientFrontier
from pypfopt.discrete_allocation import get_latest_prices
from dateutil.relativedelta import relativedelta
import copy
import warnings
warnings.filterwarnings('ignore')

tickers = ['AAPL', 'GOOG', 'MSFT', 'AMZN', 'INTC', 'AMD', 'NVDA', 'F', 'TSLA', 'JPM', 'MS', 'VOO']
data_for_portfolio_5y = yf.download(tickers, start='2017-01-01', end='2022-01-01')['Close'].dropna()
data_for_portfolio_5y.tail()
# Out:
# [*********************100%***********************]  12 of 12 completed
#                   AAPL         AMD        AMZN          F        GOOG  \
# Date
# 2021-12-27  180.330002  154.360001  169.669495  20.799999  148.063995
# 2021-12-28  179.289993  153.149994  170.660995  20.760000  146.447998
# 2021-12-29  179.380005  148.259995  169.201004  20.559999  146.504501
# 2021-12-30  178.199997  145.149994  168.644501  20.469999  146.002502
# 2021-12-31  177.570007  143.899994  166.716995  20.770000  144.679504
#
#                  INTC         JPM          MS        MSFT        NVDA  \
# Date
# 2021-12-27  51.939999  158.160004  100.400002  342.450012  309.450012
# 2021-12-28  51.759998  158.639999   99.970001  341.250000  303.220001
# 2021-12-29  51.830002  158.559998   98.730003  341.950012  300.010010
# 2021-12-30  51.740002  158.479996   98.800003  339.320007  295.859985
# 2021-12-31  51.500000  158.350006   98.160004  336.320007  294.109985
#
#                   TSLA         VOO
# Date
# 2021-12-27  364.646667  438.809998
# 2021-12-28  362.823334  438.480011
# 2021-12-29  362.063324  439.010010
# 2021-12-30  356.779999  437.769989
# 2021-12-31  352.260010  436.570007

# %%
# Create initial portfolio
mu = mean_historical_return(data_for_portfolio_5y)
S = CovarianceShrinkage(data_for_portfolio_5y).ledoit_wolf()
ef = EfficientFrontier(mu, S, weight_bounds=(0,1))
weights = ef.max_sharpe()
initial_weights = ef.clean_weights()
print(initial_weights, '\n')

# Initial buy stocks
balance_usd = 100_000
balance_remain = balance_usd
stocks_initial = {}
latest_prices_data_dec_2021 = get_latest_prices(data_for_portfolio_5y)
for ticker in initial_weights:
    to_spend_usd = balance_usd * initial_weights[ticker]
    one_stock_price = latest_prices_data_dec_2021[ticker]
    stocks_number = to_spend_usd // one_stock_price
    stocks_initial[ticker] = stocks_number
    balance_remain = balance_remain - (stocks_number * one_stock_price)
print('Portfolio:', stocks_initial)
print('Remaining balance: USD', balance_remain)
# Out:
# OrderedDict([('AAPL', 0.25899), ('AMD', 0.10384), ('AMZN', 0.0), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.25217), ('NVDA', 0.09699), ('TSLA', 0.288), ('VOO', 0.0)])
#
# Portfolio: {'AAPL': 145.0, 'AMD': 72.0, 'AMZN': 0.0, 'F': 0.0, 'GOOG': 0.0, 'INTC': 0.0, 'JPM': 0.0, 'MS': 0.0, 'MSFT': 74.0, 'NVDA': 32.0, 'TSLA': 81.0, 'VOO': 0.0}
# Remaining balance: USD 1059.2885131835938

# %%
# Calculate MACD, RSI, and S&R signals.
data_2022 = yf.download(tickers, start='2021-12-14', end='2023-01-01')['Close'].dropna()

short_ma = 5                                       # 5 минулих днів для "короткого" МА 
long_ma = 12                                       # 12 минулих днів для "довгого" МА 
rsi_period = 14                                    # RSI рахується за 14 минулих днів 
rsi_oversold = 30                                  # Параметри для індикатора RSI 
rsi_overbought = 70 
sr_sell = 0.7                                      # Параметри для індикатора S&R
sr_buy = 0.3 
start = max(long_ma, rsi_period)

for ticker in data_2022.columns:
    data_2022['MA_' + ticker + str(short_ma)] = data_2022[ticker].rolling(short_ma).mean()
    data_2022['MA_' + ticker + str(long_ma)] = data_2022[ticker].rolling(long_ma).mean() 
    data_2022['return_' + ticker] = data_2022[ticker].pct_change() 
    data_2022['Up_' + ticker] = np.maximum(data_2022[ticker].diff(),0) 
    data_2022['Down_' + ticker] = np.maximum(-data_2022[ticker].diff(),0) 
    data_2022['RS_' + ticker] = data_2022['Up_' + ticker].rolling(rsi_period).mean()/data_2022['Down_' + ticker].rolling(rsi_period).mean() 
    data_2022['RSI_' + ticker] = 100 - 100/(1 + data_2022['RS_' + ticker]) 
    data_2022['S&R_' + ticker] = (data_2022[ticker]/(10**np.floor(np.log10(data_2022[ticker]))))%1 
    data_2022['MACD_signal_' + ticker] = 2*(data_2022['MA_' + ticker + str(short_ma)] > data_2022['MA_' + ticker + str(long_ma)]) -1 
    data_2022['RSI_signal_' + ticker] = 1*(data_2022['RSI_' + ticker] < rsi_oversold) -1*(data_2022['RSI_' + ticker] > rsi_overbought) 
    data_2022['S&R_signal_' + ticker] = 1*(data_2022['S&R_' + ticker] < sr_buy) -1*(data_2022['S&R_' + ticker] > sr_sell) 

data = data_2022.drop(data_2022.index[range(14)])
#print(data.to_string())
data.head(3)
# Out:
# [*********************100%***********************]  12 of 12 completed
#                   AAPL         AMD        AMZN          F        GOOG  \
# Date
# 2022-01-03  182.009995  150.240005  170.404495  21.770000  145.074493
# 2022-01-04  179.699997  144.419998  167.522003  24.309999  144.416504
# 2022-01-05  174.919998  136.149994  164.356995  23.660000  137.653503
#
#                  INTC         JPM          MS        MSFT        NVDA  ...  \
# Date                                                                   ...
# 2022-01-03  53.209999  161.699997  100.190002  334.750000  301.209991  ...
# 2022-01-04  53.139999  167.830002  104.260002  329.010010  292.899994  ...
# 2022-01-05  53.869999  163.779999  101.680000  316.380005  276.040009  ...
#
#               MA_VOO12  return_VOO    Up_VOO  Down_VOO    RS_VOO    RSI_VOO  \
# Date
# 2022-01-03  432.603335    0.006139  2.679993  0.000000  1.549355  60.774396
# 2022-01-04  433.455836   -0.000410  0.000000  0.179993  1.816353  64.493090
# 2022-01-05  433.978335   -0.019154  0.000000  8.410004  0.914027  47.754141
#
#             S&R_VOO  MACD_signal_VOO  RSI_signal_VOO  S&R_signal_VOO
# Date
# 2022-01-03   0.3925                1               0               0
# 2022-01-04   0.3907                1               0               0
# 2022-01-05   0.3066                1               0               0
#
# [3 rows x 144 columns]

# %%
data.tail(3)
# Out:
#                   AAPL        AMD   AMZN      F       GOOG       INTC  \
# Date
# 2022-12-28  126.040001  62.570000  81.82  10.95  86.459999  25.540001
# 2022-12-29  129.610001  64.820000  84.18  11.54  88.949997  26.209999
# 2022-12-30  129.929993  64.769997  84.00  11.63  88.730003  26.430000
#
#                    JPM         MS        MSFT        NVDA  ...    MA_VOO12  \
# Date                                                       ...
# 2022-12-28  132.460007  84.459999  234.529999  140.360001  ...  355.751668
# 2022-12-29  133.220001  85.239998  241.009995  146.029999  ...  354.554169
# 2022-12-30  134.100006  85.019997  239.820007  146.139999  ...  353.050001
#
#             return_VOO    Up_VOO  Down_VOO    RS_VOO    RSI_VOO  S&R_VOO  \
# Date
# 2022-12-28   -0.012269  0.000000  4.299988  0.541579  35.131445   0.4617
# 2022-12-29    0.017737  6.139984  0.000000  0.641064  39.063936   0.5231
# 2022-12-30   -0.002753  0.000000  0.970001  0.675590  40.319512   0.5134
#
#             MACD_signal_VOO  RSI_signal_VOO  S&R_signal_VOO
# Date
# 2022-12-28               -1               0               0
# 2022-12-29               -1               0               0
# 2022-12-30               -1               0               0
#
# [3 rows x 144 columns]

# %%
def check_tickers_for_sell(tickers_sell, now, current_weights):
    ticker_percent_sell = {}
    end_date = now.strftime('%Y-%m-%d')
    start_date = (now - relativedelta(years=5)).strftime('%Y-%m-%d')
    # Get data for all tickers for last 5 years
    data_for_tickers = yf.download(tickers, start_date, end_date, progress=False)['Close'].dropna()
    
    # Generate portfolio on this data
    mu = mean_historical_return(data_for_tickers)
    S = CovarianceShrinkage(data_for_tickers).ledoit_wolf()
    ef = EfficientFrontier(mu, S, weight_bounds=(0,1))
    weights = ef.max_sharpe()
    new_weights = ef.clean_weights()
    
    for ticker in tickers_sell:
        if new_weights[ticker] == 0:
            ticker_percent_sell[ticker] = 100
        elif new_weights[ticker] < current_weights[ticker]:
            delta = current_weights[ticker] - new_weights[ticker]
            sell_percent = (delta * 100) // current_weights[ticker]
            ticker_percent_sell[ticker] = sell_percent
    return ticker_percent_sell

# %%
def select_ticker_for_sell(data, date, filtered_sell_tickers_with_percents, stocks_current):
    sell_ticker = ''
    sell_profit = 0
    stocks_to_sell = 0
    for ticker in filtered_sell_tickers_with_percents:
        no_of_stocks = stocks_current[ticker]
        #print(ticker, 'no_of_stocks', no_of_stocks)
        cur_price = data[ticker][date]
        #print(ticker, 'cur_price', cur_price)
        sell_percent = (filtered_sell_tickers_with_percents[ticker] / 100)
        #print(ticker, 'sell_percent', sell_percent)
        potentail_profit = no_of_stocks * cur_price * sell_percent
        #print(ticker, 'potentail_profit', potentail_profit)
        if potentail_profit > sell_profit:
            sell_profit = potentail_profit
            sell_ticker = ticker
            stocks_to_sell = no_of_stocks * sell_percent
    return [sell_ticker, sell_profit, stocks_to_sell]

# %%
def select_ticker_for_buy(tickers_buy, now):
    if len(tickers_buy) == 1:
        return tickers_buy[0]
    end_date = now.strftime('%Y-%m-%d')
    start_date = (now - relativedelta(years=5)).strftime('%Y-%m-%d')
    # Get data for all tickers for last 5 years period
    data_for_tickers_last_year = yf.download(tickers_buy, start_date, end_date, progress=False)['Close'].dropna()
    ticker_percent_delta = {}
    for t in tickers_buy:
        first_price = data_for_tickers_last_year[t][0]
        last_price = data_for_tickers_last_year[t][len(data_for_tickers_last_year[t]) - 1]
        delta = last_price - first_price
        delta_abs = abs(delta)
        percent = (delta_abs * 100) / first_price
        if delta > 0:
            ticker_percent_delta[t] = percent
        else:
            ticker_percent_delta[t] = -1 * percent
    sorted_by_delta = dict(sorted(ticker_percent_delta.items(), key=lambda x:x[1], reverse=True))
    return list(sorted_by_delta.keys())[0]

# %%
print('Start weights:', initial_weights)
clean_result = balance_remain
for stock in initial_weights:
    clean_result = clean_result + (stocks_initial[stock] * data[stock][len(data[stock]) - 1])
print('Without any changes balance on the end of 2022 would be', clean_result)
print('------------------------------------')
# Out:
# Start weights: OrderedDict([('AAPL', 0.25899), ('AMD', 0.10384), ('AMZN', 0.0), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.25217), ('NVDA', 0.09699), ('TSLA', 0.288), ('VOO', 0.0)])
# Without any changes balance on the end of 2022 would be 56963.31775665283
# ------------------------------------

# %%
strategy = 'MACD_signal_'                 # MACD_signal_        or        RSI_signal_        or        S&R_signal_
strategy_weights = copy.deepcopy(initial_weights)
stocks_strategy = copy.deepcopy(stocks_initial)
balance_strategy = balance_remain

balance_buy_and_hold_dict = {}
balance_strategy_dict = {}

for d in data.index: 
    if d.weekday() == 4:                   # every Friday
        tickers_sell = []
        tickers_buy = []
        for t in strategy_weights:
            if data[strategy + t][d] == -1:
                tickers_sell.append(t)
            if data[strategy + t][d] == 1:
                tickers_buy.append(t)
        print(d, 'Sell candidates:', tickers_sell, 'Buy candidates:', tickers_buy)
        if len(tickers_sell) > 0 and len(tickers_buy) > 0:
            filtered_sell_tickers_with_percents = check_tickers_for_sell(tickers_sell, d, strategy_weights)
            print('Filtered sell candidates:', filtered_sell_tickers_with_percents)
            if len(filtered_sell_tickers_with_percents) > 0:
                ticker_for_sell_data = select_ticker_for_sell(data, d, filtered_sell_tickers_with_percents, stocks_strategy)
                will_receive_usd = ticker_for_sell_data[1]
                # If this ticker is present in current portfolio
                if will_receive_usd > 0:
                    ticker_for_sell = ticker_for_sell_data[0]
                    stocks_to_sell = ticker_for_sell_data[2]
                    sell_percents = filtered_sell_tickers_with_percents[ticker_for_sell]
                    ticker_for_buy = select_ticker_for_buy(tickers_buy, d)
                    # If we can buy other ticker on that money
                    if (will_receive_usd + balance_strategy) > data[ticker_for_buy][d]:
                        print('Will sell',ticker_for_sell,'and get',will_receive_usd,'$ after selling (',sell_percents,'% )')
                        print('Will buy', ticker_for_buy)
                        # Sell percent of ticker_for_sell and add that money to balance
                        stocks_strategy[ticker_for_sell] = stocks_strategy[ticker_for_sell] - stocks_to_sell
                        balance_strategy = balance_strategy + will_receive_usd
                        # Buy ticker_for_buy on all balance
                        no_of_buy_stocks = balance_strategy // data[ticker_for_buy][d]
                        stocks_strategy[ticker_for_buy] = stocks_strategy[ticker_for_buy] + no_of_buy_stocks
                        balance_strategy = balance_strategy - (data[ticker_for_buy][d] * no_of_buy_stocks)
                        # Recalculate new weights for all portfolio
                        # calculate all prices for now + balance - потом высчитать сколько в процентах сейчас каждый ФИ
                        cur_balance = balance_strategy
                        stock_usd = {}
                        for stock in stocks_strategy:
                            stock_usd[stock] = stocks_strategy[stock] * data[stock][d]
                            cur_balance = cur_balance + stock_usd[stock]
                        for stock in stocks_strategy:
                            strategy_weights[stock] = stock_usd[stock] / cur_balance
                        print('Current weights are', strategy_weights)
                        print('Current balance =', cur_balance)
                    else:
                        print("No changes because sell profit is not enough for buying at least one stock.")
                else:
                    print("No changes because all sell candidates are not present in current portfolio.")
            else:
                print("No changes because all sell candidates failed check.")
        else:
            print("No changes because no sell candidates or no buy candidates.")
        print('------------------------------------')
    # Calculate current balance for stocks_initial
    today_balance_buy_and_hold = balance_remain
    for stock in stocks_initial:
        today_balance_buy_and_hold = today_balance_buy_and_hold + (data[stock][d] * stocks_initial[stock])
    balance_buy_and_hold_dict[d] = today_balance_buy_and_hold
    # Calculate current balance for stocks_strategy
    today_balance_strategy = balance_strategy
    for stock in stocks_strategy:
        today_balance_strategy = today_balance_strategy + (data[stock][d] * stocks_strategy[stock])
    balance_strategy_dict[d] = today_balance_strategy

print('\nWith strategy final weights are:', strategy_weights)        
clean_result = balance_strategy
for stock in strategy_weights:
    clean_result = clean_result + (stocks_strategy[stock] * data[stock][len(data[stock]) - 1])
print('\nWith strategy balance on the end of 2022 would be', clean_result)
# Out:
# 2022-01-07 00:00:00 Sell candidates: ['AAPL', 'AMD', 'AMZN', 'GOOG', 'MSFT', 'NVDA', 'VOO'] Buy candidates: ['F', 'INTC', 'JPM', 'MS', 'TSLA']
# Filtered sell candidates: {'AMZN': 100, 'GOOG': 100, 'MSFT': 18.0, 'VOO': 100}
# Will sell MSFT and get 4183.012913818359 $ after selling ( 18.0 % )
# Will buy TSLA
# Current weights are OrderedDict([('AAPL', 0.26219554445500065), ('AMD', 0.0998174010451634), ('AMZN', 0.0), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.2001383812830141), ('NVDA', 0.09157322351724945), ('TSLA', 0.34514639855419005), ('VOO', 0.0)])
# Current balance = 95213.8595123291
# ------------------------------------
# 2022-01-14 00:00:00 Sell candidates: ['AAPL', 'AMD', 'AMZN', 'GOOG', 'MSFT', 'NVDA', 'TSLA', 'VOO'] Buy candidates: ['F', 'INTC', 'JPM', 'MS']
# Filtered sell candidates: {'AMZN': 100, 'GOOG': 100, 'MSFT': 5.0, 'NVDA': 21.0, 'TSLA': 16.0, 'VOO': 100}
# Will sell TSLA and get 5374.003125 $ after selling ( 16.0 % )
# Will buy MS
# Current weights are OrderedDict([('AAPL', 0.26116322941976955), ('AMD', 0.10256394672219551), ('AMZN', 0.0), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.056596992140631276), ('MSFT', 0.19588879677288093), ('NVDA', 0.08972264081230266), ('TSLA', 0.2936158080792692), ('VOO', 0.0)])
# Current balance = 96089.90943237304
# ------------------------------------
# 2022-01-21 00:00:00 Sell candidates: ['AAPL', 'AMD', 'AMZN', 'F', 'GOOG', 'INTC', 'JPM', 'MS', 'MSFT', 'NVDA', 'TSLA', 'VOO'] Buy candidates: []
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-01-28 00:00:00 Sell candidates: ['AAPL', 'AMD', 'AMZN', 'F', 'GOOG', 'INTC', 'JPM', 'MSFT', 'NVDA', 'TSLA', 'VOO'] Buy candidates: ['MS']
# Filtered sell candidates: {'AMZN': 100, 'F': 100, 'GOOG': 100, 'INTC': 100, 'JPM': 100, 'NVDA': 100, 'TSLA': 13.0, 'VOO': 100}
# Will sell NVDA and get 7308.7998046875 $ after selling ( 100 % )
# Will buy MS
# Current weights are OrderedDict([('AAPL', 0.28492761169050124), ('AMD', 0.08741555343792275), ('AMZN', 0.0), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.1491512496566316), ('MSFT', 0.21579339337331516), ('NVDA', 0.0), ('TSLA', 0.26245487891171865), ('VOO', 0.0)])
# Current balance = 86681.14023406983
# ------------------------------------
# 2022-02-04 00:00:00 Sell candidates: ['F', 'INTC'] Buy candidates: ['AAPL', 'AMD', 'AMZN', 'GOOG', 'JPM', 'MS', 'MSFT', 'NVDA', 'TSLA', 'VOO']
# Filtered sell candidates: {'F': 100, 'INTC': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2022-02-11 00:00:00 Sell candidates: ['F', 'GOOG', 'MSFT'] Buy candidates: ['AAPL', 'AMD', 'AMZN', 'INTC', 'JPM', 'MS', 'NVDA', 'TSLA', 'VOO']
# Filtered sell candidates: {'F': 100, 'GOOG': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2022-02-18 00:00:00 Sell candidates: ['AAPL', 'AMD', 'AMZN', 'F', 'GOOG', 'INTC', 'JPM', 'MS', 'MSFT', 'TSLA', 'VOO'] Buy candidates: ['NVDA']
# Filtered sell candidates: {'AAPL': 5.0, 'AMD': 35.0, 'AMZN': 100, 'F': 100, 'GOOG': 100, 'INTC': 100, 'JPM': 100, 'MS': 100, 'TSLA': 0.0, 'VOO': 100}
# Will sell MS and get 12118.339767456055 $ after selling ( 100 % )
# Will buy NVDA
# Current weights are OrderedDict([('AAPL', 0.2850516612143042), ('AMD', 0.09630500640511008), ('AMZN', 0.0), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.20530149102977371), ('NVDA', 0.14168178212356455), ('TSLA', 0.2706821277748662), ('VOO', 0.0)])
# Current balance = 85102.1191708374
# ------------------------------------
# 2022-02-25 00:00:00 Sell candidates: ['AAPL', 'AMD', 'AMZN', 'F', 'GOOG', 'INTC', 'JPM', 'MS', 'MSFT', 'NVDA', 'TSLA', 'VOO'] Buy candidates: []
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-03-04 00:00:00 Sell candidates: ['AAPL', 'AMD', 'AMZN', 'F', 'JPM', 'MS', 'NVDA'] Buy candidates: ['GOOG', 'INTC', 'MSFT', 'TSLA', 'VOO']
# Filtered sell candidates: {'AAPL': 36.0, 'AMD': 55.0, 'AMZN': 100, 'F': 100, 'JPM': 100, 'MS': 100}
# Will sell AAPL and get 8517.473904418945 $ after selling ( 36.0 % )
# Will buy TSLA
# Current weights are OrderedDict([('AAPL', 0.1816312213984831), ('AMD', 0.0936276394522634), ('AMZN', 0.0), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.2109774585928082), ('NVDA', 0.140310468814613), ('TSLA', 0.3708407109470554), ('VOO', 0.0)])
# Current balance = 83367.69258880615
# ------------------------------------
# 2022-03-11 00:00:00 Sell candidates: ['AAPL', 'AMD', 'AMZN', 'F', 'GOOG', 'INTC', 'JPM', 'MS', 'MSFT', 'NVDA', 'TSLA', 'VOO'] Buy candidates: []
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-03-18 00:00:00 Sell candidates: ['AAPL', 'F', 'INTC'] Buy candidates: ['AMD', 'AMZN', 'GOOG', 'JPM', 'MS', 'MSFT', 'NVDA', 'TSLA', 'VOO']
# Filtered sell candidates: {'AAPL': 17.0, 'F': 100, 'INTC': 100}
# Will sell AAPL and get 2586.948412597657 $ after selling ( 17.0 % )
# Will buy TSLA
# Current weights are OrderedDict([('AAPL', 0.1423685865909853), ('AMD', 0.0920815256472568), ('AMZN', 0.0), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.20548782408676552), ('NVDA', 0.15206957778125602), ('TSLA', 0.4069940588072505), ('VOO', 0.0)])
# Current balance = 88716.16620880127
# ------------------------------------
# 2022-03-25 00:00:00 Sell candidates: [] Buy candidates: ['AAPL', 'AMD', 'AMZN', 'F', 'GOOG', 'INTC', 'JPM', 'MS', 'MSFT', 'NVDA', 'TSLA', 'VOO']
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-04-01 00:00:00 Sell candidates: ['JPM', 'MS'] Buy candidates: ['AAPL', 'AMD', 'AMZN', 'F', 'GOOG', 'INTC', 'MSFT', 'NVDA', 'TSLA', 'VOO']
# Filtered sell candidates: {'JPM': 100, 'MS': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2022-04-08 00:00:00 Sell candidates: ['AAPL', 'AMD', 'AMZN', 'F', 'GOOG', 'INTC', 'JPM', 'MS', 'MSFT', 'NVDA', 'VOO'] Buy candidates: ['TSLA']
# Filtered sell candidates: {'AMD': 100, 'AMZN': 100, 'F': 100, 'GOOG': 100, 'INTC': 100, 'JPM': 100, 'MS': 100, 'VOO': 100}
# Will sell AMD and get 7272.0 $ after selling ( 100 % )
# Will buy TSLA
# Current weights are OrderedDict([('AAPL', 0.1437003578921263), ('AMD', 0.0), ('AMZN', 0.0), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.1976565279505341), ('NVDA', 0.12932790279671452), ('TSLA', 0.5273173064866052), ('VOO', 0.0)])
# Current balance = 91168.95789337158
# ------------------------------------
# 2022-04-22 00:00:00 Sell candidates: ['AAPL', 'AMD', 'AMZN', 'GOOG', 'JPM', 'MSFT', 'NVDA', 'TSLA', 'VOO'] Buy candidates: ['F', 'INTC', 'MS']
# Filtered sell candidates: {'AMZN': 100, 'GOOG': 100, 'JPM': 100, 'NVDA': 17.0, 'TSLA': 41.0, 'VOO': 100}
# Will sell TSLA and get 19317.86480537109 $ after selling ( 41.0 % )
# Will buy MS
# Current weights are OrderedDict([('AAPL', 0.14433068589819506), ('AMD', 0.0), ('AMZN', 0.0), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.22573413375364865), ('MSFT', 0.19258596356277777), ('NVDA', 0.11527089576675892), ('TSLA', 0.3219646767777586), ('VOO', 0.0)])
# Current balance = 86341.39279058838
# ------------------------------------
# 2022-04-29 00:00:00 Sell candidates: ['AAPL', 'AMD', 'AMZN', 'F', 'GOOG', 'INTC', 'JPM', 'MS', 'MSFT', 'NVDA', 'TSLA', 'VOO'] Buy candidates: []
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-05-06 00:00:00 Sell candidates: ['AAPL', 'AMZN', 'F', 'GOOG', 'INTC', 'JPM', 'TSLA', 'VOO'] Buy candidates: ['AMD', 'MS', 'MSFT', 'NVDA']
# Filtered sell candidates: {'AMZN': 100, 'F': 100, 'GOOG': 100, 'INTC': 100, 'JPM': 100, 'TSLA': 9.0, 'VOO': 100}
# Will sell TSLA and get 2154.8866920380856 $ after selling ( 9.0 % )
# Will buy AMD
# Current weights are OrderedDict([('AAPL', 0.14839615075027437), ('AMD', 0.02569335881250265), ('AMZN', 0.0), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.2373109206742031), ('MSFT', 0.20420893756872968), ('NVDA', 0.11666856516846187), ('TSLA', 0.2668986592694484), ('VOO', 0.0)])
# Current balance = 81635.1001338501
# ------------------------------------
# 2022-05-13 00:00:00 Sell candidates: ['AAPL', 'AMD', 'AMZN', 'F', 'GOOG', 'INTC', 'JPM', 'MS', 'MSFT', 'NVDA', 'TSLA', 'VOO'] Buy candidates: []
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-05-20 00:00:00 Sell candidates: ['AAPL', 'AMZN', 'F', 'GOOG', 'INTC', 'JPM', 'MS', 'MSFT', 'NVDA', 'TSLA', 'VOO'] Buy candidates: ['AMD']
# Filtered sell candidates: {'AAPL': 66.0, 'AMZN': 100, 'F': 100, 'GOOG': 100, 'INTC': 100, 'JPM': 100, 'MS': 100, 'NVDA': 100, 'VOO': 100}
# Will sell MS and get 18255.100631713867 $ after selling ( 100 % )
# Will buy AMD
# Current weights are OrderedDict([('AAPL', 0.14816488300068237), ('AMD', 0.28366365824963835), ('AMZN', 0.0), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.21426068622820768), ('NVDA', 0.1190317850039368), ('TSLA', 0.23362323660589338), ('VOO', 0.0)])
# Current balance = 71526.61051189086
# ------------------------------------
# 2022-05-27 00:00:00 Sell candidates: ['AMZN', 'F', 'GOOG', 'INTC', 'TSLA'] Buy candidates: ['AAPL', 'AMD', 'JPM', 'MS', 'MSFT', 'NVDA', 'VOO']
# Filtered sell candidates: {'AMZN': 100, 'F': 100, 'GOOG': 100, 'INTC': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2022-06-03 00:00:00 Sell candidates: [] Buy candidates: ['AAPL', 'AMD', 'AMZN', 'F', 'GOOG', 'INTC', 'JPM', 'MS', 'MSFT', 'NVDA', 'TSLA', 'VOO']
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-06-10 00:00:00 Sell candidates: ['AAPL', 'AMD', 'F', 'INTC', 'JPM', 'MS', 'MSFT', 'NVDA', 'TSLA', 'VOO'] Buy candidates: ['AMZN', 'GOOG']
# Filtered sell candidates: {'AMD': 27.0, 'F': 100, 'INTC': 100, 'JPM': 100, 'MS': 100, 'NVDA': 100, 'TSLA': 3.0, 'VOO': 100}
# Will sell NVDA and get 8656.740280151367 $ after selling ( 100 % )
# Will buy GOOG
# Current weights are OrderedDict([('AAPL', 0.14514271678139015), ('AMD', 0.28274593595188946), ('AMZN', 0.0), ('F', 0.0), ('GOOG', 0.11943281509871109), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.2109529604262659), ('NVDA', 0.0), ('TSLA', 0.24096682964163385), ('VOO', 0.0)])
# Current balance = 72771.83265077221
# ------------------------------------
# 2022-06-17 00:00:00 Sell candidates: ['AAPL', 'AMD', 'AMZN', 'F', 'GOOG', 'INTC', 'JPM', 'MS', 'MSFT', 'NVDA', 'TSLA', 'VOO'] Buy candidates: []
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-06-24 00:00:00 Sell candidates: ['AAPL', 'AMD', 'F', 'INTC', 'JPM', 'MS', 'NVDA', 'VOO'] Buy candidates: ['AMZN', 'GOOG', 'MSFT', 'TSLA']
# Filtered sell candidates: {'AMD': 68.0, 'F': 100, 'INTC': 100, 'JPM': 100, 'MS': 100, 'NVDA': 100, 'VOO': 100}
# Will sell AMD and get 12849.525070190432 $ after selling ( 68.0 % )
# Will buy TSLA
# Current weights are OrderedDict([('AAPL', 0.1476364340101306), ('AMD', 0.08181790805786514), ('AMZN', 0.0), ('F', 0.0), ('GOOG', 0.12510435697097688), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.21979316992046874), ('NVDA', 0.0), ('TSLA', 0.42391628897326583), ('VOO', 0.0)])
# Current balance = 73906.01239611083
# ------------------------------------
# 2022-07-01 00:00:00 Sell candidates: ['AMD', 'AMZN', 'F', 'INTC', 'JPM', 'NVDA'] Buy candidates: ['AAPL', 'GOOG', 'MS', 'MSFT', 'TSLA', 'VOO']
# Filtered sell candidates: {'AMZN': 100, 'F': 100, 'INTC': 100, 'JPM': 100, 'NVDA': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2022-07-08 00:00:00 Sell candidates: ['AMD', 'F', 'INTC', 'JPM', 'MS', 'NVDA'] Buy candidates: ['AAPL', 'AMZN', 'GOOG', 'MSFT', 'TSLA', 'VOO']
# Filtered sell candidates: {'AMD': 35.0, 'F': 100, 'INTC': 100, 'JPM': 100, 'MS': 100, 'NVDA': 100}
# Will sell AMD and get 1928.522362915039 $ after selling ( 35.0 % )
# Will buy TSLA
# Current weights are OrderedDict([('AAPL', 0.15191320165843183), ('AMD', 0.04804010694972942), ('AMZN', 0.0), ('F', 0.0), ('GOOG', 0.12572430021600264), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.21785273957643111), ('NVDA', 0.0), ('TSLA', 0.4557935002698581), ('VOO', 0.0)])
# Current balance = 74553.15482281835
# ------------------------------------
# 2022-07-15 00:00:00 Sell candidates: ['AMZN', 'GOOG', 'JPM', 'MS', 'MSFT', 'VOO'] Buy candidates: ['AAPL', 'AMD', 'F', 'INTC', 'NVDA', 'TSLA']
# Filtered sell candidates: {'AMZN': 100, 'GOOG': 100, 'JPM': 100, 'MS': 100, 'VOO': 100}
# Will sell GOOG and get 8795.825866699219 $ after selling ( 100 % )
# Will buy TSLA
# Current weights are OrderedDict([('AAPL', 0.16024119967912492), ('AMD', 0.05071803477665052), ('AMZN', 0.0), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.2158093327333106), ('NVDA', 0.0), ('TSLA', 0.5704075676659089), ('VOO', 0.0)])
# Current balance = 72183.02135859302
# ------------------------------------
# 2022-07-22 00:00:00 Sell candidates: ['GOOG'] Buy candidates: ['AAPL', 'AMD', 'AMZN', 'F', 'INTC', 'JPM', 'MS', 'MSFT', 'NVDA', 'TSLA', 'VOO']
# Filtered sell candidates: {'GOOG': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2022-07-29 00:00:00 Sell candidates: ['GOOG', 'INTC'] Buy candidates: ['AAPL', 'AMD', 'AMZN', 'F', 'JPM', 'MS', 'MSFT', 'NVDA', 'TSLA', 'VOO']
# Filtered sell candidates: {'GOOG': 100, 'INTC': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2022-08-05 00:00:00 Sell candidates: ['INTC', 'JPM'] Buy candidates: ['AAPL', 'AMD', 'AMZN', 'F', 'GOOG', 'MS', 'MSFT', 'NVDA', 'TSLA', 'VOO']
# Filtered sell candidates: {'INTC': 100, 'JPM': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2022-08-12 00:00:00 Sell candidates: ['INTC', 'NVDA', 'TSLA'] Buy candidates: ['AAPL', 'AMD', 'AMZN', 'F', 'GOOG', 'JPM', 'MS', 'MSFT', 'VOO']
# Filtered sell candidates: {'INTC': 100, 'NVDA': 100, 'TSLA': 56.0}
# Will sell TSLA and get 28816.496732305903 $ after selling ( 56.0 % )
# Will buy AMD
# Current weights are OrderedDict([('AAPL', 0.15204804298382663), ('AMD', 0.38413122079760936), ('AMZN', 0.0), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.2031741403383632), ('NVDA', 0.0), ('TSLA', 0.25970464159186557), ('VOO', 0.0)])
# Current balance = 87181.85785217382
# ------------------------------------
# 2022-08-19 00:00:00 Sell candidates: ['AMD'] Buy candidates: ['AAPL', 'AMZN', 'F', 'GOOG', 'INTC', 'JPM', 'MS', 'MSFT', 'NVDA', 'TSLA', 'VOO']
# Filtered sell candidates: {'AMD': 60.0}
# Will sell AMD and get 19121.06891184082 $ after selling ( 60.0 % )
# Will buy TSLA
# Current weights are OrderedDict([('AAPL', 0.15558456641714422), ('AMD', 0.15012277168824256), ('AMZN', 0.0), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.20448665914243552), ('NVDA', 0.0), ('TSLA', 0.4872560498946722), ('VOO', 0.0)])
# Current balance = 84913.02905752909
# ------------------------------------
# 2022-08-26 00:00:00 Sell candidates: ['AAPL', 'AMD', 'AMZN', 'F', 'GOOG', 'INTC', 'JPM', 'MS', 'MSFT', 'NVDA', 'TSLA', 'VOO'] Buy candidates: []
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-09-02 00:00:00 Sell candidates: ['AAPL', 'AMD', 'AMZN', 'F', 'GOOG', 'INTC', 'JPM', 'MS', 'MSFT', 'NVDA', 'TSLA', 'VOO'] Buy candidates: []
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-09-09 00:00:00 Sell candidates: ['AAPL', 'AMD', 'AMZN', 'F', 'GOOG', 'INTC', 'MSFT', 'NVDA', 'TSLA', 'VOO'] Buy candidates: ['JPM', 'MS']
# Filtered sell candidates: {'AMD': 6.0, 'AMZN': 100, 'F': 100, 'GOOG': 100, 'INTC': 100, 'NVDA': 100, 'TSLA': 31.0, 'VOO': 100}
# Will sell TSLA and get 12956.338318346203 $ after selling ( 31.0 % )
# Will buy MS
# Current weights are OrderedDict([('AAPL', 0.14866832951355508), ('AMD', 0.13923821771076572), ('AMZN', 0.0), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.1612934330607562), ('MSFT', 0.19682307533645857), ('NVDA', 0.0), ('TSLA', 0.3537041361543052), ('VOO', 0.0)])
# Current balance = 81532.2708176463
# ------------------------------------
# 2022-09-16 00:00:00 Sell candidates: ['AAPL', 'AMD', 'AMZN', 'F', 'GOOG', 'INTC', 'MSFT', 'NVDA', 'VOO'] Buy candidates: ['JPM', 'MS', 'TSLA']
# Filtered sell candidates: {'AMD': 9.0, 'AMZN': 100, 'F': 100, 'GOOG': 100, 'INTC': 100, 'MSFT': 35.0, 'NVDA': 100, 'VOO': 100}
# Will sell MSFT and get 5197.788236663819 $ after selling ( 35.0 % )
# Will buy TSLA
# Current weights are OrderedDict([('AAPL', 0.14751138989468496), ('AMD', 0.12917557381600603), ('AMZN', 0.0), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.1633292837730638), ('MSFT', 0.12267332511191295), ('NVDA', 0.0), ('TSLA', 0.43650877982950287), ('VOO', 0.0)])
# Current balance = 78688.95122762071
# ------------------------------------
# 2022-09-23 00:00:00 Sell candidates: ['AAPL', 'AMD', 'AMZN', 'F', 'GOOG', 'INTC', 'JPM', 'MS', 'MSFT', 'NVDA', 'TSLA', 'VOO'] Buy candidates: []
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-09-30 00:00:00 Sell candidates: ['AAPL', 'AMD', 'AMZN', 'F', 'GOOG', 'INTC', 'JPM', 'MS', 'MSFT', 'NVDA', 'TSLA', 'VOO'] Buy candidates: []
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-10-07 00:00:00 Sell candidates: ['AAPL', 'AMD', 'TSLA'] Buy candidates: ['AMZN', 'F', 'GOOG', 'INTC', 'JPM', 'MS', 'MSFT', 'NVDA', 'VOO']
# Filtered sell candidates: {'AMD': 53.0, 'TSLA': 30.0}
# Will sell TSLA and get 7577.486454542297 $ after selling ( 30.0 % )
# Will buy MSFT
# Current weights are OrderedDict([('AAPL', 0.16672969750711714), ('AMD', 0.11996813546586671), ('AMZN', 0.0), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.17928304052638927), ('MSFT', 0.2585797095449863), ('NVDA', 0.0), ('TSLA', 0.2732006471205743), ('VOO', 0.0)])
# Current balance = 64717.27616172929
# ------------------------------------
# 2022-10-14 00:00:00 Sell candidates: ['AAPL', 'AMD', 'AMZN', 'F', 'GOOG', 'INTC', 'JPM', 'MS', 'MSFT', 'NVDA', 'TSLA', 'VOO'] Buy candidates: []
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-10-21 00:00:00 Sell candidates: ['AMD', 'MS', 'TSLA'] Buy candidates: ['AAPL', 'AMZN', 'F', 'GOOG', 'INTC', 'JPM', 'MSFT', 'NVDA', 'VOO']
# Filtered sell candidates: {'AMD': 100, 'MS': 100}
# Will sell MS and get 11645.34017944336 $ after selling ( 100 % )
# Will buy AAPL
# Current weights are OrderedDict([('AAPL', 0.35444647640636384), ('AMD', 0.11977640885734804), ('AMZN', 0.0), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.2651273848754136), ('NVDA', 0.0), ('TSLA', 0.2605175009972208), ('VOO', 0.0)])
# Current balance = 65242.36151346803
# ------------------------------------
# 2022-10-28 00:00:00 Sell candidates: ['AMZN', 'GOOG'] Buy candidates: ['AAPL', 'AMD', 'F', 'INTC', 'JPM', 'MS', 'MSFT', 'NVDA', 'TSLA', 'VOO']
# Filtered sell candidates: {'AMZN': 100, 'GOOG': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2022-11-04 00:00:00 Sell candidates: ['AAPL', 'AMZN', 'GOOG', 'MSFT', 'TSLA', 'VOO'] Buy candidates: ['AMD', 'F', 'INTC', 'JPM', 'MS', 'NVDA']
# Filtered sell candidates: {'AMZN': 100, 'GOOG': 100, 'MSFT': 100, 'VOO': 100}
# Will sell MSFT and get 15816.544336395265 $ after selling ( 100 % )
# Will buy AMD
# Current weights are OrderedDict([('AAPL', 0.3489999934399813), ('AMD', 0.38641513546297407), ('AMZN', 0.0), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.0), ('NVDA', 0.0), ('TSLA', 0.2641205073619155), ('VOO', 0.0)])
# Current balance = 62260.69425544432
# ------------------------------------
# 2022-11-11 00:00:00 Sell candidates: ['AAPL', 'AMZN', 'TSLA'] Buy candidates: ['AMD', 'F', 'GOOG', 'INTC', 'JPM', 'MS', 'MSFT', 'NVDA', 'VOO']
# Filtered sell candidates: {'AMZN': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2022-11-18 00:00:00 Sell candidates: ['TSLA'] Buy candidates: ['AAPL', 'AMD', 'AMZN', 'F', 'GOOG', 'INTC', 'JPM', 'MS', 'MSFT', 'NVDA', 'VOO']
# Filtered sell candidates: {}
# No changes because all sell candidates failed check.
# ------------------------------------
# 2022-11-25 00:00:00 Sell candidates: ['AMZN', 'INTC', 'TSLA'] Buy candidates: ['AAPL', 'AMD', 'F', 'GOOG', 'JPM', 'MS', 'MSFT', 'NVDA', 'VOO']
# Filtered sell candidates: {'AMZN': 100, 'INTC': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2022-12-02 00:00:00 Sell candidates: ['AAPL', 'F', 'INTC'] Buy candidates: ['AMD', 'AMZN', 'GOOG', 'JPM', 'MS', 'MSFT', 'NVDA', 'TSLA', 'VOO']
# Filtered sell candidates: {'AAPL': 6.0, 'F': 100, 'INTC': 100}
# Will sell AAPL and get 1392.5830233984375 $ after selling ( 6.0 % )
# Will buy TSLA
# Current weights are OrderedDict([('AAPL', 0.32231043988320085), ('AMD', 0.4285185922079169), ('AMZN', 0.0), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.0), ('NVDA', 0.0), ('TSLA', 0.24832187964203228), ('VOO', 0.0)])
# Current balance = 67689.81495339805
# ------------------------------------
# 2022-12-09 00:00:00 Sell candidates: ['AAPL', 'AMD', 'AMZN', 'F', 'GOOG', 'INTC', 'JPM', 'MS', 'MSFT', 'TSLA', 'VOO'] Buy candidates: ['NVDA']
# Filtered sell candidates: {'AMD': 24.0, 'AMZN': 100, 'F': 100, 'GOOG': 100, 'INTC': 100, 'JPM': 100, 'MS': 100, 'VOO': 100}
# Will sell AMD and get 6368.2420510312495 $ after selling ( 24.0 % )
# Will buy NVDA
# Current weights are OrderedDict([('AAPL', 0.33296028860385385), ('AMD', 0.3199948848740803), ('AMZN', 0.0), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.0), ('NVDA', 0.09981534238494658), ('TSLA', 0.24508180509786803), ('VOO', 0.0)])
# Current balance = 63020.069324549026
# ------------------------------------
# 2022-12-16 00:00:00 Sell candidates: ['AAPL', 'AMD', 'AMZN', 'F', 'GOOG', 'INTC', 'JPM', 'TSLA', 'VOO'] Buy candidates: ['MS', 'MSFT', 'NVDA']
# Filtered sell candidates: {'AAPL': 19.0, 'AMZN': 100, 'F': 100, 'GOOG': 100, 'INTC': 100, 'JPM': 100, 'TSLA': 0.0, 'VOO': 100}
# Will sell AAPL and get 3772.2637116110354 $ after selling ( 19.0 % )
# Will buy NVDA
# Current weights are OrderedDict([('AAPL', 0.27579372024985305), ('AMD', 0.3298042257900544), ('AMZN', 0.0), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.0), ('NVDA', 0.17051040845313914), ('TSLA', 0.22224048621889955), ('VOO', 0.0)])
# Current balance = 58310.8121846094
# ------------------------------------
# 2022-12-23 00:00:00 Sell candidates: ['AAPL', 'AMD', 'AMZN', 'F', 'GOOG', 'INTC', 'JPM', 'MS', 'MSFT', 'NVDA', 'TSLA', 'VOO'] Buy candidates: []
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-12-30 00:00:00 Sell candidates: ['AAPL', 'AMD', 'AMZN', 'F', 'GOOG', 'INTC', 'MS', 'MSFT', 'NVDA', 'TSLA', 'VOO'] Buy candidates: ['JPM']
# Filtered sell candidates: {'AMZN': 100, 'F': 100, 'GOOG': 100, 'INTC': 100, 'MS': 100, 'NVDA': 100, 'TSLA': 15.0, 'VOO': 100}
# Will sell NVDA and get 8768.399963378906 $ after selling ( 100 % )
# Will buy JPM
# Current weights are OrderedDict([('AAPL', 0.28731084495189574), ('AMD', 0.3522075847639079), ('AMZN', 0.0), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.16369538276873422), ('MS', 0.0), ('MSFT', 0.0), ('NVDA', 0.0), ('TSLA', 0.1965257723083566), ('VOO', 0.0)])
# Current balance = 54067.50180202697
# ------------------------------------
#
# With strategy final weights are: OrderedDict([('AAPL', 0.28731084495189574), ('AMD', 0.3522075847639079), ('AMZN', 0.0), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.16369538276873422), ('MS', 0.0), ('MSFT', 0.0), ('NVDA', 0.0), ('TSLA', 0.1965257723083566), ('VOO', 0.0)])
#
# With strategy balance on the end of 2022 would be 54067.50180202697

# %%
high_buy_and_hold = 0
low_buy_and_hold = 1_000_000_000
high_strategy = 0
low_strategy = 1_000_000_000
biggest_delta = 0
biggest_delta_day = ''
final_delta_usd = 0
final_delta_percent = 0

for d in balance_buy_and_hold_dict:
    if balance_buy_and_hold_dict[d] > high_buy_and_hold:
        high_buy_and_hold = balance_buy_and_hold_dict[d]
    if balance_buy_and_hold_dict[d] < low_buy_and_hold:
        low_buy_and_hold = balance_buy_and_hold_dict[d]
    if balance_strategy_dict[d] > high_strategy:
        high_strategy = balance_strategy_dict[d]
    if balance_strategy_dict[d] < low_strategy:
        low_strategy = balance_strategy_dict[d]
    delta = balance_strategy_dict[d] - balance_buy_and_hold_dict[d]
    delta_abs = abs(delta)
    percent = delta_abs / balance_buy_and_hold_dict[d]
    percent_change = percent
    if delta < 0:
        percent_change = -1 * percent_change
    if percent > abs(biggest_delta):
        biggest_delta = percent_change
        biggest_delta_day = d
    final_delta_usd = balance_strategy_dict[d] - balance_buy_and_hold_dict[d]
    final_delta_percent = percent_change
    print(d.strftime('%Y-%m-%d'), '\tBuy and hold balance:\t', "{:.2f}".format(balance_buy_and_hold_dict[d]), 
          '\tStrategy balance:\t', "{:.2f}".format(balance_strategy_dict[d]), 
          '\tDelta:\t', "{:.6f}".format(percent_change))

print('\nhigh_buy_and_hold', high_buy_and_hold)
print('low_buy_and_hold', low_buy_and_hold)
print('\nhigh_strategy', high_strategy)
print('low_strategy', low_strategy)
print('\nbiggest_delta', biggest_delta)
print('biggest_delta_day', biggest_delta_day)
print('\nfinal_delta_usd', final_delta_usd)
print('final_delta_percent', final_delta_percent)
# Out:
# 2022-01-03 	Buy and hold balance:	 105072.30 	Strategy balance:	 105072.30 	Delta:	 0.000000
# 2022-01-04 	Buy and hold balance:	 102272.50 	Strategy balance:	 102272.50 	Delta:	 0.000000
# 2022-01-05 	Buy and hold balance:	 97850.13 	Strategy balance:	 97850.13 	Delta:	 0.000000
# 2022-01-06 	Buy and hold balance:	 96798.83 	Strategy balance:	 96798.83 	Delta:	 0.000000
# 2022-01-07 	Buy and hold balance:	 95213.86 	Strategy balance:	 95213.86 	Delta:	 0.000000
# 2022-01-10 	Buy and hold balance:	 96124.06 	Strategy balance:	 96276.79 	Delta:	 0.001589
# 2022-01-11 	Buy and hold balance:	 97280.97 	Strategy balance:	 97455.65 	Delta:	 0.001796
# 2022-01-12 	Buy and hold balance:	 98788.58 	Strategy balance:	 99128.53 	Delta:	 0.003441
# 2022-01-13 	Buy and hold balance:	 94495.44 	Strategy balance:	 94641.52 	Delta:	 0.001546
# 2022-01-14 	Buy and hold balance:	 95925.51 	Strategy balance:	 96089.91 	Delta:	 0.001714
# 2022-01-18 	Buy and hold balance:	 93688.08 	Strategy balance:	 93687.48 	Delta:	 -0.000006
# 2022-01-19 	Buy and hold balance:	 91748.49 	Strategy balance:	 91837.62 	Delta:	 0.000971
# 2022-01-20 	Buy and hold balance:	 90635.01 	Strategy balance:	 90972.61 	Delta:	 0.003725
# 2022-01-21 	Buy and hold balance:	 88034.26 	Strategy balance:	 88398.99 	Delta:	 0.004143
# 2022-01-24 	Buy and hold balance:	 87404.77 	Strategy balance:	 87723.74 	Delta:	 0.003649
# 2022-01-25 	Buy and hold balance:	 85517.49 	Strategy balance:	 85995.61 	Delta:	 0.005591
# 2022-01-26 	Buy and hold balance:	 86739.11 	Strategy balance:	 87167.61 	Delta:	 0.004940
# 2022-01-27 	Buy and hold balance:	 83129.33 	Strategy balance:	 83583.03 	Delta:	 0.005458
# 2022-01-28 	Buy and hold balance:	 86305.91 	Strategy balance:	 86681.14 	Delta:	 0.004348
# 2022-01-31 	Buy and hold balance:	 90767.87 	Strategy balance:	 90663.28 	Delta:	 -0.001152
# 2022-02-01 	Buy and hold balance:	 90662.05 	Strategy balance:	 90718.12 	Delta:	 0.000618
# 2022-02-02 	Buy and hold balance:	 91121.11 	Strategy balance:	 90920.56 	Delta:	 -0.002201
# 2022-02-03 	Buy and hold balance:	 88792.19 	Strategy balance:	 88963.09 	Delta:	 0.001925
# 2022-02-04 	Buy and hold balance:	 90306.32 	Strategy balance:	 90523.31 	Delta:	 0.002403
# 2022-02-07 	Buy and hold balance:	 89535.67 	Strategy balance:	 89826.05 	Delta:	 0.003243
# 2022-02-08 	Buy and hold balance:	 91108.20 	Strategy balance:	 91375.73 	Delta:	 0.002936
# 2022-02-09 	Buy and hold balance:	 92924.23 	Strategy balance:	 92893.20 	Delta:	 -0.000334
# 2022-02-10 	Buy and hold balance:	 90134.78 	Strategy balance:	 90359.26 	Delta:	 0.002490
# 2022-02-11 	Buy and hold balance:	 86377.69 	Strategy balance:	 86924.28 	Delta:	 0.006328
# 2022-02-14 	Buy and hold balance:	 87015.29 	Strategy balance:	 87204.76 	Delta:	 0.002177
# 2022-02-15 	Buy and hold balance:	 90478.47 	Strategy balance:	 89985.74 	Delta:	 -0.005446
# 2022-02-16 	Buy and hold balance:	 90130.77 	Strategy balance:	 89356.17 	Delta:	 -0.008594
# 2022-02-17 	Buy and hold balance:	 86655.24 	Strategy balance:	 86009.38 	Delta:	 -0.007453
# 2022-02-18 	Buy and hold balance:	 85524.27 	Strategy balance:	 85102.12 	Delta:	 -0.004936
# 2022-02-22 	Buy and hold balance:	 84169.88 	Strategy balance:	 83706.90 	Delta:	 -0.005501
# 2022-02-23 	Buy and hold balance:	 80705.06 	Strategy balance:	 80157.64 	Delta:	 -0.006783
# 2022-02-24 	Buy and hold balance:	 84072.32 	Strategy balance:	 83588.34 	Delta:	 -0.005757
# 2022-02-25 	Buy and hold balance:	 85276.53 	Strategy balance:	 84832.94 	Delta:	 -0.005202
# 2022-02-28 	Buy and hold balance:	 87297.44 	Strategy balance:	 86870.19 	Delta:	 -0.004894
# 2022-03-01 	Buy and hold balance:	 85595.98 	Strategy balance:	 85048.09 	Delta:	 -0.006401
# 2022-03-02 	Buy and hold balance:	 87448.14 	Strategy balance:	 86969.76 	Delta:	 -0.005470
# 2022-03-03 	Buy and hold balance:	 85372.59 	Strategy balance:	 84859.82 	Delta:	 -0.006006
# 2022-03-04 	Buy and hold balance:	 83947.45 	Strategy balance:	 83367.69 	Delta:	 -0.006906
# 2022-03-07 	Buy and hold balance:	 80765.83 	Strategy balance:	 79899.93 	Delta:	 -0.010721
# 2022-03-08 	Buy and hold balance:	 81042.43 	Strategy balance:	 80540.98 	Delta:	 -0.006187
# 2022-03-09 	Buy and hold balance:	 84588.31 	Strategy balance:	 84257.29 	Delta:	 -0.003913
# 2022-03-10 	Buy and hold balance:	 82728.13 	Strategy balance:	 82395.26 	Delta:	 -0.004024
# 2022-03-11 	Buy and hold balance:	 80275.65 	Strategy balance:	 79683.78 	Delta:	 -0.007373
# 2022-03-14 	Buy and hold balance:	 78235.34 	Strategy balance:	 77473.74 	Delta:	 -0.009735
# 2022-03-15 	Buy and hold balance:	 81670.59 	Strategy balance:	 81196.10 	Delta:	 -0.005810
# 2022-03-16 	Buy and hold balance:	 84816.27 	Strategy balance:	 84678.62 	Delta:	 -0.001623
# 2022-03-17 	Buy and hold balance:	 85695.47 	Strategy balance:	 85854.23 	Delta:	 0.001853
# 2022-03-18 	Buy and hold balance:	 88147.82 	Strategy balance:	 88716.17 	Delta:	 0.006448
# 2022-03-21 	Buy and hold balance:	 88949.67 	Strategy balance:	 89696.28 	Delta:	 0.008394
# 2022-03-22 	Buy and hold balance:	 91627.93 	Strategy balance:	 92973.45 	Delta:	 0.014685
# 2022-03-23 	Buy and hold balance:	 91283.09 	Strategy balance:	 92491.97 	Delta:	 0.013243
# 2022-03-24 	Buy and hold balance:	 93864.84 	Strategy balance:	 95418.72 	Delta:	 0.016554
# 2022-03-25 	Buy and hold balance:	 93630.97 	Strategy balance:	 95017.00 	Delta:	 0.014803
# 2022-03-28 	Buy and hold balance:	 96680.13 	Strategy balance:	 99058.82 	Delta:	 0.024604
# 2022-03-29 	Buy and hold balance:	 98079.70 	Strategy balance:	 100349.84 	Delta:	 0.023146
# 2022-03-30 	Buy and hold balance:	 97043.95 	Strategy balance:	 99160.22 	Delta:	 0.021807
# 2022-03-31 	Buy and hold balance:	 94891.88 	Strategy balance:	 97009.02 	Delta:	 0.022311
# 2022-04-01 	Buy and hold balance:	 94852.77 	Strategy balance:	 96956.49 	Delta:	 0.022179
# 2022-04-04 	Buy and hold balance:	 97881.38 	Strategy balance:	 100537.43 	Delta:	 0.027135
# 2022-04-05 	Buy and hold balance:	 94901.09 	Strategy balance:	 96871.89 	Delta:	 0.020767
# 2022-04-06 	Buy and hold balance:	 91647.64 	Strategy balance:	 93113.99 	Delta:	 0.016000
# 2022-04-07 	Buy and hold balance:	 92081.39 	Strategy balance:	 93612.07 	Delta:	 0.016623
# 2022-04-08 	Buy and hold balance:	 90056.43 	Strategy balance:	 91168.96 	Delta:	 0.012354
# 2022-04-11 	Buy and hold balance:	 86576.47 	Strategy balance:	 87187.72 	Delta:	 0.007060
# 2022-04-12 	Buy and hold balance:	 86618.56 	Strategy balance:	 87446.65 	Delta:	 0.009560
# 2022-04-13 	Buy and hold balance:	 88797.40 	Strategy balance:	 90012.05 	Delta:	 0.013679
# 2022-04-14 	Buy and hold balance:	 85831.64 	Strategy balance:	 86911.91 	Delta:	 0.012586
# 2022-04-18 	Buy and hold balance:	 86599.39 	Strategy balance:	 88108.90 	Delta:	 0.017431
# 2022-04-19 	Buy and hold balance:	 88286.86 	Strategy balance:	 89908.62 	Delta:	 0.018369
# 2022-04-20 	Buy and hold balance:	 86526.36 	Strategy balance:	 87206.15 	Delta:	 0.007856
# 2022-04-21 	Buy and hold balance:	 86134.95 	Strategy balance:	 87624.97 	Delta:	 0.017299
# 2022-04-22 	Buy and hold balance:	 84524.29 	Strategy balance:	 86341.39 	Delta:	 0.021498
# 2022-04-25 	Buy and hold balance:	 85295.03 	Strategy balance:	 86905.53 	Delta:	 0.018881
# 2022-04-26 	Buy and hold balance:	 79598.59 	Strategy balance:	 81252.18 	Delta:	 0.020774
# 2022-04-27 	Buy and hold balance:	 80527.31 	Strategy balance:	 81937.06 	Delta:	 0.017506
# 2022-04-28 	Buy and hold balance:	 82696.80 	Strategy balance:	 83730.81 	Delta:	 0.012504
# 2022-04-29 	Buy and hold balance:	 80058.02 	Strategy balance:	 81071.75 	Delta:	 0.012663
# 2022-05-02 	Buy and hold balance:	 82112.69 	Strategy balance:	 83225.39 	Delta:	 0.013551
# 2022-05-03 	Buy and hold balance:	 82419.36 	Strategy balance:	 83800.66 	Delta:	 0.016759
# 2022-05-04 	Buy and hold balance:	 85976.57 	Strategy balance:	 87172.97 	Delta:	 0.013915
# 2022-05-05 	Buy and hold balance:	 80682.12 	Strategy balance:	 82215.33 	Delta:	 0.019003
# 2022-05-06 	Buy and hold balance:	 80407.94 	Strategy balance:	 81635.10 	Delta:	 0.015262
# 2022-05-09 	Buy and hold balance:	 75580.80 	Strategy balance:	 76854.58 	Delta:	 0.016853
# 2022-05-10 	Buy and hold balance:	 77026.28 	Strategy balance:	 77843.67 	Delta:	 0.010612
# 2022-05-11 	Buy and hold balance:	 73052.33 	Strategy balance:	 74196.33 	Delta:	 0.015660
# 2022-05-12 	Buy and hold balance:	 71726.71 	Strategy balance:	 73106.33 	Delta:	 0.019234
# 2022-05-13 	Buy and hold balance:	 75006.61 	Strategy balance:	 76260.36 	Delta:	 0.016715
# 2022-05-16 	Buy and hold balance:	 73381.34 	Strategy balance:	 74632.33 	Delta:	 0.017048
# 2022-05-17 	Buy and hold balance:	 76201.72 	Strategy balance:	 77521.06 	Delta:	 0.017314
# 2022-05-18 	Buy and hold balance:	 71797.30 	Strategy balance:	 73512.38 	Delta:	 0.023888
# 2022-05-19 	Buy and hold balance:	 71301.66 	Strategy balance:	 73113.79 	Delta:	 0.025415
# 2022-05-20 	Buy and hold balance:	 69698.66 	Strategy balance:	 71526.61 	Delta:	 0.026227
# 2022-05-23 	Buy and hold balance:	 71573.04 	Strategy balance:	 73164.28 	Delta:	 0.022232
# 2022-05-24 	Buy and hold balance:	 69316.49 	Strategy balance:	 70485.62 	Delta:	 0.016867
# 2022-05-25 	Buy and hold balance:	 70751.57 	Strategy balance:	 72187.16 	Delta:	 0.020291
# 2022-05-26 	Buy and hold balance:	 73515.02 	Strategy balance:	 75645.38 	Delta:	 0.028979
# 2022-05-27 	Buy and hold balance:	 76869.10 	Strategy balance:	 79099.71 	Delta:	 0.029018
# 2022-05-31 	Buy and hold balance:	 76541.45 	Strategy balance:	 78762.79 	Delta:	 0.029021
# 2022-06-01 	Buy and hold balance:	 75921.55 	Strategy balance:	 78017.46 	Delta:	 0.027606
# 2022-06-02 	Buy and hold balance:	 78316.58 	Strategy balance:	 81460.73 	Delta:	 0.040147
# 2022-06-03 	Buy and hold balance:	 74760.72 	Strategy balance:	 77994.95 	Delta:	 0.043261
# 2022-06-06 	Buy and hold balance:	 75056.09 	Strategy balance:	 78153.20 	Delta:	 0.041264
# 2022-06-07 	Buy and hold balance:	 75773.54 	Strategy balance:	 78615.62 	Delta:	 0.037508
# 2022-06-08 	Buy and hold balance:	 75419.19 	Strategy balance:	 77780.81 	Delta:	 0.031313
# 2022-06-09 	Buy and hold balance:	 73641.75 	Strategy balance:	 75888.22 	Delta:	 0.030505
# 2022-06-10 	Buy and hold balance:	 70733.75 	Strategy balance:	 72771.83 	Delta:	 0.028813
# 2022-06-13 	Buy and hold balance:	 66854.12 	Strategy balance:	 68416.87 	Delta:	 0.023375
# 2022-06-14 	Buy and hold balance:	 67624.64 	Strategy balance:	 69033.85 	Delta:	 0.020839
# 2022-06-15 	Buy and hold balance:	 69918.12 	Strategy balance:	 71345.67 	Delta:	 0.020418
# 2022-06-16 	Buy and hold balance:	 66206.79 	Strategy balance:	 67151.29 	Delta:	 0.014266
# 2022-06-17 	Buy and hold balance:	 66973.79 	Strategy balance:	 67697.56 	Delta:	 0.010807
# 2022-06-21 	Buy and hold balance:	 70071.17 	Strategy balance:	 70735.56 	Delta:	 0.009482
# 2022-06-22 	Buy and hold balance:	 69804.88 	Strategy balance:	 70579.56 	Delta:	 0.011098
# 2022-06-23 	Buy and hold balance:	 70431.71 	Strategy balance:	 70839.69 	Delta:	 0.005793
# 2022-06-24 	Buy and hold balance:	 73062.11 	Strategy balance:	 73906.01 	Delta:	 0.011550
# 2022-06-27 	Buy and hold balance:	 72641.97 	Strategy balance:	 73421.90 	Delta:	 0.010737
# 2022-06-28 	Buy and hold balance:	 69743.74 	Strategy balance:	 70334.13 	Delta:	 0.008465
# 2022-06-29 	Buy and hold balance:	 69603.29 	Strategy balance:	 69950.93 	Delta:	 0.004995
# 2022-06-30 	Buy and hold balance:	 68428.17 	Strategy balance:	 68706.80 	Delta:	 0.004072
# 2022-07-01 	Buy and hold balance:	 68772.99 	Strategy balance:	 69182.47 	Delta:	 0.005954
# 2022-07-05 	Buy and hold balance:	 70117.67 	Strategy balance:	 70804.56 	Delta:	 0.009796
# 2022-07-06 	Buy and hold balance:	 70519.43 	Strategy balance:	 71057.07 	Delta:	 0.007624
# 2022-07-07 	Buy and hold balance:	 72733.81 	Strategy balance:	 73681.05 	Delta:	 0.013023
# 2022-07-08 	Buy and hold balance:	 73280.12 	Strategy balance:	 74553.15 	Delta:	 0.017372
# 2022-07-11 	Buy and hold balance:	 71010.03 	Strategy balance:	 71577.09 	Delta:	 0.007986
# 2022-07-12 	Buy and hold balance:	 70183.40 	Strategy balance:	 70665.90 	Delta:	 0.006875
# 2022-07-13 	Buy and hold balance:	 70490.78 	Strategy balance:	 70962.41 	Delta:	 0.006691
# 2022-07-14 	Buy and hold balance:	 71270.98 	Strategy balance:	 71437.50 	Delta:	 0.002336
# 2022-07-15 	Buy and hold balance:	 72160.38 	Strategy balance:	 72183.02 	Delta:	 0.000314
# 2022-07-18 	Buy and hold balance:	 71698.50 	Strategy balance:	 71891.14 	Delta:	 0.002687
# 2022-07-19 	Buy and hold balance:	 73668.24 	Strategy balance:	 73569.77 	Delta:	 -0.001337
# 2022-07-20 	Buy and hold balance:	 74842.77 	Strategy balance:	 74391.27 	Delta:	 -0.006033
# 2022-07-21 	Buy and hold balance:	 77525.92 	Strategy balance:	 78951.75 	Delta:	 0.018392
# 2022-07-22 	Buy and hold balance:	 76605.97 	Strategy balance:	 78539.94 	Delta:	 0.025246
# 2022-07-25 	Buy and hold balance:	 75884.12 	Strategy balance:	 77680.56 	Delta:	 0.023674
# 2022-07-26 	Buy and hold balance:	 74078.11 	Strategy balance:	 75410.79 	Delta:	 0.017990
# 2022-07-27 	Buy and hold balance:	 78100.86 	Strategy balance:	 79775.96 	Delta:	 0.021448
# 2022-07-28 	Buy and hold balance:	 79437.40 	Strategy balance:	 81410.79 	Delta:	 0.024842
# 2022-07-29 	Buy and hold balance:	 82081.15 	Strategy balance:	 84984.39 	Delta:	 0.035370
# 2022-08-01 	Buy and hold balance:	 81999.67 	Strategy balance:	 84867.70 	Delta:	 0.034976
# 2022-08-02 	Buy and hold balance:	 82022.14 	Strategy balance:	 85239.58 	Delta:	 0.039227
# 2022-08-03 	Buy and hold balance:	 84058.29 	Strategy balance:	 87288.99 	Delta:	 0.038434
# 2022-08-04 	Buy and hold balance:	 84721.46 	Strategy balance:	 87810.73 	Delta:	 0.036464
# 2022-08-05 	Buy and hold balance:	 82754.95 	Strategy balance:	 84148.53 	Delta:	 0.016840
# 2022-08-08 	Buy and hold balance:	 82132.21 	Strategy balance:	 84239.75 	Delta:	 0.025660
# 2022-08-09 	Buy and hold balance:	 81159.29 	Strategy balance:	 82943.28 	Delta:	 0.021981
# 2022-08-10 	Buy and hold balance:	 83762.46 	Strategy balance:	 85741.32 	Delta:	 0.023625
# 2022-08-11 	Buy and hold balance:	 82752.93 	Strategy balance:	 84186.53 	Delta:	 0.017324
# 2022-08-12 	Buy and hold balance:	 85164.20 	Strategy balance:	 87181.86 	Delta:	 0.023691
# 2022-08-15 	Buy and hold balance:	 86306.50 	Strategy balance:	 88121.32 	Delta:	 0.021028
# 2022-08-16 	Buy and hold balance:	 85896.49 	Strategy balance:	 87585.82 	Delta:	 0.019667
# 2022-08-17 	Buy and hold balance:	 85493.09 	Strategy balance:	 86783.84 	Delta:	 0.015098
# 2022-08-18 	Buy and hold balance:	 85555.13 	Strategy balance:	 87318.96 	Delta:	 0.020616
# 2022-08-19 	Buy and hold balance:	 83754.87 	Strategy balance:	 84913.03 	Delta:	 0.013828
# 2022-08-22 	Buy and hold balance:	 81528.78 	Strategy balance:	 82744.05 	Delta:	 0.014906
# 2022-08-23 	Buy and hold balance:	 81934.12 	Strategy balance:	 83503.97 	Delta:	 0.019160
# 2022-08-24 	Buy and hold balance:	 82012.03 	Strategy balance:	 83609.24 	Delta:	 0.019475
# 2022-08-25 	Buy and hold balance:	 83059.33 	Strategy balance:	 84435.50 	Delta:	 0.016569
# 2022-08-26 	Buy and hold balance:	 79726.30 	Strategy balance:	 81378.81 	Delta:	 0.020727
# 2022-08-29 	Buy and hold balance:	 78584.43 	Strategy balance:	 80219.30 	Delta:	 0.020804
# 2022-08-30 	Buy and hold balance:	 77264.16 	Strategy balance:	 78693.01 	Delta:	 0.018493
# 2022-08-31 	Buy and hold balance:	 76470.10 	Strategy balance:	 77905.33 	Delta:	 0.018768
# 2022-09-01 	Buy and hold balance:	 76070.65 	Strategy balance:	 77776.12 	Delta:	 0.022420
# 2022-09-02 	Buy and hold balance:	 74631.51 	Strategy balance:	 76100.22 	Delta:	 0.019680
# 2022-09-06 	Buy and hold balance:	 74411.30 	Strategy balance:	 76216.33 	Delta:	 0.024257
# 2022-09-07 	Buy and hold balance:	 75872.25 	Strategy balance:	 78032.63 	Delta:	 0.028474
# 2022-09-08 	Buy and hold balance:	 76453.49 	Strategy balance:	 79139.76 	Delta:	 0.035136
# 2022-09-09 	Buy and hold balance:	 78478.30 	Strategy balance:	 81532.27 	Delta:	 0.038915
# 2022-09-12 	Buy and hold balance:	 79882.44 	Strategy balance:	 82581.88 	Delta:	 0.033793
# 2022-09-13 	Buy and hold balance:	 75423.96 	Strategy balance:	 78304.26 	Delta:	 0.038188
# 2022-09-14 	Buy and hold balance:	 76532.29 	Strategy balance:	 79514.84 	Delta:	 0.038971
# 2022-09-15 	Buy and hold balance:	 75571.61 	Strategy balance:	 79036.85 	Delta:	 0.045854
# 2022-09-16 	Buy and hold balance:	 75324.98 	Strategy balance:	 78688.95 	Delta:	 0.044659
# 2022-09-19 	Buy and hold balance:	 76397.72 	Strategy balance:	 79843.27 	Delta:	 0.045100
# 2022-09-20 	Buy and hold balance:	 76392.54 	Strategy balance:	 79482.68 	Delta:	 0.040451
# 2022-09-21 	Buy and hold balance:	 75001.87 	Strategy balance:	 77977.47 	Delta:	 0.039674
# 2022-09-22 	Buy and hold balance:	 73438.42 	Strategy balance:	 75704.17 	Delta:	 0.030852
# 2022-09-23 	Buy and hold balance:	 71677.69 	Strategy balance:	 73220.30 	Delta:	 0.021522
# 2022-09-26 	Buy and hold balance:	 71535.61 	Strategy balance:	 72827.16 	Delta:	 0.018055
# 2022-09-27 	Buy and hold balance:	 72285.37 	Strategy balance:	 73721.50 	Delta:	 0.019868
# 2022-09-28 	Buy and hold balance:	 72935.32 	Strategy balance:	 74759.47 	Delta:	 0.025011
# 2022-09-29 	Buy and hold balance:	 69547.38 	Strategy balance:	 71035.14 	Delta:	 0.021392
# 2022-09-30 	Buy and hold balance:	 68264.54 	Strategy balance:	 69960.31 	Delta:	 0.024841
# 2022-10-03 	Buy and hold balance:	 67927.46 	Strategy balance:	 68576.31 	Delta:	 0.009552
# 2022-10-04 	Buy and hold balance:	 69967.79 	Strategy balance:	 70741.19 	Delta:	 0.011054
# 2022-10-05 	Buy and hold balance:	 69352.26 	Strategy balance:	 69678.63 	Delta:	 0.004706
# 2022-10-06 	Buy and hold balance:	 68784.43 	Strategy balance:	 68928.85 	Delta:	 0.002100
# 2022-10-07 	Buy and hold balance:	 64846.77 	Strategy balance:	 64717.28 	Delta:	 -0.001997
# 2022-10-10 	Buy and hold balance:	 64341.17 	Strategy balance:	 64217.34 	Delta:	 -0.001925
# 2022-10-11 	Buy and hold balance:	 63285.11 	Strategy balance:	 63088.88 	Delta:	 -0.003101
# 2022-10-12 	Buy and hold balance:	 63265.73 	Strategy balance:	 63092.95 	Delta:	 -0.002731
# 2022-10-13 	Buy and hold balance:	 65156.80 	Strategy balance:	 64957.40 	Delta:	 -0.003060
# 2022-10-14 	Buy and hold balance:	 62262.34 	Strategy balance:	 61880.99 	Delta:	 -0.006125
# 2022-10-17 	Buy and hold balance:	 65030.59 	Strategy balance:	 64509.26 	Delta:	 -0.008017
# 2022-10-18 	Buy and hold balance:	 65387.11 	Strategy balance:	 65081.14 	Delta:	 -0.004679
# 2022-10-19 	Buy and hold balance:	 65380.63 	Strategy balance:	 64735.66 	Delta:	 -0.009865
# 2022-10-20 	Buy and hold balance:	 64177.14 	Strategy balance:	 63424.85 	Delta:	 -0.011722
# 2022-10-21 	Buy and hold balance:	 65924.12 	Strategy balance:	 65242.36 	Delta:	 -0.010342
# 2022-10-24 	Buy and hold balance:	 66395.37 	Strategy balance:	 65682.38 	Delta:	 -0.010738
# 2022-10-25 	Buy and hold balance:	 68382.81 	Strategy balance:	 67633.16 	Delta:	 -0.010963
# 2022-10-26 	Buy and hold balance:	 66455.84 	Strategy balance:	 65726.76 	Delta:	 -0.010971
# 2022-10-27 	Buy and hold balance:	 65502.60 	Strategy balance:	 64571.35 	Delta:	 -0.014217
# 2022-10-28 	Buy and hold balance:	 68497.69 	Strategy balance:	 67665.65 	Delta:	 -0.012147
# 2022-10-31 	Buy and hold balance:	 67545.31 	Strategy balance:	 66684.85 	Delta:	 -0.012739
# 2022-11-01 	Buy and hold balance:	 66870.82 	Strategy balance:	 65948.60 	Delta:	 -0.013791
# 2022-11-02 	Buy and hold balance:	 64240.86 	Strategy balance:	 63335.03 	Delta:	 -0.014100
# 2022-11-03 	Buy and hold balance:	 63114.14 	Strategy balance:	 62174.18 	Delta:	 -0.014893
# 2022-11-04 	Buy and hold balance:	 63319.92 	Strategy balance:	 62260.69 	Delta:	 -0.016728
# 2022-11-07 	Buy and hold balance:	 63146.63 	Strategy balance:	 61866.26 	Delta:	 -0.020276
# 2022-11-08 	Buy and hold balance:	 62988.31 	Strategy balance:	 61797.08 	Delta:	 -0.018912
# 2022-11-09 	Buy and hold balance:	 60336.53 	Strategy balance:	 58463.05 	Delta:	 -0.031050
# 2022-11-10 	Buy and hold balance:	 65754.12 	Strategy balance:	 64695.65 	Delta:	 -0.016097
# 2022-11-11 	Buy and hold balance:	 67360.78 	Strategy balance:	 67064.88 	Delta:	 -0.004393
# 2022-11-14 	Buy and hold balance:	 66410.10 	Strategy balance:	 66892.76 	Delta:	 0.007268
# 2022-11-15 	Buy and hold balance:	 67300.65 	Strategy balance:	 68542.83 	Delta:	 0.018457
# 2022-11-16 	Buy and hold balance:	 65987.98 	Strategy balance:	 66332.33 	Delta:	 0.005218
# 2022-11-17 	Buy and hold balance:	 65972.22 	Strategy balance:	 66802.39 	Delta:	 0.012584
# 2022-11-18 	Buy and hold balance:	 65669.93 	Strategy balance:	 66528.03 	Delta:	 0.013067
# 2022-11-21 	Buy and hold balance:	 64148.47 	Strategy balance:	 64607.08 	Delta:	 0.007149
# 2022-11-22 	Buy and hold balance:	 65280.48 	Strategy balance:	 66188.84 	Delta:	 0.013915
# 2022-11-23 	Buy and hold balance:	 66911.44 	Strategy balance:	 67826.86 	Delta:	 0.013681
# 2022-11-25 	Buy and hold balance:	 66277.64 	Strategy balance:	 66847.68 	Delta:	 0.008601
# 2022-11-28 	Buy and hold balance:	 65012.27 	Strategy balance:	 65487.25 	Delta:	 0.007306
# 2022-11-29 	Buy and hold balance:	 64249.15 	Strategy balance:	 64920.04 	Delta:	 0.010442
# 2022-11-30 	Buy and hold balance:	 68179.42 	Strategy balance:	 68736.84 	Delta:	 0.008176
# 2022-12-01 	Buy and hold balance:	 68243.76 	Strategy balance:	 68722.78 	Delta:	 0.007019
# 2022-12-02 	Buy and hold balance:	 67945.76 	Strategy balance:	 67689.81 	Delta:	 -0.003767
# 2022-12-05 	Buy and hold balance:	 66229.73 	Strategy balance:	 65919.02 	Delta:	 -0.004691
# 2022-12-06 	Buy and hold balance:	 64660.82 	Strategy balance:	 63847.11 	Delta:	 -0.012584
# 2022-12-07 	Buy and hold balance:	 63884.69 	Strategy balance:	 63007.45 	Delta:	 -0.013732
# 2022-12-08 	Buy and hold balance:	 64667.70 	Strategy balance:	 63335.76 	Delta:	 -0.020597
# 2022-12-09 	Buy and hold balance:	 64715.42 	Strategy balance:	 63020.07 	Delta:	 -0.026197
# 2022-12-12 	Buy and hold balance:	 64988.94 	Strategy balance:	 63204.39 	Delta:	 -0.027459
# 2022-12-13 	Buy and hold balance:	 65143.31 	Strategy balance:	 63243.25 	Delta:	 -0.029167
# 2022-12-14 	Buy and hold balance:	 64178.46 	Strategy balance:	 61604.71 	Delta:	 -0.040103
# 2022-12-15 	Buy and hold balance:	 62264.60 	Strategy balance:	 59716.58 	Delta:	 -0.040922
# 2022-12-16 	Buy and hold balance:	 60851.17 	Strategy balance:	 58310.81 	Delta:	 -0.041747
# 2022-12-19 	Buy and hold balance:	 60037.47 	Strategy balance:	 57592.61 	Delta:	 -0.040722
# 2022-12-20 	Buy and hold balance:	 59128.59 	Strategy balance:	 56576.92 	Delta:	 -0.043155
# 2022-12-21 	Buy and hold balance:	 60083.81 	Strategy balance:	 57956.53 	Delta:	 -0.035405
# 2022-12-22 	Buy and hold balance:	 57518.45 	Strategy balance:	 54697.13 	Delta:	 -0.049051
# 2022-12-23 	Buy and hold balance:	 57331.52 	Strategy balance:	 54577.36 	Delta:	 -0.048039
# 2022-12-27 	Buy and hold balance:	 55359.94 	Strategy balance:	 52128.09 	Delta:	 -0.058379
# 2022-12-28 	Buy and hold balance:	 54816.38 	Strategy balance:	 51705.65 	Delta:	 -0.056748
# 2022-12-29 	Buy and hold balance:	 56894.90 	Strategy balance:	 53920.03 	Delta:	 -0.052287
# 2022-12-30 	Buy and hold balance:	 56963.32 	Strategy balance:	 54067.50 	Delta:	 -0.050837
#
# high_buy_and_hold 105072.29780578613
# low_buy_and_hold 54816.378479003906
#
# high_strategy 105072.29780578613
# low_strategy 51705.647178227715
#
# biggest_delta -0.05837888047022075
# biggest_delta_day 2022-12-27 00:00:00
#
# final_delta_usd -2895.815954625861
# final_delta_percent -0.05083650441494262
