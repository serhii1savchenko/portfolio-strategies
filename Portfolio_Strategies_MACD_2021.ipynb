# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from math import sqrt
from pypfopt.expected_returns import mean_historical_return
from pypfopt.risk_models import CovarianceShrinkage
from pypfopt.efficient_frontier import EfficientFrontier
from pypfopt.discrete_allocation import get_latest_prices
from dateutil.relativedelta import relativedelta
import copy
import warnings
warnings.filterwarnings('ignore')

tickers = ['AAPL', 'GOOG', 'MSFT', 'AMZN', 'INTC', 'AMD', 'NVDA', 'F', 'TSLA', 'JPM', 'MS', 'VOO']
data_for_portfolio_5y = yf.download(tickers, start='2016-01-01', end='2021-01-01')['Close'].dropna()
data_for_portfolio_5y.tail()
# Out:
# [*********************100%***********************]  12 of 12 completed
#                   AAPL        AMD        AMZN     F       GOOG       INTC  \
# Date
# 2020-12-24  131.970001  91.809998  158.634506  8.86  86.942497  47.070000
# 2020-12-28  136.690002  91.599998  164.197998  8.89  88.804497  47.070000
# 2020-12-29  134.869995  90.620003  166.100006  8.82  87.935997  49.389999
# 2020-12-30  133.720001  92.290001  164.292496  8.86  86.975998  48.750000
# 2020-12-31  132.690002  91.709999  162.846497  8.79  87.594002  49.820000
#
#                    JPM         MS        MSFT        NVDA        TSLA  \
# Date
# 2020-12-24  124.519997  68.089996  222.750000  129.937500  220.589996
# 2020-12-28  125.339996  68.050003  224.960007  129.000000  221.229996
# 2020-12-29  125.010002  67.709999  224.149994  129.432495  221.996674
# 2020-12-30  125.360001  67.839996  221.679993  131.457504  231.593338
# 2020-12-31  127.070000  68.529999  222.419998  130.550003  235.223328
#
#                    VOO
# Date
# 2020-12-24  339.160004
# 2020-12-28  342.109985
# 2020-12-29  341.390015
# 2020-12-30  341.850006
# 2020-12-31  343.690002

# %%
# Create initial portfolio
mu = mean_historical_return(data_for_portfolio_5y)
S = CovarianceShrinkage(data_for_portfolio_5y).ledoit_wolf()
ef = EfficientFrontier(mu, S, weight_bounds=(0,1))
weights = ef.max_sharpe()
initial_weights = ef.clean_weights()
print(initial_weights, '\n')

# Initial buy stocks
balance_usd = 100_000
balance_remain = balance_usd
stocks_initial = {}
latest_prices_data_dec_2020 = get_latest_prices(data_for_portfolio_5y)
for ticker in initial_weights:
    to_spend_usd = balance_usd * initial_weights[ticker]
    one_stock_price = latest_prices_data_dec_2020[ticker]
    stocks_number = to_spend_usd // one_stock_price
    stocks_initial[ticker] = stocks_number
    balance_remain = balance_remain - (stocks_number * one_stock_price)
print('Portfolio:', stocks_initial)
print('Remaining balance: USD', balance_remain)
# Out:
# OrderedDict([('AAPL', 0.1135), ('AMD', 0.27372), ('AMZN', 0.11721), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.0), ('NVDA', 0.28702), ('TSLA', 0.20854), ('VOO', 0.0)])
#
# Portfolio: {'AAPL': 85.0, 'AMD': 298.0, 'AMZN': 71.0, 'F': 0.0, 'GOOG': 0.0, 'INTC': 0.0, 'JPM': 0.0, 'MS': 0.0, 'MSFT': 0.0, 'NVDA': 219.0, 'TSLA': 88.0, 'VOO': 0.0}
# Remaining balance: USD 539.5653076171875

# %%
# Calculate MACD, RSI, and S&R signals.
data_2021 = yf.download(tickers, start='2020-12-12', end='2022-01-01')['Close'].dropna()

short_ma = 5                                       # 5 минулих днів для "короткого" МА 
long_ma = 12                                       # 12 минулих днів для "довгого" МА 
rsi_period = 14                                    # RSI рахується за 14 минулих днів 
rsi_oversold = 30                                  # Параметри для індикатора RSI 
rsi_overbought = 70 
sr_sell = 0.7                                      # Параметри для індикатора S&R
sr_buy = 0.3 
start = max(long_ma, rsi_period)

for ticker in data_2021.columns:
    data_2021['MA_' + ticker + str(short_ma)] = data_2021[ticker].rolling(short_ma).mean()
    data_2021['MA_' + ticker + str(long_ma)] = data_2021[ticker].rolling(long_ma).mean() 
    data_2021['return_' + ticker] = data_2021[ticker].pct_change() 
    data_2021['Up_' + ticker] = np.maximum(data_2021[ticker].diff(),0) 
    data_2021['Down_' + ticker] = np.maximum(-data_2021[ticker].diff(),0) 
    data_2021['RS_' + ticker] = data_2021['Up_' + ticker].rolling(rsi_period).mean()/data_2021['Down_' + ticker].rolling(rsi_period).mean() 
    data_2021['RSI_' + ticker] = 100 - 100/(1 + data_2021['RS_' + ticker]) 
    data_2021['S&R_' + ticker] = (data_2021[ticker]/(10**np.floor(np.log10(data_2021[ticker]))))%1 
    data_2021['MACD_signal_' + ticker] = 2*(data_2021['MA_' + ticker + str(short_ma)] > data_2021['MA_' + ticker + str(long_ma)]) -1 
    data_2021['RSI_signal_' + ticker] = 1*(data_2021['RSI_' + ticker] < rsi_oversold) -1*(data_2021['RSI_' + ticker] > rsi_overbought) 
    data_2021['S&R_signal_' + ticker] = 1*(data_2021['S&R_' + ticker] < sr_buy) -1*(data_2021['S&R_' + ticker] > sr_sell) 

data = data_2021.drop(data_2021.index[range(14)])
#print(data.to_string())
data.head(3)
# Out:
# [*********************100%***********************]  12 of 12 completed
#                   AAPL        AMD        AMZN     F       GOOG       INTC  \
# Date
# 2021-01-04  129.410004  92.300003  159.331497  8.52  86.412003  49.669998
# 2021-01-05  131.009995  92.769997  160.925507  8.65  87.045998  50.610001
# 2021-01-06  126.599998  90.330002  156.919006  8.84  86.764503  51.099998
#
#                    JPM         MS        MSFT        NVDA  ...    MA_VOO12  \
# Date                                                       ...
# 2021-01-04  125.870003  68.330002  217.690002  131.134995  ...  340.415003
# 2021-01-05  125.650002  69.489998  217.899994  134.047501  ...  340.506671
# 2021-01-06  131.550003  73.680000  212.250000  126.144997  ...  340.616669
#
#             return_VOO    Up_VOO  Down_VOO    RS_VOO    RSI_VOO  S&R_VOO  \
# Date
# 2021-01-04   -0.013559  0.000000  4.660004  1.217737  54.908985   0.3903
# 2021-01-05    0.006578  2.230011  0.000000  1.634519  62.042412   0.4126
# 2021-01-06    0.006066  2.069977  0.000000  1.374617  57.887952   0.4333
#
#             MACD_signal_VOO  RSI_signal_VOO  S&R_signal_VOO
# Date
# 2021-01-04                1               0               0
# 2021-01-05                1               0               0
# 2021-01-06                1               0               0
#
# [3 rows x 144 columns]

# %%
data.tail(3)
# Out:
#                   AAPL         AMD        AMZN          F        GOOG  \
# Date
# 2021-12-29  179.380005  148.259995  169.201004  20.559999  146.504501
# 2021-12-30  178.199997  145.149994  168.644501  20.469999  146.002502
# 2021-12-31  177.570007  143.899994  166.716995  20.770000  144.679504
#
#                  INTC         JPM         MS        MSFT        NVDA  ...  \
# Date                                                                  ...
# 2021-12-29  51.830002  158.559998  98.730003  341.950012  300.010010  ...
# 2021-12-30  51.740002  158.479996  98.800003  339.320007  295.859985  ...
# 2021-12-31  51.500000  158.350006  98.160004  336.320007  294.109985  ...
#
#               MA_VOO12  return_VOO    Up_VOO  Down_VOO    RS_VOO    RSI_VOO  \
# Date
# 2021-12-29  430.458336    0.001209  0.529999  0.000000  1.318102  56.861268
# 2021-12-30  431.188334   -0.002825  0.000000  1.240021  1.423401  58.735673
# 2021-12-31  432.061668   -0.002741  0.000000  1.199982  1.165480  53.820870
#
#             S&R_VOO  MACD_signal_VOO  RSI_signal_VOO  S&R_signal_VOO
# Date
# 2021-12-29   0.3901                1               0               0
# 2021-12-30   0.3777                1               0               0
# 2021-12-31   0.3657                1               0               0
#
# [3 rows x 144 columns]

# %%
def check_tickers_for_sell(tickers_sell, now, current_weights):
    ticker_percent_sell = {}
    end_date = now.strftime('%Y-%m-%d')
    start_date = (now - relativedelta(years=5)).strftime('%Y-%m-%d')
    # Get data for all tickers for last 5 years
    data_for_tickers = yf.download(tickers, start_date, end_date, progress=False)['Close'].dropna()
    
    # Generate portfolio on this data
    mu = mean_historical_return(data_for_tickers)
    S = CovarianceShrinkage(data_for_tickers).ledoit_wolf()
    ef = EfficientFrontier(mu, S, weight_bounds=(0,1))
    weights = ef.max_sharpe()
    new_weights = ef.clean_weights()
    
    for ticker in tickers_sell:
        if new_weights[ticker] == 0:
            ticker_percent_sell[ticker] = 100
        elif new_weights[ticker] < current_weights[ticker]:
            delta = current_weights[ticker] - new_weights[ticker]
            sell_percent = (delta * 100) // current_weights[ticker]
            ticker_percent_sell[ticker] = sell_percent
    return ticker_percent_sell

# %%
def select_ticker_for_sell(data, date, filtered_sell_tickers_with_percents, stocks_current):
    sell_ticker = ''
    sell_profit = 0
    stocks_to_sell = 0
    for ticker in filtered_sell_tickers_with_percents:
        no_of_stocks = stocks_current[ticker]
        #print(ticker, 'no_of_stocks', no_of_stocks)
        cur_price = data[ticker][date]
        #print(ticker, 'cur_price', cur_price)
        sell_percent = (filtered_sell_tickers_with_percents[ticker] / 100)
        #print(ticker, 'sell_percent', sell_percent)
        potentail_profit = no_of_stocks * cur_price * sell_percent
        #print(ticker, 'potentail_profit', potentail_profit)
        if potentail_profit > sell_profit:
            sell_profit = potentail_profit
            sell_ticker = ticker
            stocks_to_sell = no_of_stocks * sell_percent
    return [sell_ticker, sell_profit, stocks_to_sell]

# %%
def select_ticker_for_buy(tickers_buy, now):
    if len(tickers_buy) == 1:
        return tickers_buy[0]
    end_date = now.strftime('%Y-%m-%d')
    start_date = (now - relativedelta(years=5)).strftime('%Y-%m-%d')
    # Get data for all tickers for last 5 years period
    data_for_tickers_last_year = yf.download(tickers_buy, start_date, end_date, progress=False)['Close'].dropna()
    ticker_percent_delta = {}
    for t in tickers_buy:
        first_price = data_for_tickers_last_year[t][0]
        last_price = data_for_tickers_last_year[t][len(data_for_tickers_last_year[t]) - 1]
        delta = last_price - first_price
        delta_abs = abs(delta)
        percent = (delta_abs * 100) / first_price
        if delta > 0:
            ticker_percent_delta[t] = percent
        else:
            ticker_percent_delta[t] = -1 * percent
    sorted_by_delta = dict(sorted(ticker_percent_delta.items(), key=lambda x:x[1], reverse=True))
    return list(sorted_by_delta.keys())[0]

# %%
print('Start weights:', initial_weights)
clean_result = balance_remain
for stock in initial_weights:
    clean_result = clean_result + (stocks_initial[stock] * data[stock][len(data[stock]) - 1])
print('Without any changes balance on the end of 2021 would be', clean_result)
print('------------------------------------')
# Out:
# Start weights: OrderedDict([('AAPL', 0.1135), ('AMD', 0.27372), ('AMZN', 0.11721), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.0), ('NVDA', 0.28702), ('TSLA', 0.20854), ('VOO', 0.0)])
# Without any changes balance on the end of 2021 would be 165761.08842468262
# ------------------------------------

# %%
strategy = 'MACD_signal_'                 # MACD_signal_        or        RSI_signal_        or        S&R_signal_
strategy_weights = copy.deepcopy(initial_weights)
stocks_strategy = copy.deepcopy(stocks_initial)
balance_strategy = balance_remain

balance_buy_and_hold_dict = {}
balance_strategy_dict = {}

for d in data.index: 
    if d.weekday() == 4:                   # every Friday
        tickers_sell = []
        tickers_buy = []
        for t in strategy_weights:
            if data[strategy + t][d] == -1:
                tickers_sell.append(t)
            if data[strategy + t][d] == 1:
                tickers_buy.append(t)
        print(d, 'Sell candidates:', tickers_sell, 'Buy candidates:', tickers_buy)
        if len(tickers_sell) > 0 and len(tickers_buy) > 0:
            filtered_sell_tickers_with_percents = check_tickers_for_sell(tickers_sell, d, strategy_weights)
            print('Filtered sell candidates:', filtered_sell_tickers_with_percents)
            if len(filtered_sell_tickers_with_percents) > 0:
                ticker_for_sell_data = select_ticker_for_sell(data, d, filtered_sell_tickers_with_percents, stocks_strategy)
                will_receive_usd = ticker_for_sell_data[1]
                # If this ticker is present in current portfolio
                if will_receive_usd > 0:
                    ticker_for_sell = ticker_for_sell_data[0]
                    stocks_to_sell = ticker_for_sell_data[2]
                    sell_percents = filtered_sell_tickers_with_percents[ticker_for_sell]
                    ticker_for_buy = select_ticker_for_buy(tickers_buy, d)
                    # If we can buy other ticker on that money
                    if (will_receive_usd + balance_strategy) > data[ticker_for_buy][d]:
                        print('Will sell',ticker_for_sell,'and get',will_receive_usd,'$ after selling (',sell_percents,'% )')
                        print('Will buy', ticker_for_buy)
                        # Sell percent of ticker_for_sell and add that money to balance
                        stocks_strategy[ticker_for_sell] = stocks_strategy[ticker_for_sell] - stocks_to_sell
                        balance_strategy = balance_strategy + will_receive_usd
                        # Buy ticker_for_buy on all balance
                        no_of_buy_stocks = balance_strategy // data[ticker_for_buy][d]
                        stocks_strategy[ticker_for_buy] = stocks_strategy[ticker_for_buy] + no_of_buy_stocks
                        balance_strategy = balance_strategy - (data[ticker_for_buy][d] * no_of_buy_stocks)
                        # Recalculate new weights for all portfolio
                        # calculate all prices for now + balance - потом высчитать сколько в процентах сейчас каждый ФИ
                        cur_balance = balance_strategy
                        stock_usd = {}
                        for stock in stocks_strategy:
                            stock_usd[stock] = stocks_strategy[stock] * data[stock][d]
                            cur_balance = cur_balance + stock_usd[stock]
                        for stock in stocks_strategy:
                            strategy_weights[stock] = stock_usd[stock] / cur_balance
                        print('Current weights are', strategy_weights)
                        print('Current balance =', cur_balance)
                    else:
                        print("No changes because sell profit is not enough for buying at least one stock.")
                else:
                    print("No changes because all sell candidates are not present in current portfolio.")
            else:
                print("No changes because all sell candidates failed check.")
        else:
            print("No changes because no sell candidates or no buy candidates.")
        print('------------------------------------')
    # Calculate current balance for stocks_initial
    today_balance_buy_and_hold = balance_remain
    for stock in stocks_initial:
        today_balance_buy_and_hold = today_balance_buy_and_hold + (data[stock][d] * stocks_initial[stock])
    balance_buy_and_hold_dict[d] = today_balance_buy_and_hold
    # Calculate current balance for stocks_strategy
    today_balance_strategy = balance_strategy
    for stock in stocks_strategy:
        today_balance_strategy = today_balance_strategy + (data[stock][d] * stocks_strategy[stock])
    balance_strategy_dict[d] = today_balance_strategy

print('\nWith strategy final weights are:', strategy_weights)        
clean_result = balance_strategy
for stock in strategy_weights:
    clean_result = clean_result + (stocks_strategy[stock] * data[stock][len(data[stock]) - 1])
print('\nWith strategy balance on the end of 2021 would be', clean_result)
# Out:
# 2021-01-08 00:00:00 Sell candidates: ['AAPL', 'AMZN', 'F', 'MSFT'] Buy candidates: ['AMD', 'GOOG', 'INTC', 'JPM', 'MS', 'NVDA', 'TSLA', 'VOO']
# Filtered sell candidates: {'AAPL': 19.0, 'AMZN': 2.0, 'F': 100, 'MSFT': 100}
# Will sell AAPL and get 2132.6075492858886 $ after selling ( 19.0 % )
# Will buy AMD
# Current weights are OrderedDict([('AAPL', 0.08565930701908782), ('AMD', 0.29050199192915693), ('AMZN', 0.10645259155545839), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.0), ('NVDA', 0.27394797524969966), ('TSLA', 0.24321264501313763), ('VOO', 0.0)])
# Current balance = 106137.2433013916
# ------------------------------------
# 2021-01-15 00:00:00 Sell candidates: ['AAPL', 'AMD', 'AMZN', 'GOOG', 'MSFT'] Buy candidates: ['F', 'INTC', 'JPM', 'MS', 'NVDA', 'TSLA', 'VOO']
# Filtered sell candidates: {'AAPL': 77.0, 'GOOG': 100, 'MSFT': 100}
# Will sell AAPL and get 6740.263497642516 $ after selling ( 77.0 % )
# Will buy TSLA
# Current weights are OrderedDict([('AAPL', 0.01994370965103519), ('AMD', 0.2848573140200621), ('AMZN', 0.10916338223322228), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.0), ('NVDA', 0.27897170647319713), ('TSLA', 0.30552930708972775), ('VOO', 0.0)])
# Current balance = 100950.39967803955
# ------------------------------------
# 2021-01-22 00:00:00 Sell candidates: ['AMD', 'JPM', 'MS'] Buy candidates: ['AAPL', 'AMZN', 'F', 'GOOG', 'INTC', 'MSFT', 'NVDA', 'TSLA', 'VOO']
# Filtered sell candidates: {'JPM': 100, 'MS': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2021-01-29 00:00:00 Sell candidates: ['AMD', 'INTC', 'JPM', 'MS', 'NVDA', 'VOO'] Buy candidates: ['AAPL', 'AMZN', 'F', 'GOOG', 'MSFT', 'TSLA']
# Filtered sell candidates: {'INTC': 100, 'JPM': 100, 'MS': 100, 'NVDA': 11.0, 'VOO': 100}
# Will sell NVDA and get 3129.2309367370603 $ after selling ( 11.0 % )
# Will buy TSLA
# Current weights are OrderedDict([('AAPL', 0.02097668003797208), ('AMD', 0.28025727817648277), ('AMZN', 0.11425668001492673), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.0), ('NVDA', 0.25415436969565536), ('TSLA', 0.3292504983603699), ('VOO', 0.0)])
# Current balance = 99617.89389620972
# ------------------------------------
# 2021-02-05 00:00:00 Sell candidates: ['AAPL', 'AMD', 'MS'] Buy candidates: ['AMZN', 'F', 'GOOG', 'INTC', 'JPM', 'MSFT', 'NVDA', 'TSLA', 'VOO']
# Filtered sell candidates: {'AAPL': 26.0, 'AMD': 2.0, 'MS': 100}
# Will sell AMD and get 573.1080099487305 $ after selling ( 2.0 % )
# Will buy TSLA
# Current weights are OrderedDict([('AAPL', 0.020714740498699848), ('AMD', 0.26860939593307515), ('AMZN', 0.11382572732807456), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.0), ('NVDA', 0.25338108264755277), ('TSLA', 0.3423692412139794), ('VOO', 0.0)])
# Current balance = 104546.94777127076
# ------------------------------------
# 2021-02-12 00:00:00 Sell candidates: ['AMZN', 'TSLA'] Buy candidates: ['AAPL', 'AMD', 'F', 'GOOG', 'INTC', 'JPM', 'MS', 'MSFT', 'NVDA', 'VOO']
# Filtered sell candidates: {'TSLA': 24.0}
# Will sell TSLA and get 8226.489858398438 $ after selling ( 24.0 % )
# Will buy AMD
# Current weights are OrderedDict([('AAPL', 0.019979946224351793), ('AMD', 0.3561314427282166), ('AMZN', 0.10845235703542562), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.0), ('NVDA', 0.2717954182898039), ('TSLA', 0.24280467158539973), ('VOO', 0.0)])
# Current balance = 107290.15652031708
# ------------------------------------
# 2021-02-19 00:00:00 Sell candidates: ['AAPL', 'AMZN', 'F', 'TSLA'] Buy candidates: ['AMD', 'GOOG', 'INTC', 'JPM', 'MS', 'MSFT', 'NVDA', 'VOO']
# Filtered sell candidates: {'AAPL': 100, 'F': 100}
# Will sell AAPL and get 2056.5563076782223 $ after selling ( 100 % )
# Will buy AMD
# Current weights are OrderedDict([('AAPL', 0.0), ('AMD', 0.37001736982127886), ('AMZN', 0.11070223870230328), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.0), ('NVDA', 0.2791580594696402), ('TSLA', 0.23929782371626704), ('VOO', 0.0)])
# Current balance = 104217.80795549774
# ------------------------------------
# 2021-02-26 00:00:00 Sell candidates: ['AAPL', 'AMD', 'AMZN', 'GOOG', 'INTC', 'MSFT', 'NVDA', 'TSLA', 'VOO'] Buy candidates: ['F', 'JPM', 'MS']
# Filtered sell candidates: {'AAPL': 100, 'AMD': 14.0, 'GOOG': 100, 'INTC': 100, 'MSFT': 100, 'NVDA': 22.0, 'TSLA': 3.0, 'VOO': 100}
# Will sell NVDA and get 5880.805212203979 $ after selling ( 22.0 % )
# Will buy MS
# Current weights are OrderedDict([('AAPL', 0.0), ('AMD', 0.3799916641112233), ('AMZN', 0.11468626808684992), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.06182449813466131), ('MSFT', 0.0), ('NVDA', 0.21778185586297572), ('TSLA', 0.22521702829055013), ('VOO', 0.0)])
# Current balance = 95738.5889100876
# ------------------------------------
# 2021-03-05 00:00:00 Sell candidates: ['AAPL', 'AMD', 'AMZN', 'GOOG', 'INTC', 'MSFT', 'NVDA', 'TSLA', 'VOO'] Buy candidates: ['F', 'JPM', 'MS']
# Filtered sell candidates: {'AAPL': 100, 'AMD': 22.0, 'GOOG': 100, 'INTC': 100, 'MSFT': 100, 'TSLA': 4.0, 'VOO': 100}
# Will sell AMD and get 7436.28339407959 $ after selling ( 22.0 % )
# Will buy MS
# Current weights are OrderedDict([('AAPL', 0.0), ('AMD', 0.2970389764474383), ('AMZN', 0.12000566990083948), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.1539783806974848), ('MSFT', 0.0), ('NVDA', 0.21344433078769168), ('TSLA', 0.21503707118410392), ('VOO', 0.0)])
# Current balance = 88759.41156325988
# ------------------------------------
# 2021-03-12 00:00:00 Sell candidates: ['AAPL', 'AMD', 'NVDA', 'TSLA'] Buy candidates: ['AMZN', 'F', 'GOOG', 'INTC', 'JPM', 'MS', 'MSFT', 'VOO']
# Filtered sell candidates: {'AAPL': 100, 'AMD': 7.0, 'TSLA': 1.0}
# Will sell AMD and get 1905.0161301291507 $ after selling ( 7.0 % )
# Will buy AMZN
# Current weights are OrderedDict([('AAPL', 0.0), ('AMD', 0.2687683216404482), ('AMZN', 0.13615368852031118), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.15136128146441877), ('MSFT', 0.0), ('NVDA', 0.20755303730551553), ('TSLA', 0.235151562725052), ('VOO', 0.0)])
# Current balance = 94168.4639770584
# ------------------------------------
# 2021-03-19 00:00:00 Sell candidates: ['GOOG'] Buy candidates: ['AAPL', 'AMD', 'AMZN', 'F', 'INTC', 'JPM', 'MS', 'MSFT', 'NVDA', 'TSLA', 'VOO']
# Filtered sell candidates: {'GOOG': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2021-03-26 00:00:00 Sell candidates: ['AAPL', 'AMD', 'AMZN', 'F', 'GOOG', 'INTC', 'JPM', 'MS', 'NVDA', 'TSLA', 'VOO'] Buy candidates: ['MSFT']
# Filtered sell candidates: {'AAPL': 100, 'F': 100, 'GOOG': 100, 'INTC': 100, 'JPM': 100, 'MS': 100, 'TSLA': 20.0, 'VOO': 100}
# Will sell MS and get 13516.620567321777 $ after selling ( 100 % )
# Will buy MSFT
# Current weights are OrderedDict([('AAPL', 0.0), ('AMD', 0.2694270886468847), ('AMZN', 0.14117264089762804), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.15023907620510984), ('NVDA', 0.21756149060061006), ('TSLA', 0.2201221023820585), ('VOO', 0.0)])
# Current balance = 89719.39988546917
# ------------------------------------
# 2021-04-09 00:00:00 Sell candidates: [] Buy candidates: ['AAPL', 'AMD', 'AMZN', 'F', 'GOOG', 'INTC', 'JPM', 'MS', 'MSFT', 'NVDA', 'TSLA', 'VOO']
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2021-04-16 00:00:00 Sell candidates: ['AMD', 'F', 'INTC', 'JPM'] Buy candidates: ['AAPL', 'AMZN', 'GOOG', 'MS', 'MSFT', 'NVDA', 'TSLA', 'VOO']
# Filtered sell candidates: {'AMD': 1.0, 'F': 100, 'INTC': 100, 'JPM': 100}
# Will sell AMD and get 256.529967492865 $ after selling ( 1.0 % )
# Will buy NVDA
# Current weights are OrderedDict([('AAPL', 0.0), ('AMD', 0.24762318253960972), ('AMZN', 0.1375540803325803), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.14491071552826046), ('NVDA', 0.2389797863078965), ('TSLA', 0.23024143170361364), ('VOO', 0.0)])
# Current balance = 102560.94167488226
# ------------------------------------
# 2021-04-23 00:00:00 Sell candidates: ['AMD', 'AMZN', 'F', 'INTC', 'JPM', 'MS', 'NVDA'] Buy candidates: ['AAPL', 'GOOG', 'MSFT', 'TSLA', 'VOO']
# Filtered sell candidates: {'AMD': 24.0, 'F': 100, 'INTC': 100, 'JPM': 100, 'MS': 100}
# Will sell AMD and get 6140.411265463461 $ after selling ( 24.0 % )
# Will buy TSLA
# Current weights are OrderedDict([('AAPL', 0.0), ('AMD', 0.1921376691831436), ('AMZN', 0.13700035656161128), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.14708811533524513), ('NVDA', 0.2323386009439405), ('TSLA', 0.2901217661346814), ('VOO', 0.0)])
# Current balance = 101201.57987048969
# ------------------------------------
# 2021-04-30 00:00:00 Sell candidates: ['AAPL', 'INTC', 'MSFT', 'NVDA', 'TSLA'] Buy candidates: ['AMD', 'AMZN', 'F', 'GOOG', 'JPM', 'MS', 'VOO']
# Filtered sell candidates: {'INTC': 100, 'MSFT': 69.0, 'TSLA': 47.0}
# Will sell TSLA and get 13421.942413507079 $ after selling ( 47.0 % )
# Will buy AMD
# Current weights are OrderedDict([('AAPL', 0.0), ('AMD', 0.3280766510808079), ('AMZN', 0.1442582919952446), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.14410256699245924), ('NVDA', 0.23176999639383272), ('TSLA', 0.15173285047737856), ('VOO', 0.0)])
# Current balance = 99750.19794943502
# ------------------------------------
# 2021-05-07 00:00:00 Sell candidates: ['AAPL', 'AMD', 'AMZN', 'F', 'INTC', 'MSFT', 'NVDA', 'TSLA'] Buy candidates: ['GOOG', 'JPM', 'MS', 'VOO']
# Filtered sell candidates: {'AMD': 35.0, 'AMZN': 32.0, 'F': 100, 'INTC': 100, 'MSFT': 51.0}
# Will sell AMD and get 11059.661699782047 $ after selling ( 35.0 % )
# Will buy GOOG
# Current weights are OrderedDict([('AAPL', 0.0), ('AMD', 0.21215031238459225), ('AMZN', 0.14109544855541106), ('F', 0.0), ('GOOG', 0.11396945797994984), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.14863598506688122), ('NVDA', 0.2356580601386428), ('TSLA', 0.14816395908573804), ('VOO', 0.0)])
# Current balance = 96815.18493799004
# ------------------------------------
# 2021-05-14 00:00:00 Sell candidates: ['AAPL', 'AMD', 'AMZN', 'GOOG', 'INTC', 'MSFT', 'NVDA', 'TSLA', 'VOO'] Buy candidates: ['F', 'JPM', 'MS']
# Filtered sell candidates: {'AMZN': 84.0, 'GOOG': 100, 'INTC': 100, 'MSFT': 18.0, 'NVDA': 18.0, 'VOO': 100}
# Will sell AMZN and get 11235.029697875976 $ after selling ( 84.0 % )
# Will buy MS
# Current weights are OrderedDict([('AAPL', 0.0), ('AMD', 0.21092070500549145), ('AMZN', 0.02321922440656862), ('F', 0.0), ('GOOG', 0.11560035593347356), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.12131252966202202), ('MSFT', 0.15346944129228476), ('NVDA', 0.23803399797824154), ('TSLA', 0.1365120838749227), ('VOO', 0.0)])
# Current balance = 92165.25148587146
# ------------------------------------
# 2021-05-21 00:00:00 Sell candidates: ['AAPL', 'INTC', 'MSFT', 'TSLA', 'VOO'] Buy candidates: ['AMD', 'AMZN', 'F', 'GOOG', 'JPM', 'MS', 'NVDA']
# Filtered sell candidates: {'INTC': 100, 'VOO': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2021-05-28 00:00:00 Sell candidates: [] Buy candidates: ['AAPL', 'AMD', 'AMZN', 'F', 'GOOG', 'INTC', 'JPM', 'MS', 'MSFT', 'NVDA', 'TSLA', 'VOO']
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2021-06-04 00:00:00 Sell candidates: ['AAPL', 'AMZN', 'MSFT'] Buy candidates: ['AMD', 'F', 'GOOG', 'INTC', 'JPM', 'MS', 'NVDA', 'TSLA', 'VOO']
# Filtered sell candidates: {}
# No changes because all sell candidates failed check.
# ------------------------------------
# 2021-06-11 00:00:00 Sell candidates: ['JPM', 'TSLA'] Buy candidates: ['AAPL', 'AMD', 'AMZN', 'F', 'GOOG', 'INTC', 'MS', 'MSFT', 'NVDA', 'VOO']
# Filtered sell candidates: {'JPM': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2021-06-18 00:00:00 Sell candidates: ['F', 'JPM', 'MS', 'VOO'] Buy candidates: ['AAPL', 'AMD', 'AMZN', 'GOOG', 'INTC', 'MSFT', 'NVDA', 'TSLA']
# Filtered sell candidates: {'F': 100, 'JPM': 100, 'MS': 100, 'VOO': 100}
# Will sell MS and get 10763.51953125 $ after selling ( 100 % )
# Will buy AMD
# Current weights are OrderedDict([('AAPL', 0.0), ('AMD', 0.3176177534947604), ('AMZN', 0.022354321916711765), ('F', 0.0), ('GOOG', 0.1115370082812206), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.1427739467029272), ('NVDA', 0.2771886564641628), ('TSLA', 0.12839134501051064), ('VOO', 0.0)])
# Current balance = 103572.88513770806
# ------------------------------------
# 2021-06-25 00:00:00 Sell candidates: ['INTC', 'JPM', 'MS'] Buy candidates: ['AAPL', 'AMD', 'AMZN', 'F', 'GOOG', 'MSFT', 'NVDA', 'TSLA', 'VOO']
# Filtered sell candidates: {'INTC': 100, 'JPM': 100, 'MS': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2021-07-02 00:00:00 Sell candidates: ['AMZN', 'F'] Buy candidates: ['AAPL', 'AMD', 'GOOG', 'INTC', 'JPM', 'MS', 'MSFT', 'NVDA', 'TSLA', 'VOO']
# Filtered sell candidates: {'AMZN': 100, 'F': 100}
# Will sell AMZN and get 2331.2906665039063 $ after selling ( 100 % )
# Will buy AMD
# Current weights are OrderedDict([('AAPL', 0.0), ('AMD', 0.346238348561331), ('AMZN', 0.0), ('F', 0.0), ('GOOG', 0.1049316718474721), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.14023249197105067), ('NVDA', 0.2796142085914561), ('TSLA', 0.12833929860394622), ('VOO', 0.0)])
# Current balance = 112855.79703858295
# ------------------------------------
# 2021-07-09 00:00:00 Sell candidates: ['F', 'INTC', 'JPM', 'TSLA'] Buy candidates: ['AAPL', 'AMD', 'AMZN', 'GOOG', 'MS', 'MSFT', 'NVDA', 'VOO']
# Filtered sell candidates: {'F': 100, 'INTC': 100, 'JPM': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2021-07-16 00:00:00 Sell candidates: ['AMD', 'F', 'NVDA', 'TSLA'] Buy candidates: ['AAPL', 'AMZN', 'GOOG', 'INTC', 'JPM', 'MS', 'MSFT', 'VOO']
# Filtered sell candidates: {'AMD': 55.0, 'F': 100, 'NVDA': 29.0}
# Will sell AMD and get 19491.908503157865 $ after selling ( 55.0 % )
# Will buy AAPL
# Current weights are OrderedDict([('AAPL', 0.18478961357270582), ('AMD', 0.15136264063394614), ('AMZN', 0.0), ('F', 0.0), ('GOOG', 0.11512447478800494), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.15188298642620554), ('NVDA', 0.2654966335816605), ('TSLA', 0.13044470086179996), ('VOO', 0.0)])
# Current balance = 105362.36069979542
# ------------------------------------
# 2021-07-23 00:00:00 Sell candidates: ['AAPL', 'AMZN', 'F', 'INTC', 'JPM', 'NVDA', 'TSLA', 'VOO'] Buy candidates: ['AMD', 'GOOG', 'MS', 'MSFT']
# Filtered sell candidates: {'F': 100, 'INTC': 100, 'JPM': 100, 'NVDA': 17.0, 'VOO': 100}
# Will sell NVDA and get 5121.275256226289 $ after selling ( 17.0 % )
# Will buy AMD
# Current weights are OrderedDict([('AAPL', 0.17961450921184718), ('AMD', 0.20245160849721755), ('AMZN', 0.0), ('F', 0.0), ('GOOG', 0.11525913112551335), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.15009502120426144), ('NVDA', 0.22729777324683068), ('TSLA', 0.12477660950495141), ('VOO', 0.0)])
# Current balance = 110004.91976953117
# ------------------------------------
# 2021-07-30 00:00:00 Sell candidates: ['AMZN', 'INTC'] Buy candidates: ['AAPL', 'AMD', 'F', 'GOOG', 'JPM', 'MS', 'MSFT', 'NVDA', 'TSLA', 'VOO']
# Filtered sell candidates: {'INTC': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2021-08-06 00:00:00 Sell candidates: ['AAPL', 'AMZN', 'F', 'GOOG'] Buy candidates: ['AMD', 'INTC', 'JPM', 'MS', 'MSFT', 'NVDA', 'TSLA', 'VOO']
# Filtered sell candidates: {'AAPL': 3.0, 'AMZN': 100, 'F': 100, 'GOOG': 100}
# Will sell GOOG and get 12607.311584472656 $ after selling ( 100 % )
# Will buy AMD
# Current weights are OrderedDict([('AAPL', 0.1673239609925872), ('AMD', 0.33809681189523527), ('AMZN', 0.0), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.14203677253150493), ('NVDA', 0.2241434157266418), ('TSLA', 0.12839686779669268), ('VOO', 0.0)])
# Current balance = 116161.60532850596
# ------------------------------------
# 2021-08-13 00:00:00 Sell candidates: ['AMD', 'AMZN', 'F', 'INTC'] Buy candidates: ['AAPL', 'GOOG', 'JPM', 'MS', 'MSFT', 'NVDA', 'TSLA', 'VOO']
# Filtered sell candidates: {'AMD': 46.0, 'AMZN': 100, 'F': 100, 'INTC': 100}
# Will sell AMD and get 18138.171602396727 $ after selling ( 46.0 % )
# Will buy TSLA
# Current weights are OrderedDict([('AAPL', 0.1693979527342598), ('AMD', 0.18188977664679062), ('AMZN', 0.0), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.14259324363726403), ('NVDA', 0.2204727938727023), ('TSLA', 0.283859394055855), ('VOO', 0.0)])
# Current balance = 117063.4030204369
# ------------------------------------
# 2021-08-20 00:00:00 Sell candidates: ['AMD', 'AMZN', 'F', 'GOOG', 'INTC', 'JPM', 'MS', 'NVDA', 'TSLA', 'VOO'] Buy candidates: ['AAPL', 'MSFT']
# Filtered sell candidates: {'AMD': 27.0, 'AMZN': 100, 'F': 100, 'GOOG': 100, 'INTC': 100, 'JPM': 100, 'MS': 100, 'NVDA': 13.0, 'TSLA': 29.0, 'VOO': 100}
# Will sell TSLA and get 9140.610711530639 $ after selling ( 29.0 % )
# Will buy AAPL
# Current weights are OrderedDict([('AAPL', 0.2513548409410537), ('AMD', 0.17443040612790878), ('AMZN', 0.0), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.1501324899863273), ('NVDA', 0.23029918873125824), ('TSLA', 0.19366352897221414), ('VOO', 0.0)])
# Current balance = 115554.72880399844
# ------------------------------------
# 2021-08-27 00:00:00 Sell candidates: ['F'] Buy candidates: ['AAPL', 'AMD', 'AMZN', 'GOOG', 'INTC', 'JPM', 'MS', 'MSFT', 'NVDA', 'TSLA', 'VOO']
# Filtered sell candidates: {'F': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2021-09-03 00:00:00 Sell candidates: [] Buy candidates: ['AAPL', 'AMD', 'AMZN', 'F', 'GOOG', 'INTC', 'JPM', 'MS', 'MSFT', 'NVDA', 'TSLA', 'VOO']
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2021-09-10 00:00:00 Sell candidates: ['AMD', 'F', 'INTC', 'JPM', 'MS', 'MSFT', 'VOO'] Buy candidates: ['AAPL', 'AMZN', 'GOOG', 'NVDA', 'TSLA']
# Filtered sell candidates: {'F': 100, 'INTC': 100, 'JPM': 100, 'MS': 100, 'VOO': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2021-09-17 00:00:00 Sell candidates: ['AAPL', 'AMD', 'AMZN', 'GOOG', 'JPM', 'MS', 'NVDA', 'VOO'] Buy candidates: ['F', 'INTC', 'MSFT', 'TSLA']
# Filtered sell candidates: {'AAPL': 86.0, 'AMZN': 100, 'GOOG': 100, 'JPM': 100, 'MS': 100, 'NVDA': 19.0, 'VOO': 100}
# Will sell AAPL and get 24619.873188476562 $ after selling ( 86.0 % )
# Will buy TSLA
# Current weights are OrderedDict([('AAPL', 0.0337576425229557), ('AMD', 0.16852305323585576), ('AMZN', 0.0), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.143967539414468), ('NVDA', 0.23582164936325367), ('TSLA', 0.41728287189393043), ('VOO', 0.0)])
# Current balance = 118725.3028786708
# ------------------------------------
# 2021-09-24 00:00:00 Sell candidates: ['AAPL', 'AMD', 'AMZN', 'GOOG', 'INTC', 'JPM', 'MS', 'MSFT', 'NVDA', 'TSLA', 'VOO'] Buy candidates: ['F']
# Filtered sell candidates: {'AMZN': 100, 'GOOG': 100, 'INTC': 100, 'JPM': 100, 'MS': 100, 'NVDA': 16.0, 'TSLA': 41.0, 'VOO': 100}
# Will sell TSLA and get 20710.729265366586 $ after selling ( 41.0 % )
# Will buy F
# Current weights are OrderedDict([('AAPL', 0.03351404246437014), ('AMD', 0.16940185050316475), ('AMZN', 0.0), ('F', 0.17274772832182037), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.14184561719143382), ('NVDA', 0.2346731328494945), ('TSLA', 0.24775666175404873), ('VOO', 0.0)])
# Current balance = 120292.40441650273
# ------------------------------------
# 2021-10-01 00:00:00 Sell candidates: ['AAPL', 'AMD', 'AMZN', 'GOOG', 'MS', 'MSFT', 'NVDA', 'VOO'] Buy candidates: ['F', 'INTC', 'JPM', 'TSLA']
# Filtered sell candidates: {'AMZN': 100, 'GOOG': 100, 'MS': 100, 'NVDA': 33.0, 'VOO': 100}
# Will sell NVDA and get 8750.792982422468 $ after selling ( 33.0 % )
# Will buy TSLA
# Current weights are OrderedDict([('AAPL', 0.03321751946841105), ('AMD', 0.1674533958468293), ('AMZN', 0.0), ('F', 0.18120739787480028), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.13984092573034904), ('NVDA', 0.15077162180891823), ('TSLA', 0.32555132655019753), ('VOO', 0.0)])
# Current balance = 117838.8963162026
# ------------------------------------
# 2021-10-08 00:00:00 Sell candidates: ['AAPL', 'AMD', 'AMZN', 'GOOG', 'INTC', 'MS', 'NVDA', 'VOO'] Buy candidates: ['F', 'JPM', 'MSFT', 'TSLA']
# Filtered sell candidates: {'AMZN': 100, 'GOOG': 100, 'INTC': 100, 'MS': 100, 'VOO': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2021-10-15 00:00:00 Sell candidates: ['INTC', 'JPM'] Buy candidates: ['AAPL', 'AMD', 'AMZN', 'F', 'GOOG', 'MS', 'MSFT', 'NVDA', 'TSLA', 'VOO']
# Filtered sell candidates: {'INTC': 100, 'JPM': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2021-10-22 00:00:00 Sell candidates: [] Buy candidates: ['AAPL', 'AMD', 'AMZN', 'F', 'GOOG', 'INTC', 'JPM', 'MS', 'MSFT', 'NVDA', 'TSLA', 'VOO']
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2021-10-29 00:00:00 Sell candidates: ['AMZN', 'INTC'] Buy candidates: ['AAPL', 'AMD', 'F', 'GOOG', 'JPM', 'MS', 'MSFT', 'NVDA', 'TSLA', 'VOO']
# Filtered sell candidates: {'AMZN': 100, 'INTC': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2021-11-05 00:00:00 Sell candidates: ['JPM'] Buy candidates: ['AAPL', 'AMD', 'AMZN', 'F', 'GOOG', 'INTC', 'MS', 'MSFT', 'NVDA', 'TSLA', 'VOO']
# Filtered sell candidates: {'JPM': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2021-11-12 00:00:00 Sell candidates: ['AAPL', 'JPM', 'MS', 'TSLA'] Buy candidates: ['AMD', 'AMZN', 'F', 'GOOG', 'INTC', 'MSFT', 'NVDA', 'VOO']
# Filtered sell candidates: {'AAPL': 72.0, 'JPM': 100, 'MS': 100, 'TSLA': 2.0}
# Will sell AAPL and get 2963.3225405273433 $ after selling ( 72.0 % )
# Will buy AMD
# Current weights are OrderedDict([('AAPL', 0.007266062013851477), ('AMD', 0.19918089249816376), ('AMZN', 0.0), ('F', 0.18540890695826265), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.12101477863384955), ('NVDA', 0.16412811385837986), ('TSLA', 0.3224442561204323), ('VOO', 0.0)])
# Current balance = 158600.79476451245
# ------------------------------------
# 2021-11-19 00:00:00 Sell candidates: ['INTC', 'JPM', 'MS', 'TSLA'] Buy candidates: ['AAPL', 'AMD', 'AMZN', 'F', 'GOOG', 'MSFT', 'NVDA', 'VOO']
# Filtered sell candidates: {'INTC': 100, 'JPM': 100, 'MS': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2021-11-26 00:00:00 Sell candidates: ['GOOG', 'INTC', 'JPM', 'VOO'] Buy candidates: ['AAPL', 'AMD', 'AMZN', 'F', 'MS', 'MSFT', 'NVDA', 'TSLA']
# Filtered sell candidates: {'GOOG': 100, 'INTC': 100, 'JPM': 100, 'VOO': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2021-12-03 00:00:00 Sell candidates: ['AMD', 'AMZN', 'F', 'GOOG', 'INTC', 'JPM', 'MS', 'MSFT', 'TSLA', 'VOO'] Buy candidates: ['AAPL', 'NVDA']
# Filtered sell candidates: {'AMD': 15.0, 'AMZN': 100, 'F': 100, 'GOOG': 100, 'INTC': 100, 'JPM': 100, 'MS': 100, 'VOO': 100}
# Will sell F and get 28863.119079589844 $ after selling ( 100 % )
# Will buy NVDA
# Current weights are OrderedDict([('AAPL', 0.007976696499285068), ('AMD', 0.19733400482457633), ('AMZN', 0.0), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.11810979246841295), ('NVDA', 0.3537333903740244), ('TSLA', 0.32220436920817025), ('VOO', 0.0)])
# Current balance = 155885.2163893572
# ------------------------------------
# 2021-12-10 00:00:00 Sell candidates: ['AMD', 'AMZN', 'JPM', 'NVDA', 'TSLA'] Buy candidates: ['AAPL', 'F', 'GOOG', 'INTC', 'MS', 'MSFT', 'VOO']
# Filtered sell candidates: {'AMD': 51.0, 'AMZN': 100, 'JPM': 100, 'NVDA': 51.0, 'TSLA': 6.0}
# Will sell NVDA and get 27668.781289260765 $ after selling ( 51.0 % )
# Will buy AAPL
# Current weights are OrderedDict([('AAPL', 0.18697018560566167), ('AMD', 0.1907149654946077), ('AMZN', 0.0), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.12582014105099415), ('NVDA', 0.17130890622105438), ('TSLA', 0.32432537827670743), ('VOO', 0.0)])
# Current balance = 155180.08741658676
# ------------------------------------
# 2021-12-17 00:00:00 Sell candidates: ['AMD', 'AMZN', 'GOOG', 'INTC', 'JPM', 'MS', 'MSFT', 'NVDA', 'TSLA'] Buy candidates: ['AAPL', 'F', 'VOO']
# Filtered sell candidates: {'AMD': 34.0, 'AMZN': 100, 'GOOG': 100, 'INTC': 100, 'JPM': 100, 'MS': 100, 'NVDA': 47.0, 'TSLA': 12.0}
# Will sell NVDA and get 11502.600295413149 $ after selling ( 47.0 % )
# Will buy AAPL
# Current weights are OrderedDict([('AAPL', 0.2674967671432427), ('AMD', 0.20111227765345654), ('AMZN', 0.0), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.12614918078889836), ('NVDA', 0.08865572613282663), ('TSLA', 0.3154258845901279), ('VOO', 0.0)])
# Current balance = 146307.72224422937
# ------------------------------------
# 2021-12-31 00:00:00 Sell candidates: ['AMZN'] Buy candidates: ['AAPL', 'AMD', 'F', 'GOOG', 'INTC', 'JPM', 'MS', 'MSFT', 'NVDA', 'TSLA', 'VOO']
# Filtered sell candidates: {'AMZN': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
#
# With strategy final weights are: OrderedDict([('AAPL', 0.2674967671432427), ('AMD', 0.20111227765345654), ('AMZN', 0.0), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.12614918078889836), ('NVDA', 0.08865572613282663), ('TSLA', 0.3154258845901279), ('VOO', 0.0)])
#
# With strategy balance on the end of 2021 would be 156703.31707752252

# %%
high_buy_and_hold = 0
low_buy_and_hold = 1_000_000_000
high_strategy = 0
low_strategy = 1_000_000_000
biggest_delta = 0
biggest_delta_day = ''
final_delta_usd = 0
final_delta_percent = 0

for d in balance_buy_and_hold_dict:
    if balance_buy_and_hold_dict[d] > high_buy_and_hold:
        high_buy_and_hold = balance_buy_and_hold_dict[d]
    if balance_buy_and_hold_dict[d] < low_buy_and_hold:
        low_buy_and_hold = balance_buy_and_hold_dict[d]
    if balance_strategy_dict[d] > high_strategy:
        high_strategy = balance_strategy_dict[d]
    if balance_strategy_dict[d] < low_strategy:
        low_strategy = balance_strategy_dict[d]
    delta = balance_strategy_dict[d] - balance_buy_and_hold_dict[d]
    delta_abs = abs(delta)
    percent = delta_abs / balance_buy_and_hold_dict[d]
    percent_change = percent
    if delta < 0:
        percent_change = -1 * percent_change
    if percent > abs(biggest_delta):
        biggest_delta = percent_change
        biggest_delta_day = d
    final_delta_usd = balance_strategy_dict[d] - balance_buy_and_hold_dict[d]
    final_delta_percent = percent_change
    print(d.strftime('%Y-%m-%d'), '\tBuy and hold balance:\t', "{:.2f}".format(balance_buy_and_hold_dict[d]), 
          '\tStrategy balance:\t', "{:.2f}".format(balance_strategy_dict[d]), 
          '\tDelta:\t', "{:.6f}".format(percent_change))

print('\nhigh_buy_and_hold', high_buy_and_hold)
print('low_buy_and_hold', low_buy_and_hold)
print('\nhigh_strategy', high_strategy)
print('low_strategy', low_strategy)
print('\nbiggest_delta', biggest_delta)
print('biggest_delta_day', biggest_delta_day)
print('\nfinal_delta_usd', final_delta_usd)
print('final_delta_percent', final_delta_percent)
# Out:
# 2021-01-04 	Buy and hold balance:	 100482.50 	Strategy balance:	 100482.50 	Delta:	 0.000000
# 2021-01-05 	Buy and hold balance:	 101666.21 	Strategy balance:	 101666.21 	Delta:	 0.000000
# 2021-01-06 	Buy and hold balance:	 99161.32 	Strategy balance:	 99161.32 	Delta:	 0.000000
# 2021-01-07 	Buy and hold balance:	 104411.65 	Strategy balance:	 104411.65 	Delta:	 0.000000
# 2021-01-08 	Buy and hold balance:	 106137.24 	Strategy balance:	 106137.24 	Delta:	 0.000000
# 2021-01-11 	Buy and hold balance:	 105164.80 	Strategy balance:	 105289.14 	Delta:	 0.001182
# 2021-01-12 	Buy and hold balance:	 105432.30 	Strategy balance:	 105506.63 	Delta:	 0.000705
# 2021-01-13 	Buy and hold balance:	 104951.79 	Strategy balance:	 104892.13 	Delta:	 -0.000569
# 2021-01-14 	Buy and hold balance:	 103350.07 	Strategy balance:	 103294.66 	Delta:	 -0.000536
# 2021-01-15 	Buy and hold balance:	 101049.46 	Strategy balance:	 100950.40 	Delta:	 -0.000980
# 2021-01-19 	Buy and hold balance:	 102438.68 	Strategy balance:	 102473.73 	Delta:	 0.000342
# 2021-01-20 	Buy and hold balance:	 104012.14 	Strategy balance:	 103784.30 	Delta:	 -0.002190
# 2021-01-21 	Buy and hold balance:	 106345.47 	Strategy balance:	 105817.03 	Delta:	 -0.004969
# 2021-01-22 	Buy and hold balance:	 106564.50 	Strategy balance:	 105932.38 	Delta:	 -0.005932
# 2021-01-25 	Buy and hold balance:	 108169.62 	Strategy balance:	 107582.02 	Delta:	 -0.005432
# 2021-01-26 	Buy and hold balance:	 108066.68 	Strategy balance:	 107497.04 	Delta:	 -0.005271
# 2021-01-27 	Buy and hold balance:	 104203.21 	Strategy balance:	 103393.85 	Delta:	 -0.007767
# 2021-01-28 	Buy and hold balance:	 102854.36 	Strategy balance:	 102121.95 	Delta:	 -0.007121
# 2021-01-29 	Buy and hold balance:	 100383.33 	Strategy balance:	 99617.89 	Delta:	 -0.007625
# 2021-02-01 	Buy and hold balance:	 103554.83 	Strategy balance:	 103190.97 	Delta:	 -0.003514
# 2021-02-02 	Buy and hold balance:	 105784.12 	Strategy balance:	 105713.80 	Delta:	 -0.000665
# 2021-02-03 	Buy and hold balance:	 104577.87 	Strategy balance:	 104342.14 	Delta:	 -0.002254
# 2021-02-04 	Buy and hold balance:	 105076.83 	Strategy balance:	 104512.46 	Delta:	 -0.005371
# 2021-02-05 	Buy and hold balance:	 105021.53 	Strategy balance:	 104546.95 	Delta:	 -0.004519
# 2021-02-08 	Buy and hold balance:	 108179.26 	Strategy balance:	 107708.50 	Delta:	 -0.004352
# 2021-02-09 	Buy and hold balance:	 107078.36 	Strategy balance:	 106523.27 	Delta:	 -0.005184
# 2021-02-10 	Buy and hold balance:	 107177.14 	Strategy balance:	 106009.73 	Delta:	 -0.010892
# 2021-02-11 	Buy and hold balance:	 108426.70 	Strategy balance:	 107253.37 	Delta:	 -0.010821
# 2021-02-12 	Buy and hold balance:	 108330.00 	Strategy balance:	 107290.16 	Delta:	 -0.009599
# 2021-02-16 	Buy and hold balance:	 107649.60 	Strategy balance:	 106367.27 	Delta:	 -0.011912
# 2021-02-17 	Buy and hold balance:	 106265.30 	Strategy balance:	 105086.28 	Delta:	 -0.011095
# 2021-02-18 	Buy and hold balance:	 105366.84 	Strategy balance:	 104114.35 	Delta:	 -0.011887
# 2021-02-19 	Buy and hold balance:	 105417.67 	Strategy balance:	 104217.81 	Delta:	 -0.011382
# 2021-02-22 	Buy and hold balance:	 100379.21 	Strategy balance:	 98915.27 	Delta:	 -0.014584
# 2021-02-23 	Buy and hold balance:	 99300.95 	Strategy balance:	 97776.42 	Delta:	 -0.015353
# 2021-02-24 	Buy and hold balance:	 101837.50 	Strategy balance:	 100673.47 	Delta:	 -0.011430
# 2021-02-25 	Buy and hold balance:	 95393.00 	Strategy balance:	 94133.12 	Delta:	 -0.013207
# 2021-02-26 	Buy and hold balance:	 96859.97 	Strategy balance:	 95738.59 	Delta:	 -0.011577
# 2021-03-01 	Buy and hold balance:	 99702.11 	Strategy balance:	 98476.90 	Delta:	 -0.012289
# 2021-03-02 	Buy and hold balance:	 96726.35 	Strategy balance:	 95763.10 	Delta:	 -0.009959
# 2021-03-03 	Buy and hold balance:	 92881.63 	Strategy balance:	 92159.91 	Delta:	 -0.007770
# 2021-03-04 	Buy and hold balance:	 89810.24 	Strategy balance:	 88976.24 	Delta:	 -0.009286
# 2021-03-05 	Buy and hold balance:	 89741.41 	Strategy balance:	 88759.41 	Delta:	 -0.010943
# 2021-03-08 	Buy and hold balance:	 84853.55 	Strategy balance:	 84659.34 	Delta:	 -0.002289
# 2021-03-09 	Buy and hold balance:	 92284.97 	Strategy balance:	 91484.30 	Delta:	 -0.008676
# 2021-03-10 	Buy and hold balance:	 91595.34 	Strategy balance:	 91249.98 	Delta:	 -0.003771
# 2021-03-11 	Buy and hold balance:	 95143.32 	Strategy balance:	 94526.66 	Delta:	 -0.006481
# 2021-03-12 	Buy and hold balance:	 94451.76 	Strategy balance:	 94168.46 	Delta:	 -0.002999
# 2021-03-15 	Buy and hold balance:	 96258.76 	Strategy balance:	 95470.99 	Delta:	 -0.008184
# 2021-03-16 	Buy and hold balance:	 95811.60 	Strategy balance:	 94528.82 	Delta:	 -0.013389
# 2021-03-17 	Buy and hold balance:	 96703.51 	Strategy balance:	 95768.26 	Delta:	 -0.009671
# 2021-03-18 	Buy and hold balance:	 91835.38 	Strategy balance:	 91432.73 	Delta:	 -0.004384
# 2021-03-19 	Buy and hold balance:	 92556.42 	Strategy balance:	 91994.15 	Delta:	 -0.006075
# 2021-03-22 	Buy and hold balance:	 94531.93 	Strategy balance:	 93358.63 	Delta:	 -0.012412
# 2021-03-23 	Buy and hold balance:	 93499.13 	Strategy balance:	 91970.53 	Delta:	 -0.016349
# 2021-03-24 	Buy and hold balance:	 90673.44 	Strategy balance:	 89535.19 	Delta:	 -0.012553
# 2021-03-25 	Buy and hold balance:	 90554.47 	Strategy balance:	 89579.06 	Delta:	 -0.010772
# 2021-03-26 	Buy and hold balance:	 91012.09 	Strategy balance:	 89719.40 	Delta:	 -0.014203
# 2021-03-29 	Buy and hold balance:	 91052.12 	Strategy balance:	 89591.63 	Delta:	 -0.016040
# 2021-03-30 	Buy and hold balance:	 91059.33 	Strategy balance:	 89617.89 	Delta:	 -0.015830
# 2021-03-31 	Buy and hold balance:	 94124.58 	Strategy balance:	 92538.74 	Delta:	 -0.016848
# 2021-04-01 	Buy and hold balance:	 96040.00 	Strategy balance:	 94507.69 	Delta:	 -0.015955
# 2021-04-05 	Buy and hold balance:	 97865.52 	Strategy balance:	 96472.14 	Delta:	 -0.014238
# 2021-04-06 	Buy and hold balance:	 97625.30 	Strategy balance:	 96220.85 	Delta:	 -0.014386
# 2021-04-07 	Buy and hold balance:	 98204.55 	Strategy balance:	 96574.64 	Delta:	 -0.016597
# 2021-04-08 	Buy and hold balance:	 99583.34 	Strategy balance:	 97880.64 	Delta:	 -0.017098
# 2021-04-09 	Buy and hold balance:	 99873.61 	Strategy balance:	 98056.90 	Delta:	 -0.018190
# 2021-04-12 	Buy and hold balance:	 101007.76 	Strategy balance:	 98811.51 	Delta:	 -0.021743
# 2021-04-13 	Buy and hold balance:	 104632.23 	Strategy balance:	 102188.21 	Delta:	 -0.023358
# 2021-04-14 	Buy and hold balance:	 101937.54 	Strategy balance:	 99660.35 	Delta:	 -0.022339
# 2021-04-15 	Buy and hold balance:	 105718.33 	Strategy balance:	 102986.36 	Delta:	 -0.025842
# 2021-04-16 	Buy and hold balance:	 105040.47 	Strategy balance:	 102560.94 	Delta:	 -0.023605
# 2021-04-19 	Buy and hold balance:	 102747.09 	Strategy balance:	 100360.48 	Delta:	 -0.023228
# 2021-04-20 	Buy and hold balance:	 101629.93 	Strategy balance:	 99455.16 	Delta:	 -0.021399
# 2021-04-21 	Buy and hold balance:	 103609.03 	Strategy balance:	 101517.87 	Delta:	 -0.020183
# 2021-04-22 	Buy and hold balance:	 100694.39 	Strategy balance:	 98749.57 	Delta:	 -0.019314
# 2021-04-23 	Buy and hold balance:	 103306.00 	Strategy balance:	 101201.58 	Delta:	 -0.020371
# 2021-04-26 	Buy and hold balance:	 105095.58 	Strategy balance:	 102811.63 	Delta:	 -0.021732
# 2021-04-27 	Buy and hold balance:	 103845.58 	Strategy balance:	 101328.43 	Delta:	 -0.024239
# 2021-04-28 	Buy and hold balance:	 103034.65 	Strategy balance:	 100218.96 	Delta:	 -0.027328
# 2021-04-29 	Buy and hold balance:	 102633.57 	Strategy balance:	 99502.95 	Delta:	 -0.030503
# 2021-04-30 	Buy and hold balance:	 102026.81 	Strategy balance:	 99750.20 	Delta:	 -0.022314
# 2021-05-03 	Buy and hold balance:	 99818.29 	Strategy balance:	 97375.55 	Delta:	 -0.024472
# 2021-05-04 	Buy and hold balance:	 97777.91 	Strategy balance:	 95869.05 	Delta:	 -0.019522
# 2021-05-05 	Buy and hold balance:	 97576.85 	Strategy balance:	 95417.99 	Delta:	 -0.022125
# 2021-05-06 	Buy and hold balance:	 97785.51 	Strategy balance:	 95718.04 	Delta:	 -0.021143
# 2021-05-07 	Buy and hold balance:	 98939.69 	Strategy balance:	 96815.18 	Delta:	 -0.021473
# 2021-05-10 	Buy and hold balance:	 94986.91 	Strategy balance:	 93331.11 	Delta:	 -0.017432
# 2021-05-11 	Buy and hold balance:	 95017.36 	Strategy balance:	 93293.01 	Delta:	 -0.018148
# 2021-05-12 	Buy and hold balance:	 91841.68 	Strategy balance:	 90264.61 	Delta:	 -0.017172
# 2021-05-13 	Buy and hold balance:	 90862.52 	Strategy balance:	 89703.29 	Delta:	 -0.012758
# 2021-05-14 	Buy and hold balance:	 93533.14 	Strategy balance:	 92165.25 	Delta:	 -0.014625
# 2021-05-17 	Buy and hold balance:	 93070.89 	Strategy balance:	 91767.21 	Delta:	 -0.014007
# 2021-05-18 	Buy and hold balance:	 92454.88 	Strategy balance:	 91132.93 	Delta:	 -0.014298
# 2021-05-19 	Buy and hold balance:	 92659.80 	Strategy balance:	 91277.52 	Delta:	 -0.014918
# 2021-05-20 	Buy and hold balance:	 95365.65 	Strategy balance:	 93567.89 	Delta:	 -0.018851
# 2021-05-21 	Buy and hold balance:	 95439.79 	Strategy balance:	 93878.75 	Delta:	 -0.016356
# 2021-05-24 	Buy and hold balance:	 97919.09 	Strategy balance:	 96253.41 	Delta:	 -0.017011
# 2021-05-25 	Buy and hold balance:	 98104.12 	Strategy balance:	 96348.32 	Delta:	 -0.017897
# 2021-05-26 	Buy and hold balance:	 98802.60 	Strategy balance:	 97028.14 	Delta:	 -0.017960
# 2021-05-27 	Buy and hold balance:	 98448.07 	Strategy balance:	 96803.87 	Delta:	 -0.016701
# 2021-05-28 	Buy and hold balance:	 100352.40 	Strategy balance:	 98422.86 	Delta:	 -0.019228
# 2021-06-01 	Buy and hold balance:	 100531.27 	Strategy balance:	 98715.29 	Delta:	 -0.018064
# 2021-06-02 	Buy and hold balance:	 101571.94 	Strategy balance:	 99456.73 	Delta:	 -0.020825
# 2021-06-03 	Buy and hold balance:	 100244.85 	Strategy balance:	 98499.59 	Delta:	 -0.017410
# 2021-06-04 	Buy and hold balance:	 103001.64 	Strategy balance:	 100932.13 	Delta:	 -0.020092
# 2021-06-07 	Buy and hold balance:	 103172.39 	Strategy balance:	 101201.27 	Delta:	 -0.019105
# 2021-06-08 	Buy and hold balance:	 102941.41 	Strategy balance:	 100795.55 	Delta:	 -0.020845
# 2021-06-09 	Buy and hold balance:	 102400.56 	Strategy balance:	 100391.87 	Delta:	 -0.019616
# 2021-06-10 	Buy and hold balance:	 103512.66 	Strategy balance:	 101419.34 	Delta:	 -0.020223
# 2021-06-11 	Buy and hold balance:	 104403.35 	Strategy balance:	 102013.04 	Delta:	 -0.022895
# 2021-06-14 	Buy and hold balance:	 105524.97 	Strategy balance:	 102568.71 	Delta:	 -0.028015
# 2021-06-15 	Buy and hold balance:	 104087.18 	Strategy balance:	 101421.92 	Delta:	 -0.025606
# 2021-06-16 	Buy and hold balance:	 104346.53 	Strategy balance:	 101464.86 	Delta:	 -0.027616
# 2021-06-17 	Buy and hold balance:	 108273.71 	Strategy balance:	 104083.00 	Delta:	 -0.038705
# 2021-06-18 	Buy and hold balance:	 108335.48 	Strategy balance:	 103572.89 	Delta:	 -0.043962
# 2021-06-21 	Buy and hold balance:	 107225.13 	Strategy balance:	 102635.83 	Delta:	 -0.042801
# 2021-06-22 	Buy and hold balance:	 108936.49 	Strategy balance:	 104038.21 	Delta:	 -0.044965
# 2021-06-23 	Buy and hold balance:	 110315.75 	Strategy balance:	 105030.89 	Delta:	 -0.047907
# 2021-06-24 	Buy and hold balance:	 111782.88 	Strategy balance:	 106761.39 	Delta:	 -0.044922
# 2021-06-25 	Buy and hold balance:	 110829.94 	Strategy balance:	 105983.25 	Delta:	 -0.043731
# 2021-06-28 	Buy and hold balance:	 114141.12 	Strategy balance:	 108602.49 	Delta:	 -0.048524
# 2021-06-29 	Buy and hold balance:	 114873.01 	Strategy balance:	 109527.09 	Delta:	 -0.046538
# 2021-06-30 	Buy and hold balance:	 116128.21 	Strategy balance:	 111082.50 	Delta:	 -0.043449
# 2021-07-01 	Buy and hold balance:	 116350.87 	Strategy balance:	 111258.23 	Delta:	 -0.043770
# 2021-07-02 	Buy and hold balance:	 117901.67 	Strategy balance:	 112855.80 	Delta:	 -0.042797
# 2021-07-06 	Buy and hold balance:	 118489.60 	Strategy balance:	 112771.85 	Delta:	 -0.048255
# 2021-07-07 	Buy and hold balance:	 116455.66 	Strategy balance:	 110486.03 	Delta:	 -0.051261
# 2021-07-08 	Buy and hold balance:	 115440.11 	Strategy balance:	 109381.71 	Delta:	 -0.052481
# 2021-07-09 	Buy and hold balance:	 116346.35 	Strategy balance:	 110242.07 	Delta:	 -0.052466
# 2021-07-12 	Buy and hold balance:	 118120.54 	Strategy balance:	 111585.99 	Delta:	 -0.055321
# 2021-07-13 	Buy and hold balance:	 116829.08 	Strategy balance:	 110836.86 	Delta:	 -0.051291
# 2021-07-14 	Buy and hold balance:	 115442.88 	Strategy balance:	 109572.25 	Delta:	 -0.050853
# 2021-07-15 	Buy and hold balance:	 112576.62 	Strategy balance:	 107130.61 	Delta:	 -0.048376
# 2021-07-16 	Buy and hold balance:	 109934.03 	Strategy balance:	 105362.36 	Delta:	 -0.041586
# 2021-07-19 	Buy and hold balance:	 111133.14 	Strategy balance:	 105510.59 	Delta:	 -0.050593
# 2021-07-20 	Buy and hold balance:	 111740.87 	Strategy balance:	 106449.01 	Delta:	 -0.047358
# 2021-07-21 	Buy and hold balance:	 113999.95 	Strategy balance:	 108150.79 	Delta:	 -0.051308
# 2021-07-22 	Buy and hold balance:	 115068.97 	Strategy balance:	 109163.14 	Delta:	 -0.051324
# 2021-07-23 	Buy and hold balance:	 115313.44 	Strategy balance:	 110004.92 	Delta:	 -0.046036
# 2021-07-26 	Buy and hold balance:	 115244.48 	Strategy balance:	 110081.53 	Delta:	 -0.044800
# 2021-07-27 	Buy and hold balance:	 113994.71 	Strategy balance:	 108806.38 	Delta:	 -0.045514
# 2021-07-28 	Buy and hold balance:	 116623.29 	Strategy balance:	 110603.54 	Delta:	 -0.051617
# 2021-07-29 	Buy and hold balance:	 119306.49 	Strategy balance:	 112786.33 	Delta:	 -0.054651
# 2021-07-30 	Buy and hold balance:	 119255.91 	Strategy balance:	 113388.36 	Delta:	 -0.049201
# 2021-08-02 	Buy and hold balance:	 121176.75 	Strategy balance:	 114798.68 	Delta:	 -0.052634
# 2021-08-03 	Buy and hold balance:	 122772.09 	Strategy balance:	 116235.62 	Delta:	 -0.053241
# 2021-08-04 	Buy and hold balance:	 125586.74 	Strategy balance:	 118235.98 	Delta:	 -0.058531
# 2021-08-05 	Buy and hold balance:	 124662.24 	Strategy balance:	 117497.69 	Delta:	 -0.057472
# 2021-08-06 	Buy and hold balance:	 122757.26 	Strategy balance:	 116161.61 	Delta:	 -0.053729
# 2021-08-09 	Buy and hold balance:	 122262.70 	Strategy balance:	 115410.14 	Delta:	 -0.056048
# 2021-08-10 	Buy and hold balance:	 120921.23 	Strategy balance:	 114305.50 	Delta:	 -0.054711
# 2021-08-11 	Buy and hold balance:	 120616.83 	Strategy balance:	 114447.88 	Delta:	 -0.051145
# 2021-08-12 	Buy and hold balance:	 121437.59 	Strategy balance:	 115164.22 	Delta:	 -0.051659
# 2021-08-13 	Buy and hold balance:	 123099.27 	Strategy balance:	 117063.40 	Delta:	 -0.049033
# 2021-08-16 	Buy and hold balance:	 120943.37 	Strategy balance:	 115099.88 	Delta:	 -0.048316
# 2021-08-17 	Buy and hold balance:	 119008.07 	Strategy balance:	 113327.96 	Delta:	 -0.047729
# 2021-08-18 	Buy and hold balance:	 117077.59 	Strategy balance:	 112435.35 	Delta:	 -0.039651
# 2021-08-19 	Buy and hold balance:	 118340.92 	Strategy balance:	 113124.88 	Delta:	 -0.044076
# 2021-08-20 	Buy and hold balance:	 121222.57 	Strategy balance:	 115554.73 	Delta:	 -0.046756
# 2021-08-23 	Buy and hold balance:	 126078.37 	Strategy balance:	 118979.35 	Delta:	 -0.056306
# 2021-08-24 	Buy and hold balance:	 125581.53 	Strategy balance:	 118491.38 	Delta:	 -0.056459
# 2021-08-25 	Buy and hold balance:	 126643.99 	Strategy balance:	 118960.95 	Delta:	 -0.060666
# 2021-08-26 	Buy and hold balance:	 125715.00 	Strategy balance:	 117919.74 	Delta:	 -0.062007
# 2021-08-27 	Buy and hold balance:	 128714.78 	Strategy balance:	 120039.01 	Delta:	 -0.067403
# 2021-08-30 	Buy and hold balance:	 130001.45 	Strategy balance:	 121821.31 	Delta:	 -0.062923
# 2021-08-31 	Buy and hold balance:	 129365.25 	Strategy balance:	 121126.30 	Delta:	 -0.063688
# 2021-09-01 	Buy and hold balance:	 129309.48 	Strategy balance:	 121134.10 	Delta:	 -0.063223
# 2021-09-02 	Buy and hold balance:	 128966.17 	Strategy balance:	 121053.16 	Delta:	 -0.061357
# 2021-09-03 	Buy and hold balance:	 130302.52 	Strategy balance:	 121928.95 	Delta:	 -0.064263
# 2021-09-07 	Buy and hold balance:	 130558.33 	Strategy balance:	 122599.53 	Delta:	 -0.060960
# 2021-09-08 	Buy and hold balance:	 128914.03 	Strategy balance:	 121335.91 	Delta:	 -0.058784
# 2021-09-09 	Buy and hold balance:	 128347.17 	Strategy balance:	 120784.96 	Delta:	 -0.058920
# 2021-09-10 	Buy and hold balance:	 127691.17 	Strategy balance:	 119287.85 	Delta:	 -0.065810
# 2021-09-13 	Buy and hold balance:	 127062.22 	Strategy balance:	 119202.08 	Delta:	 -0.061861
# 2021-09-14 	Buy and hold balance:	 127433.16 	Strategy balance:	 119424.59 	Delta:	 -0.062845
# 2021-09-15 	Buy and hold balance:	 128112.77 	Strategy balance:	 120364.25 	Delta:	 -0.060482
# 2021-09-16 	Buy and hold balance:	 128138.55 	Strategy balance:	 120371.02 	Delta:	 -0.060618
# 2021-09-17 	Buy and hold balance:	 126442.22 	Strategy balance:	 118725.30 	Delta:	 -0.061031
# 2021-09-20 	Buy and hold balance:	 122520.00 	Strategy balance:	 114954.73 	Delta:	 -0.061747
# 2021-09-21 	Buy and hold balance:	 123458.58 	Strategy balance:	 116012.09 	Delta:	 -0.060316
# 2021-09-22 	Buy and hold balance:	 126148.93 	Strategy balance:	 118302.24 	Delta:	 -0.062202
# 2021-09-23 	Buy and hold balance:	 128121.97 	Strategy balance:	 119528.44 	Delta:	 -0.067073
# 2021-09-24 	Buy and hold balance:	 127789.59 	Strategy balance:	 120292.40 	Delta:	 -0.058668
# 2021-09-27 	Buy and hold balance:	 127866.91 	Strategy balance:	 121097.09 	Delta:	 -0.052944
# 2021-09-28 	Buy and hold balance:	 122765.77 	Strategy balance:	 117582.69 	Delta:	 -0.042219
# 2021-09-29 	Buy and hold balance:	 122154.05 	Strategy balance:	 117306.51 	Delta:	 -0.039684
# 2021-09-30 	Buy and hold balance:	 123008.61 	Strategy balance:	 117461.52 	Delta:	 -0.045095
# 2021-10-01 	Buy and hold balance:	 123015.25 	Strategy balance:	 117838.90 	Delta:	 -0.042079
# 2021-10-04 	Buy and hold balance:	 119729.47 	Strategy balance:	 116728.40 	Delta:	 -0.025065
# 2021-10-05 	Buy and hold balance:	 121992.84 	Strategy balance:	 117866.51 	Delta:	 -0.033824
# 2021-10-06 	Buy and hold balance:	 123368.09 	Strategy balance:	 118555.16 	Delta:	 -0.039013
# 2021-10-07 	Buy and hold balance:	 125598.42 	Strategy balance:	 121250.76 	Delta:	 -0.034616
# 2021-10-08 	Buy and hold balance:	 124329.47 	Strategy balance:	 120708.34 	Delta:	 -0.029125
# 2021-10-11 	Buy and hold balance:	 123949.71 	Strategy balance:	 120754.80 	Delta:	 -0.025776
# 2021-10-12 	Buy and hold balance:	 124301.80 	Strategy balance:	 122202.28 	Delta:	 -0.016891
# 2021-10-13 	Buy and hold balance:	 126353.88 	Strategy balance:	 123473.62 	Delta:	 -0.022795
# 2021-10-14 	Buy and hold balance:	 129474.48 	Strategy balance:	 125423.03 	Delta:	 -0.031292
# 2021-10-15 	Buy and hold balance:	 130971.41 	Strategy balance:	 127260.08 	Delta:	 -0.028337
# 2021-10-18 	Buy and hold balance:	 134117.79 	Strategy balance:	 129750.03 	Delta:	 -0.032567
# 2021-10-19 	Buy and hold balance:	 134244.26 	Strategy balance:	 129403.11 	Delta:	 -0.036062
# 2021-10-20 	Buy and hold balance:	 133836.72 	Strategy balance:	 130232.15 	Delta:	 -0.026933
# 2021-10-21 	Buy and hold balance:	 136919.47 	Strategy balance:	 133664.50 	Delta:	 -0.023773
# 2021-10-22 	Buy and hold balance:	 137179.66 	Strategy balance:	 134043.90 	Delta:	 -0.022859
# 2021-10-25 	Buy and hold balance:	 142220.66 	Strategy balance:	 140127.49 	Delta:	 -0.014718
# 2021-10-26 	Buy and hold balance:	 145854.13 	Strategy balance:	 141288.64 	Delta:	 -0.031302
# 2021-10-27 	Buy and hold balance:	 145666.18 	Strategy balance:	 141980.21 	Delta:	 -0.025304
# 2021-10-28 	Buy and hold balance:	 148062.99 	Strategy balance:	 146328.20 	Delta:	 -0.011717
# 2021-10-29 	Buy and hold balance:	 149742.30 	Strategy balance:	 149184.43 	Delta:	 -0.003725
# 2021-11-01 	Buy and hold balance:	 154312.10 	Strategy balance:	 156211.72 	Delta:	 0.012310
# 2021-11-02 	Buy and hold balance:	 155282.13 	Strategy balance:	 155688.83 	Delta:	 0.002619
# 2021-11-03 	Buy and hold balance:	 158183.54 	Strategy balance:	 159512.50 	Delta:	 0.008401
# 2021-11-04 	Buy and hold balance:	 168031.07 	Strategy balance:	 165708.64 	Delta:	 -0.013821
# 2021-11-05 	Buy and hold balance:	 167524.95 	Strategy balance:	 164847.35 	Delta:	 -0.015983
# 2021-11-08 	Buy and hold balance:	 172034.19 	Strategy balance:	 166810.01 	Delta:	 -0.030367
# 2021-11-09 	Buy and hold balance:	 167593.69 	Strategy balance:	 159450.55 	Delta:	 -0.048589
# 2021-11-10 	Buy and hold balance:	 162997.04 	Strategy balance:	 157362.03 	Delta:	 -0.034571
# 2021-11-11 	Buy and hold balance:	 166697.26 	Strategy balance:	 159500.43 	Delta:	 -0.043173
# 2021-11-12 	Buy and hold balance:	 166741.97 	Strategy balance:	 158600.79 	Delta:	 -0.048825
# 2021-11-15 	Buy and hold balance:	 165011.61 	Strategy balance:	 157503.81 	Delta:	 -0.045499
# 2021-11-16 	Buy and hold balance:	 168457.47 	Strategy balance:	 161073.32 	Delta:	 -0.043834
# 2021-11-17 	Buy and hold balance:	 167310.36 	Strategy balance:	 161978.98 	Delta:	 -0.031865
# 2021-11-18 	Buy and hold balance:	 174804.22 	Strategy balance:	 164750.50 	Delta:	 -0.057514
# 2021-11-19 	Buy and hold balance:	 179141.23 	Strategy balance:	 167838.11 	Delta:	 -0.063096
# 2021-11-22 	Buy and hold balance:	 176278.34 	Strategy balance:	 168780.08 	Delta:	 -0.042537
# 2021-11-23 	Buy and hold balance:	 173700.00 	Strategy balance:	 165135.62 	Delta:	 -0.049306
# 2021-11-24 	Buy and hold balance:	 178331.38 	Strategy balance:	 168051.22 	Delta:	 -0.057646
# 2021-11-26 	Buy and hold balance:	 173170.87 	Strategy balance:	 163460.50 	Delta:	 -0.056074
# 2021-11-29 	Buy and hold balance:	 181497.87 	Strategy balance:	 169608.51 	Delta:	 -0.065507
# 2021-11-30 	Buy and hold balance:	 179374.49 	Strategy balance:	 167608.01 	Delta:	 -0.065597
# 2021-12-01 	Buy and hold balance:	 172167.65 	Strategy balance:	 162659.57 	Delta:	 -0.055226
# 2021-12-02 	Buy and hold balance:	 173735.31 	Strategy balance:	 163468.09 	Delta:	 -0.059097
# 2021-12-03 	Buy and hold balance:	 166234.82 	Strategy balance:	 155885.22 	Delta:	 -0.062259
# 2021-12-06 	Buy and hold balance:	 163577.46 	Strategy balance:	 153562.38 	Delta:	 -0.061225
# 2021-12-07 	Buy and hold balance:	 172629.31 	Strategy balance:	 161750.61 	Delta:	 -0.063018
# 2021-12-08 	Buy and hold balance:	 172265.21 	Strategy balance:	 161638.66 	Delta:	 -0.061687
# 2021-12-09 	Buy and hold balance:	 165115.01 	Strategy balance:	 154378.21 	Delta:	 -0.065026
# 2021-12-10 	Buy and hold balance:	 165274.27 	Strategy balance:	 155180.09 	Delta:	 -0.061075
# 2021-12-13 	Buy and hold balance:	 157409.77 	Strategy balance:	 149088.44 	Delta:	 -0.052864
# 2021-12-14 	Buy and hold balance:	 157946.24 	Strategy balance:	 148378.54 	Delta:	 -0.060576
# 2021-12-15 	Buy and hold balance:	 167076.68 	Strategy balance:	 154603.12 	Delta:	 -0.074658
# 2021-12-16 	Buy and hold balance:	 157843.41 	Strategy balance:	 146977.88 	Delta:	 -0.068837
# 2021-12-17 	Buy and hold balance:	 156446.79 	Strategy balance:	 146307.72 	Delta:	 -0.064808
# 2021-12-20 	Buy and hold balance:	 154402.18 	Strategy balance:	 143698.60 	Delta:	 -0.069323
# 2021-12-21 	Buy and hold balance:	 161534.29 	Strategy balance:	 149207.50 	Delta:	 -0.076311
# 2021-12-22 	Buy and hold balance:	 164468.35 	Strategy balance:	 153703.84 	Delta:	 -0.065450
# 2021-12-23 	Buy and hold balance:	 167429.21 	Strategy balance:	 157406.47 	Delta:	 -0.059863
# 2021-12-27 	Buy and hold balance:	 173771.89 	Strategy balance:	 162472.83 	Delta:	 -0.065022
# 2021-12-28 	Buy and hold balance:	 171868.48 	Strategy balance:	 161346.77 	Delta:	 -0.061220
# 2021-12-29 	Buy and hold balance:	 169545.38 	Strategy balance:	 160100.13 	Delta:	 -0.055709
# 2021-12-30 	Buy and hold balance:	 167105.00 	Strategy balance:	 158038.07 	Delta:	 -0.054259
# 2021-12-31 	Buy and hold balance:	 165761.09 	Strategy balance:	 156703.32 	Delta:	 -0.054644
#
# high_buy_and_hold 181497.8702392578
# low_buy_and_hold 84853.55306243896
#
# high_strategy 169608.50528203574
# low_strategy 84659.33910063782
#
# biggest_delta -0.07631063213496764
# biggest_delta_day 2021-12-21 00:00:00
#
# final_delta_usd -9057.771347160102
# final_delta_percent -0.05464353204507166
