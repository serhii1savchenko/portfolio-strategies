# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from math import sqrt
from pypfopt.expected_returns import mean_historical_return
from pypfopt.risk_models import CovarianceShrinkage
from pypfopt.efficient_frontier import EfficientFrontier
from pypfopt.discrete_allocation import get_latest_prices
from dateutil.relativedelta import relativedelta
import copy
import warnings
warnings.filterwarnings('ignore')

tickers = ['AAPL', 'GOOG', 'MSFT', 'AMZN', 'INTC', 'AMD', 'NVDA', 'F', 'TSLA', 'JPM', 'MS', 'VOO']
data_for_portfolio_5y = yf.download(tickers, start='2017-01-01', end='2022-01-01')['Close'].dropna()
data_for_portfolio_5y.tail()
# Out:
# [*********************100%***********************]  12 of 12 completed
#                   AAPL         AMD        AMZN          F        GOOG  \
# Date
# 2021-12-27  180.330002  154.360001  169.669495  20.799999  148.063995
# 2021-12-28  179.289993  153.149994  170.660995  20.760000  146.447998
# 2021-12-29  179.380005  148.259995  169.201004  20.559999  146.504501
# 2021-12-30  178.199997  145.149994  168.644501  20.469999  146.002502
# 2021-12-31  177.570007  143.899994  166.716995  20.770000  144.679504
#
#                  INTC         JPM          MS        MSFT        NVDA  \
# Date
# 2021-12-27  51.939999  158.160004  100.400002  342.450012  309.450012
# 2021-12-28  51.759998  158.639999   99.970001  341.250000  303.220001
# 2021-12-29  51.830002  158.559998   98.730003  341.950012  300.010010
# 2021-12-30  51.740002  158.479996   98.800003  339.320007  295.859985
# 2021-12-31  51.500000  158.350006   98.160004  336.320007  294.109985
#
#                   TSLA         VOO
# Date
# 2021-12-27  364.646667  438.809998
# 2021-12-28  362.823334  438.480011
# 2021-12-29  362.063324  439.010010
# 2021-12-30  356.779999  437.769989
# 2021-12-31  352.260010  436.570007

# %%
# Create initial portfolio
mu = mean_historical_return(data_for_portfolio_5y)
S = CovarianceShrinkage(data_for_portfolio_5y).ledoit_wolf()
ef = EfficientFrontier(mu, S, weight_bounds=(0,1))
weights = ef.max_sharpe()
initial_weights = ef.clean_weights()
print(initial_weights, '\n')

# Initial buy stocks
balance_usd = 100_000
balance_remain = balance_usd
stocks_initial = {}
latest_prices_data_dec_2021 = get_latest_prices(data_for_portfolio_5y)
for ticker in initial_weights:
    to_spend_usd = balance_usd * initial_weights[ticker]
    one_stock_price = latest_prices_data_dec_2021[ticker]
    stocks_number = to_spend_usd // one_stock_price
    stocks_initial[ticker] = stocks_number
    balance_remain = balance_remain - (stocks_number * one_stock_price)
print('Portfolio:', stocks_initial)
print('Remaining balance: USD', balance_remain)
# Out:
# OrderedDict([('AAPL', 0.25899), ('AMD', 0.10384), ('AMZN', 0.0), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.25217), ('NVDA', 0.09699), ('TSLA', 0.288), ('VOO', 0.0)])
#
# Portfolio: {'AAPL': 145.0, 'AMD': 72.0, 'AMZN': 0.0, 'F': 0.0, 'GOOG': 0.0, 'INTC': 0.0, 'JPM': 0.0, 'MS': 0.0, 'MSFT': 74.0, 'NVDA': 32.0, 'TSLA': 81.0, 'VOO': 0.0}
# Remaining balance: USD 1059.2885131835938

# %%
# Calculate MACD, RSI, and S&R signals.
data_2022 = yf.download(tickers, start='2021-12-14', end='2023-01-01')['Close'].dropna()

short_ma = 5                                       # 5 минулих днів для "короткого" МА 
long_ma = 12                                       # 12 минулих днів для "довгого" МА 
rsi_period = 14                                    # RSI рахується за 14 минулих днів 
rsi_oversold = 30                                  # Параметри для індикатора RSI 
rsi_overbought = 70 
sr_sell = 0.7                                      # Параметри для індикатора S&R
sr_buy = 0.3 
start = max(long_ma, rsi_period)

for ticker in data_2022.columns:
    data_2022['MA_' + ticker + str(short_ma)] = data_2022[ticker].rolling(short_ma).mean()
    data_2022['MA_' + ticker + str(long_ma)] = data_2022[ticker].rolling(long_ma).mean() 
    data_2022['return_' + ticker] = data_2022[ticker].pct_change() 
    data_2022['Up_' + ticker] = np.maximum(data_2022[ticker].diff(),0) 
    data_2022['Down_' + ticker] = np.maximum(-data_2022[ticker].diff(),0) 
    data_2022['RS_' + ticker] = data_2022['Up_' + ticker].rolling(rsi_period).mean()/data_2022['Down_' + ticker].rolling(rsi_period).mean() 
    data_2022['RSI_' + ticker] = 100 - 100/(1 + data_2022['RS_' + ticker]) 
    data_2022['S&R_' + ticker] = (data_2022[ticker]/(10**np.floor(np.log10(data_2022[ticker]))))%1 
    data_2022['MACD_signal_' + ticker] = 2*(data_2022['MA_' + ticker + str(short_ma)] > data_2022['MA_' + ticker + str(long_ma)]) -1 
    data_2022['RSI_signal_' + ticker] = 1*(data_2022['RSI_' + ticker] < rsi_oversold) -1*(data_2022['RSI_' + ticker] > rsi_overbought) 
    data_2022['S&R_signal_' + ticker] = 1*(data_2022['S&R_' + ticker] < sr_buy) -1*(data_2022['S&R_' + ticker] > sr_sell) 

data = data_2022.drop(data_2022.index[range(14)])
#print(data.to_string())
data.head(3)
# Out:
# [*********************100%***********************]  12 of 12 completed
#                   AAPL         AMD        AMZN          F        GOOG  \
# Date
# 2022-01-03  182.009995  150.240005  170.404495  21.770000  145.074493
# 2022-01-04  179.699997  144.419998  167.522003  24.309999  144.416504
# 2022-01-05  174.919998  136.149994  164.356995  23.660000  137.653503
#
#                  INTC         JPM          MS        MSFT        NVDA  ...  \
# Date                                                                   ...
# 2022-01-03  53.209999  161.699997  100.190002  334.750000  301.209991  ...
# 2022-01-04  53.139999  167.830002  104.260002  329.010010  292.899994  ...
# 2022-01-05  53.869999  163.779999  101.680000  316.380005  276.040009  ...
#
#               MA_VOO12  return_VOO    Up_VOO  Down_VOO    RS_VOO    RSI_VOO  \
# Date
# 2022-01-03  432.603335    0.006139  2.679993  0.000000  1.549355  60.774396
# 2022-01-04  433.455836   -0.000410  0.000000  0.179993  1.816353  64.493090
# 2022-01-05  433.978335   -0.019154  0.000000  8.410004  0.914027  47.754141
#
#             S&R_VOO  MACD_signal_VOO  RSI_signal_VOO  S&R_signal_VOO
# Date
# 2022-01-03   0.3925                1               0               0
# 2022-01-04   0.3907                1               0               0
# 2022-01-05   0.3066                1               0               0
#
# [3 rows x 144 columns]

# %%
data.tail(3)
# Out:
#                   AAPL        AMD   AMZN      F       GOOG       INTC  \
# Date
# 2022-12-28  126.040001  62.570000  81.82  10.95  86.459999  25.540001
# 2022-12-29  129.610001  64.820000  84.18  11.54  88.949997  26.209999
# 2022-12-30  129.929993  64.769997  84.00  11.63  88.730003  26.430000
#
#                    JPM         MS        MSFT        NVDA  ...    MA_VOO12  \
# Date                                                       ...
# 2022-12-28  132.460007  84.459999  234.529999  140.360001  ...  355.751668
# 2022-12-29  133.220001  85.239998  241.009995  146.029999  ...  354.554169
# 2022-12-30  134.100006  85.019997  239.820007  146.139999  ...  353.050001
#
#             return_VOO    Up_VOO  Down_VOO    RS_VOO    RSI_VOO  S&R_VOO  \
# Date
# 2022-12-28   -0.012269  0.000000  4.299988  0.541579  35.131445   0.4617
# 2022-12-29    0.017737  6.139984  0.000000  0.641064  39.063936   0.5231
# 2022-12-30   -0.002753  0.000000  0.970001  0.675590  40.319512   0.5134
#
#             MACD_signal_VOO  RSI_signal_VOO  S&R_signal_VOO
# Date
# 2022-12-28               -1               0               0
# 2022-12-29               -1               0               0
# 2022-12-30               -1               0               0
#
# [3 rows x 144 columns]

# %%
def check_tickers_for_sell(tickers_sell, now, current_weights):
    ticker_percent_sell = {}
    end_date = now.strftime('%Y-%m-%d')
    start_date = (now - relativedelta(years=5)).strftime('%Y-%m-%d')
    # Get data for all tickers for last 5 years
    data_for_tickers = yf.download(tickers, start_date, end_date, progress=False)['Close'].dropna()
    
    # Generate portfolio on this data
    mu = mean_historical_return(data_for_tickers)
    S = CovarianceShrinkage(data_for_tickers).ledoit_wolf()
    ef = EfficientFrontier(mu, S, weight_bounds=(0,1))
    weights = ef.max_sharpe()
    new_weights = ef.clean_weights()
    
    for ticker in tickers_sell:
        if new_weights[ticker] == 0:
            ticker_percent_sell[ticker] = 100
        elif new_weights[ticker] < current_weights[ticker]:
            delta = current_weights[ticker] - new_weights[ticker]
            sell_percent = (delta * 100) // current_weights[ticker]
            ticker_percent_sell[ticker] = sell_percent
    return ticker_percent_sell

# %%
def select_ticker_for_sell(data, date, filtered_sell_tickers_with_percents, stocks_current):
    sell_ticker = ''
    sell_profit = 0
    stocks_to_sell = 0
    for ticker in filtered_sell_tickers_with_percents:
        no_of_stocks = stocks_current[ticker]
        #print(ticker, 'no_of_stocks', no_of_stocks)
        cur_price = data[ticker][date]
        #print(ticker, 'cur_price', cur_price)
        sell_percent = (filtered_sell_tickers_with_percents[ticker] / 100)
        #print(ticker, 'sell_percent', sell_percent)
        potentail_profit = no_of_stocks * cur_price * sell_percent
        #print(ticker, 'potentail_profit', potentail_profit)
        if potentail_profit > sell_profit:
            sell_profit = potentail_profit
            sell_ticker = ticker
            stocks_to_sell = no_of_stocks * sell_percent
    return [sell_ticker, sell_profit, stocks_to_sell]

# %%
def select_ticker_for_buy(tickers_buy, now):
    if len(tickers_buy) == 1:
        return tickers_buy[0]
    end_date = now.strftime('%Y-%m-%d')
    start_date = (now - relativedelta(years=5)).strftime('%Y-%m-%d')
    # Get data for all tickers for last 5 years period
    data_for_tickers_last_year = yf.download(tickers_buy, start_date, end_date, progress=False)['Close'].dropna()
    ticker_percent_delta = {}
    for t in tickers_buy:
        first_price = data_for_tickers_last_year[t][0]
        last_price = data_for_tickers_last_year[t][len(data_for_tickers_last_year[t]) - 1]
        delta = last_price - first_price
        delta_abs = abs(delta)
        percent = (delta_abs * 100) / first_price
        if delta > 0:
            ticker_percent_delta[t] = percent
        else:
            ticker_percent_delta[t] = -1 * percent
    sorted_by_delta = dict(sorted(ticker_percent_delta.items(), key=lambda x:x[1], reverse=True))
    return list(sorted_by_delta.keys())[0]

# %%
print('Start weights:', initial_weights)
clean_result = balance_remain
for stock in initial_weights:
    clean_result = clean_result + (stocks_initial[stock] * data[stock][len(data[stock]) - 1])
print('Without any changes balance on the end of 2022 would be', clean_result)
print('------------------------------------')
# Out:
# Start weights: OrderedDict([('AAPL', 0.25899), ('AMD', 0.10384), ('AMZN', 0.0), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.25217), ('NVDA', 0.09699), ('TSLA', 0.288), ('VOO', 0.0)])
# Without any changes balance on the end of 2022 would be 56963.31775665283
# ------------------------------------

# %%
strategy = 'S&R_signal_'                  # MACD_signal_        or        RSI_signal_        or        S&R_signal_
strategy_weights = copy.deepcopy(initial_weights)
stocks_strategy = copy.deepcopy(stocks_initial)
balance_strategy = balance_remain

balance_buy_and_hold_dict = {}
balance_strategy_dict = {}

for d in data.index: 
    if d.weekday() == 4:                   # every Friday
        tickers_sell = []
        tickers_buy = []
        for t in strategy_weights:
            if data[strategy + t][d] == -1:
                tickers_sell.append(t)
            if data[strategy + t][d] == 1:
                tickers_buy.append(t)
        print(d, 'Sell candidates:', tickers_sell, 'Buy candidates:', tickers_buy)
        if len(tickers_sell) > 0 and len(tickers_buy) > 0:
            filtered_sell_tickers_with_percents = check_tickers_for_sell(tickers_sell, d, strategy_weights)
            print('Filtered sell candidates:', filtered_sell_tickers_with_percents)
            if len(filtered_sell_tickers_with_percents) > 0:
                ticker_for_sell_data = select_ticker_for_sell(data, d, filtered_sell_tickers_with_percents, stocks_strategy)
                will_receive_usd = ticker_for_sell_data[1]
                # If this ticker is present in current portfolio
                if will_receive_usd > 0:
                    ticker_for_sell = ticker_for_sell_data[0]
                    stocks_to_sell = ticker_for_sell_data[2]
                    sell_percents = filtered_sell_tickers_with_percents[ticker_for_sell]
                    ticker_for_buy = select_ticker_for_buy(tickers_buy, d)
                    # If we can buy other ticker on that money
                    if (will_receive_usd + balance_strategy) > data[ticker_for_buy][d]:
                        print('Will sell',ticker_for_sell,'and get',will_receive_usd,'$ after selling (',sell_percents,'% )')
                        print('Will buy', ticker_for_buy)
                        # Sell percent of ticker_for_sell and add that money to balance
                        stocks_strategy[ticker_for_sell] = stocks_strategy[ticker_for_sell] - stocks_to_sell
                        balance_strategy = balance_strategy + will_receive_usd
                        # Buy ticker_for_buy on all balance
                        no_of_buy_stocks = balance_strategy // data[ticker_for_buy][d]
                        stocks_strategy[ticker_for_buy] = stocks_strategy[ticker_for_buy] + no_of_buy_stocks
                        balance_strategy = balance_strategy - (data[ticker_for_buy][d] * no_of_buy_stocks)
                        # Recalculate new weights for all portfolio
                        # calculate all prices for now + balance - потом высчитать сколько в процентах сейчас каждый ФИ
                        cur_balance = balance_strategy
                        stock_usd = {}
                        for stock in stocks_strategy:
                            stock_usd[stock] = stocks_strategy[stock] * data[stock][d]
                            cur_balance = cur_balance + stock_usd[stock]
                        for stock in stocks_strategy:
                            strategy_weights[stock] = stock_usd[stock] / cur_balance
                        print('Current weights are', strategy_weights)
                        print('Current balance =', cur_balance)
                    else:
                        print("No changes because sell profit is not enough for buying at least one stock.")
                else:
                    print("No changes because all sell candidates are not present in current portfolio.")
            else:
                print("No changes because all sell candidates failed check.")
        else:
            print("No changes because no sell candidates or no buy candidates.")
        print('------------------------------------')
    # Calculate current balance for stocks_initial
    today_balance_buy_and_hold = balance_remain
    for stock in stocks_initial:
        today_balance_buy_and_hold = today_balance_buy_and_hold + (data[stock][d] * stocks_initial[stock])
    balance_buy_and_hold_dict[d] = today_balance_buy_and_hold
    # Calculate current balance for stocks_strategy
    today_balance_strategy = balance_strategy
    for stock in stocks_strategy:
        today_balance_strategy = today_balance_strategy + (data[stock][d] * stocks_strategy[stock])
    balance_strategy_dict[d] = today_balance_strategy

print('\nWith strategy final weights are:', strategy_weights)        
clean_result = balance_strategy
for stock in strategy_weights:
    clean_result = clean_result + (stocks_strategy[stock] * data[stock][len(data[stock]) - 1])
print('\nWith strategy balance on the end of 2022 would be', clean_result)
# Out:
# 2022-01-07 00:00:00 Sell candidates: ['AAPL', 'NVDA'] Buy candidates: ['MS', 'MSFT', 'VOO']
# Filtered sell candidates: {}
# No changes because all sell candidates failed check.
# ------------------------------------
# 2022-01-14 00:00:00 Sell candidates: ['AAPL', 'MS'] Buy candidates: ['MSFT', 'VOO']
# Filtered sell candidates: {'MS': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2022-01-21 00:00:00 Sell candidates: ['MS', 'MSFT'] Buy candidates: ['AMD', 'F', 'INTC', 'TSLA', 'VOO']
# Filtered sell candidates: {'MS': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2022-01-28 00:00:00 Sell candidates: ['AAPL', 'F', 'INTC', 'TSLA'] Buy candidates: ['AMD', 'MS', 'MSFT', 'NVDA', 'VOO']
# Filtered sell candidates: {'F': 100, 'INTC': 100, 'TSLA': 11.0}
# Will sell TSLA and get 2513.6595181274415 $ after selling ( 11.0 % )
# Will buy AMD
# Current weights are OrderedDict([('AAPL', 0.2861663872259712), ('AMD', 0.12803526274320912), ('AMZN', 0.0), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.26430682328908206), ('NVDA', 0.08468481315504142), ('TSLA', 0.23564771876701102), ('VOO', 0.0)])
# Current balance = 86305.9093170166
# ------------------------------------
# 2022-02-04 00:00:00 Sell candidates: ['AAPL', 'F', 'INTC'] Buy candidates: ['AMD', 'MS', 'MSFT', 'TSLA', 'VOO']
# Filtered sell candidates: {'F': 100, 'INTC': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2022-02-11 00:00:00 Sell candidates: ['F', 'INTC', 'MSFT', 'TSLA'] Buy candidates: ['AMD', 'MS', 'VOO']
# Filtered sell candidates: {'F': 100, 'INTC': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2022-02-18 00:00:00 Sell candidates: ['F', 'MSFT', 'TSLA', 'VOO'] Buy candidates: ['AMD']
# Filtered sell candidates: {'F': 100, 'VOO': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2022-02-25 00:00:00 Sell candidates: ['F', 'INTC', 'MSFT'] Buy candidates: ['AMD', 'VOO']
# Filtered sell candidates: {'F': 100, 'INTC': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2022-03-04 00:00:00 Sell candidates: ['INTC', 'MSFT', 'TSLA', 'VOO'] Buy candidates: ['AMD', 'NVDA']
# Filtered sell candidates: {'INTC': 100, 'VOO': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2022-03-11 00:00:00 Sell candidates: ['MSFT', 'VOO'] Buy candidates: ['AMD', 'JPM', 'NVDA']
# Filtered sell candidates: {'VOO': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2022-03-18 00:00:00 Sell candidates: ['INTC'] Buy candidates: ['AMD', 'MSFT', 'TSLA', 'VOO']
# Filtered sell candidates: {'INTC': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2022-03-25 00:00:00 Sell candidates: ['AAPL', 'NVDA'] Buy candidates: ['AMD', 'INTC', 'MS', 'MSFT', 'VOO']
# Filtered sell candidates: {'AAPL': 31.0}
# Will sell AAPL and get 7853.6640548706055 $ after selling ( 31.0 % )
# Will buy AMD
# Current weights are OrderedDict([('AAPL', 0.18672166446200872), ('AMD', 0.21858300280231366), ('AMZN', 0.0), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.24003959925971335), ('NVDA', 0.09465407492006961), ('TSLA', 0.25940912767396), ('VOO', 0.0)])
# Current balance = 93619.21752624512
# ------------------------------------
# 2022-04-01 00:00:00 Sell candidates: ['AAPL', 'INTC'] Buy candidates: ['AMD', 'MSFT', 'VOO']
# Filtered sell candidates: {'AAPL': 1.0, 'INTC': 100}
# Will sell AAPL and get 174.39715255737306 $ after selling ( 1.0 % )
# Will buy AMD
# Current weights are OrderedDict([('AAPL', 0.1846492986652916), ('AMD', 0.20017337508898733), ('AMZN', 0.0), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.2448799333840007), ('NVDA', 0.09141752401080705), ('TSLA', 0.2787356020098419), ('VOO', 0.0)])
# Current balance = 93503.29640014649
# ------------------------------------
# 2022-04-08 00:00:00 Sell candidates: ['AAPL', 'INTC', 'MSFT'] Buy candidates: ['AMD', 'VOO']
# Filtered sell candidates: {'INTC': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2022-04-22 00:00:00 Sell candidates: ['AMD', 'MSFT', 'NVDA', 'VOO'] Buy candidates: ['GOOG', 'JPM']
# Filtered sell candidates: {'AMD': 93.0, 'VOO': 100}
# Will sell AMD and get 14180.844501800539 $ after selling ( 93.0 % )
# Will buy GOOG
# Current weights are OrderedDict([('AAPL', 0.1955217681481632), ('AMD', 0.013022919552303386), ('AMZN', 0.0), ('F', 0.0), ('GOOG', 0.1722087390763233), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.24741213670114062), ('NVDA', 0.07619205580327974), ('TSLA', 0.29466774859324957), ('VOO', 0.0)])
# Current balance = 81961.29818062592
# ------------------------------------
# 2022-04-29 00:00:00 Sell candidates: ['MSFT', 'NVDA', 'TSLA', 'VOO'] Buy candidates: ['AMZN', 'GOOG', 'JPM', 'MS']
# Filtered sell candidates: {'TSLA': 9.0, 'VOO': 100}
# Will sell TSLA and get 1883.1926071197508 $ after selling ( 9.0 % )
# Will buy AMZN
# Current weights are OrderedDict([('AAPL', 0.20098633462334645), ('AMD', 0.013330059947618893), ('AMZN', 0.023994849800266733), ('F', 0.0), ('GOOG', 0.17461180390828102), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.2643298890023128), ('NVDA', 0.07639130643883031), ('TSLA', 0.2450834062602201), ('VOO', 0.0)])
# Current balance = 77692.61079223633
# ------------------------------------
# 2022-05-06 00:00:00 Sell candidates: ['MSFT', 'NVDA', 'TSLA', 'VOO'] Buy candidates: ['AMZN', 'GOOG', 'JPM']
# Filtered sell candidates: {'NVDA': 100, 'VOO': 100}
# Will sell NVDA and get 5976.0 $ after selling ( 100 % )
# Will buy GOOG
# Current weights are OrderedDict([('AAPL', 0.2011769210226589), ('AMD', 0.014909794114296014), ('AMZN', 0.022232150289316476), ('F', 0.0), ('GOOG', 0.25391274201652575), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.26253680495744874), ('NVDA', 0.0), ('TSLA', 0.2444498924318839), ('VOO', 0.0)])
# Current balance = 77436.84096514893
# ------------------------------------
# 2022-05-13 00:00:00 Sell candidates: ['NVDA'] Buy candidates: ['AMZN', 'GOOG', 'JPM', 'MS']
# Filtered sell candidates: {'NVDA': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2022-05-20 00:00:00 Sell candidates: ['MS'] Buy candidates: ['AMZN', 'F', 'GOOG', 'INTC', 'JPM', 'TSLA']
# Filtered sell candidates: {'MS': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2022-05-27 00:00:00 Sell candidates: ['MSFT', 'NVDA', 'VOO'] Buy candidates: ['AMD', 'AMZN', 'GOOG']
# Filtered sell candidates: {'NVDA': 100, 'VOO': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2022-06-03 00:00:00 Sell candidates: ['MSFT', 'NVDA', 'VOO'] Buy candidates: ['AMD', 'AMZN', 'GOOG']
# Filtered sell candidates: {'NVDA': 100, 'VOO': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2022-06-10 00:00:00 Sell candidates: ['INTC', 'MS'] Buy candidates: ['AMZN', 'F', 'GOOG', 'JPM']
# Filtered sell candidates: {'INTC': 100, 'MS': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2022-06-17 00:00:00 Sell candidates: [] Buy candidates: ['AMD', 'AMZN', 'F', 'GOOG', 'JPM', 'MS', 'TSLA']
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-06-24 00:00:00 Sell candidates: ['AMD', 'INTC', 'MS', 'NVDA'] Buy candidates: ['AMZN', 'F', 'GOOG', 'JPM']
# Filtered sell candidates: {'INTC': 100, 'MS': 100, 'NVDA': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2022-07-01 00:00:00 Sell candidates: [] Buy candidates: ['AMZN', 'F', 'GOOG', 'JPM', 'TSLA']
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-07-08 00:00:00 Sell candidates: ['AMD', 'INTC'] Buy candidates: ['AMZN', 'F', 'GOOG', 'JPM']
# Filtered sell candidates: {'INTC': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2022-07-15 00:00:00 Sell candidates: ['INTC', 'MS'] Buy candidates: ['AMD', 'AMZN', 'F', 'GOOG', 'JPM']
# Filtered sell candidates: {'INTC': 100, 'MS': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2022-07-22 00:00:00 Sell candidates: ['AMD', 'INTC', 'NVDA', 'TSLA'] Buy candidates: ['AMZN', 'F', 'GOOG', 'JPM', 'MS']
# Filtered sell candidates: {'INTC': 100, 'NVDA': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2022-07-29 00:00:00 Sell candidates: ['MSFT', 'NVDA', 'TSLA', 'VOO'] Buy candidates: ['GOOG', 'JPM']
# Filtered sell candidates: {'NVDA': 100, 'VOO': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2022-08-05 00:00:00 Sell candidates: ['MSFT', 'NVDA', 'TSLA', 'VOO'] Buy candidates: ['AMD', 'GOOG', 'JPM']
# Filtered sell candidates: {'NVDA': 100, 'VOO': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2022-08-12 00:00:00 Sell candidates: ['AAPL', 'MSFT', 'NVDA', 'VOO'] Buy candidates: ['AMD', 'GOOG', 'JPM', 'MS', 'TSLA']
# Filtered sell candidates: {'NVDA': 100, 'VOO': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2022-08-19 00:00:00 Sell candidates: ['AAPL', 'MSFT', 'NVDA', 'TSLA', 'VOO'] Buy candidates: ['GOOG', 'JPM', 'MS']
# Filtered sell candidates: {'NVDA': 100, 'VOO': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2022-08-26 00:00:00 Sell candidates: ['TSLA', 'VOO'] Buy candidates: ['AMD', 'GOOG', 'JPM']
# Filtered sell candidates: {'VOO': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2022-09-02 00:00:00 Sell candidates: ['TSLA'] Buy candidates: ['AMD', 'AMZN', 'GOOG', 'INTC', 'JPM']
# Filtered sell candidates: {}
# No changes because all sell candidates failed check.
# ------------------------------------
# 2022-09-09 00:00:00 Sell candidates: ['MS', 'TSLA', 'VOO'] Buy candidates: ['GOOG', 'INTC', 'JPM']
# Filtered sell candidates: {'MS': 100, 'VOO': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2022-09-16 00:00:00 Sell candidates: ['INTC', 'MS'] Buy candidates: ['AMZN', 'GOOG', 'JPM', 'TSLA']
# Filtered sell candidates: {'INTC': 100, 'MS': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2022-09-23 00:00:00 Sell candidates: ['AMD', 'GOOG', 'INTC', 'TSLA'] Buy candidates: ['AMZN', 'F', 'JPM', 'MS', 'NVDA']
# Filtered sell candidates: {'GOOG': 100, 'INTC': 100}
# Will sell GOOG and get 16858.899688720703 $ after selling ( 100 % )
# Will buy NVDA
# Current weights are OrderedDict([('AAPL', 0.2128044895017863), ('AMD', 0.011754159279968857), ('AMZN', 0.024375371749433918), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.25145294800005813), ('NVDA', 0.24132004615398112), ('TSLA', 0.2579669063538614), ('VOO', 0.0)])
# Current balance = 70017.39293387756
# ------------------------------------
# 2022-09-30 00:00:00 Sell candidates: ['MS'] Buy candidates: ['AMZN', 'F', 'JPM', 'NVDA', 'VOO']
# Filtered sell candidates: {'MS': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2022-10-07 00:00:00 Sell candidates: ['AMD', 'GOOG', 'MS'] Buy candidates: ['AMZN', 'F', 'JPM', 'NVDA', 'TSLA']
# Filtered sell candidates: {'GOOG': 100, 'MS': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2022-10-14 00:00:00 Sell candidates: ['GOOG'] Buy candidates: ['AMZN', 'F', 'JPM', 'MSFT', 'NVDA', 'TSLA', 'VOO']
# Filtered sell candidates: {'GOOG': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2022-10-21 00:00:00 Sell candidates: ['AMD', 'MS'] Buy candidates: ['AMZN', 'F', 'GOOG', 'JPM', 'NVDA', 'TSLA']
# Filtered sell candidates: {'AMD': 100, 'MS': 100}
# Will sell AMD and get 712.3101963043205 $ after selling ( 100 % )
# Will buy TSLA
# Current weights are OrderedDict([('AAPL', 0.22126483978145808), ('AMD', 0.0), ('AMZN', 0.027148780313190023), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.2717741817254742), ('NVDA', 0.25527408277975283), ('TSLA', 0.2231453124671351), ('VOO', 0.0)])
# Current balance = 65925.61340786285
# ------------------------------------
# 2022-10-28 00:00:00 Sell candidates: ['INTC'] Buy candidates: ['AMD', 'AMZN', 'JPM', 'MS', 'TSLA']
# Filtered sell candidates: {'INTC': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2022-11-04 00:00:00 Sell candidates: ['INTC'] Buy candidates: ['AMD', 'AMZN', 'MSFT', 'TSLA']
# Filtered sell candidates: {'INTC': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2022-11-11 00:00:00 Sell candidates: ['TSLA'] Buy candidates: ['AMD', 'AMZN', 'INTC', 'MS']
# Filtered sell candidates: {}
# No changes because all sell candidates failed check.
# ------------------------------------
# 2022-11-18 00:00:00 Sell candidates: ['GOOG', 'INTC', 'MS', 'TSLA'] Buy candidates: []
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-11-25 00:00:00 Sell candidates: ['GOOG', 'INTC', 'TSLA'] Buy candidates: ['MS']
# Filtered sell candidates: {'GOOG': 100, 'INTC': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2022-12-02 00:00:00 Sell candidates: ['INTC', 'TSLA', 'VOO'] Buy candidates: ['GOOG', 'MS']
# Filtered sell candidates: {'INTC': 100, 'VOO': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2022-12-09 00:00:00 Sell candidates: ['AMD', 'AMZN', 'INTC', 'MS', 'NVDA', 'TSLA'] Buy candidates: []
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-12-16 00:00:00 Sell candidates: ['AMZN'] Buy candidates: ['F', 'GOOG', 'JPM']
# Filtered sell candidates: {'AMZN': 100}
# Will sell AMZN and get 1317.9000091552734 $ after selling ( 100 % )
# Will buy GOOG
# Current weights are OrderedDict([('AAPL', 0.2033545424961942), ('AMD', 0.0), ('AMZN', 0.0), ('F', 0.0), ('GOOG', 0.02080228441894453), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.2763725976512233), ('NVDA', 0.34145190411774107), ('TSLA', 0.15730402474053135), ('VOO', 0.0)])
# Current balance = 65516.84332871094
# ------------------------------------
# 2022-12-23 00:00:00 Sell candidates: ['GOOG'] Buy candidates: ['F', 'TSLA']
# Filtered sell candidates: {'GOOG': 100}
# Will sell GOOG and get 1347.1499633789062 $ after selling ( 100 % )
# Will buy TSLA
# Current weights are OrderedDict([('AAPL', 0.2137690822351617), ('AMD', 0.0), ('AMZN', 0.0), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.28914670107136864), ('NVDA', 0.3359914913031416), ('TSLA', 0.1604491376269087), ('VOO', 0.0)])
# Current balance = 61097.08192547379
# ------------------------------------
# 2022-12-30 00:00:00 Sell candidates: ['GOOG'] Buy candidates: ['AAPL', 'F', 'TSLA']
# Filtered sell candidates: {'GOOG': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
#
# With strategy final weights are: OrderedDict([('AAPL', 0.2137690822351617), ('AMD', 0.0), ('AMZN', 0.0), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.28914670107136864), ('NVDA', 0.3359914913031416), ('TSLA', 0.1604491376269087), ('VOO', 0.0)])
#
# With strategy balance on the end of 2022 would be 60189.764669734956

# %%
high_buy_and_hold = 0
low_buy_and_hold = 1_000_000_000
high_strategy = 0
low_strategy = 1_000_000_000
biggest_delta = 0
biggest_delta_day = ''
final_delta_usd = 0
final_delta_percent = 0

for d in balance_buy_and_hold_dict:
    if balance_buy_and_hold_dict[d] > high_buy_and_hold:
        high_buy_and_hold = balance_buy_and_hold_dict[d]
    if balance_buy_and_hold_dict[d] < low_buy_and_hold:
        low_buy_and_hold = balance_buy_and_hold_dict[d]
    if balance_strategy_dict[d] > high_strategy:
        high_strategy = balance_strategy_dict[d]
    if balance_strategy_dict[d] < low_strategy:
        low_strategy = balance_strategy_dict[d]
    delta = balance_strategy_dict[d] - balance_buy_and_hold_dict[d]
    delta_abs = abs(delta)
    percent = delta_abs / balance_buy_and_hold_dict[d]
    percent_change = percent
    if delta < 0:
        percent_change = -1 * percent_change
    if percent > abs(biggest_delta):
        biggest_delta = percent_change
        biggest_delta_day = d
    final_delta_usd = balance_strategy_dict[d] - balance_buy_and_hold_dict[d]
    final_delta_percent = percent_change
    print(d.strftime('%Y-%m-%d'), '\tBuy and hold balance:\t', "{:.2f}".format(balance_buy_and_hold_dict[d]), 
          '\tStrategy balance:\t', "{:.2f}".format(balance_strategy_dict[d]), 
          '\tDelta:\t', "{:.6f}".format(percent_change))

print('\nhigh_buy_and_hold', high_buy_and_hold)
print('low_buy_and_hold', low_buy_and_hold)
print('\nhigh_strategy', high_strategy)
print('low_strategy', low_strategy)
print('\nbiggest_delta', biggest_delta)
print('biggest_delta_day', biggest_delta_day)
print('\nfinal_delta_usd', final_delta_usd)
print('final_delta_percent', final_delta_percent)
# Out:
# 2022-01-03 	Buy and hold balance:	 105072.30 	Strategy balance:	 105072.30 	Delta:	 0.000000
# 2022-01-04 	Buy and hold balance:	 102272.50 	Strategy balance:	 102272.50 	Delta:	 0.000000
# 2022-01-05 	Buy and hold balance:	 97850.13 	Strategy balance:	 97850.13 	Delta:	 0.000000
# 2022-01-06 	Buy and hold balance:	 96798.83 	Strategy balance:	 96798.83 	Delta:	 0.000000
# 2022-01-07 	Buy and hold balance:	 95213.86 	Strategy balance:	 95213.86 	Delta:	 0.000000
# 2022-01-10 	Buy and hold balance:	 96124.06 	Strategy balance:	 96124.06 	Delta:	 0.000000
# 2022-01-11 	Buy and hold balance:	 97280.97 	Strategy balance:	 97280.97 	Delta:	 0.000000
# 2022-01-12 	Buy and hold balance:	 98788.58 	Strategy balance:	 98788.58 	Delta:	 0.000000
# 2022-01-13 	Buy and hold balance:	 94495.44 	Strategy balance:	 94495.44 	Delta:	 0.000000
# 2022-01-14 	Buy and hold balance:	 95925.51 	Strategy balance:	 95925.51 	Delta:	 0.000000
# 2022-01-18 	Buy and hold balance:	 93688.08 	Strategy balance:	 93688.08 	Delta:	 0.000000
# 2022-01-19 	Buy and hold balance:	 91748.49 	Strategy balance:	 91748.49 	Delta:	 0.000000
# 2022-01-20 	Buy and hold balance:	 90635.01 	Strategy balance:	 90635.01 	Delta:	 0.000000
# 2022-01-21 	Buy and hold balance:	 88034.26 	Strategy balance:	 88034.26 	Delta:	 0.000000
# 2022-01-24 	Buy and hold balance:	 87404.77 	Strategy balance:	 87404.77 	Delta:	 0.000000
# 2022-01-25 	Buy and hold balance:	 85517.49 	Strategy balance:	 85517.49 	Delta:	 0.000000
# 2022-01-26 	Buy and hold balance:	 86739.11 	Strategy balance:	 86739.11 	Delta:	 0.000000
# 2022-01-27 	Buy and hold balance:	 83129.33 	Strategy balance:	 83129.33 	Delta:	 0.000000
# 2022-01-28 	Buy and hold balance:	 86305.91 	Strategy balance:	 86305.91 	Delta:	 0.000000
# 2022-01-31 	Buy and hold balance:	 90767.87 	Strategy balance:	 90796.80 	Delta:	 0.000319
# 2022-02-01 	Buy and hold balance:	 90662.05 	Strategy balance:	 90790.72 	Delta:	 0.001419
# 2022-02-02 	Buy and hold balance:	 91121.11 	Strategy balance:	 91523.12 	Delta:	 0.004412
# 2022-02-03 	Buy and hold balance:	 88792.19 	Strategy balance:	 89148.88 	Delta:	 0.004017
# 2022-02-04 	Buy and hold balance:	 90306.32 	Strategy balance:	 90683.60 	Delta:	 0.004178
# 2022-02-07 	Buy and hold balance:	 89535.67 	Strategy balance:	 89962.72 	Delta:	 0.004770
# 2022-02-08 	Buy and hold balance:	 91108.20 	Strategy balance:	 91642.19 	Delta:	 0.005861
# 2022-02-09 	Buy and hold balance:	 92924.23 	Strategy balance:	 93580.98 	Delta:	 0.007068
# 2022-02-10 	Buy and hold balance:	 90134.78 	Strategy balance:	 90639.41 	Delta:	 0.005599
# 2022-02-11 	Buy and hold balance:	 86377.69 	Strategy balance:	 86599.17 	Delta:	 0.002564
# 2022-02-14 	Buy and hold balance:	 87015.29 	Strategy balance:	 87225.93 	Delta:	 0.002421
# 2022-02-15 	Buy and hold balance:	 90478.47 	Strategy balance:	 90788.10 	Delta:	 0.003422
# 2022-02-16 	Buy and hold balance:	 90130.77 	Strategy balance:	 90312.81 	Delta:	 0.002020
# 2022-02-17 	Buy and hold balance:	 86655.24 	Strategy balance:	 86801.43 	Delta:	 0.001687
# 2022-02-18 	Buy and hold balance:	 85524.27 	Strategy balance:	 85776.17 	Delta:	 0.002945
# 2022-02-22 	Buy and hold balance:	 84169.88 	Strategy balance:	 84587.12 	Delta:	 0.004957
# 2022-02-23 	Buy and hold balance:	 80705.06 	Strategy balance:	 81098.68 	Delta:	 0.004877
# 2022-02-24 	Buy and hold balance:	 84072.32 	Strategy balance:	 84582.90 	Delta:	 0.006073
# 2022-02-25 	Buy and hold balance:	 85276.53 	Strategy balance:	 85906.93 	Delta:	 0.007392
# 2022-02-28 	Buy and hold balance:	 87297.44 	Strategy balance:	 87823.22 	Delta:	 0.006023
# 2022-03-01 	Buy and hold balance:	 85595.98 	Strategy balance:	 85825.93 	Delta:	 0.002686
# 2022-03-02 	Buy and hold balance:	 87448.14 	Strategy balance:	 87778.84 	Delta:	 0.003782
# 2022-03-03 	Buy and hold balance:	 85372.59 	Strategy balance:	 85615.98 	Delta:	 0.002851
# 2022-03-04 	Buy and hold balance:	 83947.45 	Strategy balance:	 84076.00 	Delta:	 0.001531
# 2022-03-07 	Buy and hold balance:	 80765.83 	Strategy balance:	 80814.32 	Delta:	 0.000600
# 2022-03-08 	Buy and hold balance:	 81042.43 	Strategy balance:	 81117.19 	Delta:	 0.000923
# 2022-03-09 	Buy and hold balance:	 84588.31 	Strategy balance:	 84742.56 	Delta:	 0.001824
# 2022-03-10 	Buy and hold balance:	 82728.13 	Strategy balance:	 82792.30 	Delta:	 0.000776
# 2022-03-11 	Buy and hold balance:	 80275.65 	Strategy balance:	 80395.77 	Delta:	 0.001496
# 2022-03-14 	Buy and hold balance:	 78235.34 	Strategy balance:	 78374.21 	Delta:	 0.001775
# 2022-03-15 	Buy and hold balance:	 81670.59 	Strategy balance:	 81937.60 	Delta:	 0.003269
# 2022-03-16 	Buy and hold balance:	 84816.27 	Strategy balance:	 85168.74 	Delta:	 0.004156
# 2022-03-17 	Buy and hold balance:	 85695.47 	Strategy balance:	 85833.33 	Delta:	 0.001609
# 2022-03-18 	Buy and hold balance:	 88147.82 	Strategy balance:	 88243.73 	Delta:	 0.001088
# 2022-03-21 	Buy and hold balance:	 88949.67 	Strategy balance:	 89079.92 	Delta:	 0.001464
# 2022-03-22 	Buy and hold balance:	 91627.93 	Strategy balance:	 91504.29 	Delta:	 -0.001349
# 2022-03-23 	Buy and hold balance:	 91283.09 	Strategy balance:	 91115.83 	Delta:	 -0.001832
# 2022-03-24 	Buy and hold balance:	 93864.84 	Strategy balance:	 93871.73 	Delta:	 0.000073
# 2022-03-25 	Buy and hold balance:	 93630.97 	Strategy balance:	 93619.22 	Delta:	 -0.000126
# 2022-03-28 	Buy and hold balance:	 96680.13 	Strategy balance:	 96444.09 	Delta:	 -0.002441
# 2022-03-29 	Buy and hold balance:	 98079.70 	Strategy balance:	 97965.68 	Delta:	 -0.001163
# 2022-03-30 	Buy and hold balance:	 97043.95 	Strategy balance:	 96603.00 	Delta:	 -0.004544
# 2022-03-31 	Buy and hold balance:	 94891.88 	Strategy balance:	 93663.53 	Delta:	 -0.012945
# 2022-04-01 	Buy and hold balance:	 94852.77 	Strategy balance:	 93503.30 	Delta:	 -0.014227
# 2022-04-04 	Buy and hold balance:	 97881.38 	Strategy balance:	 96397.72 	Delta:	 -0.015158
# 2022-04-05 	Buy and hold balance:	 94901.09 	Strategy balance:	 93358.97 	Delta:	 -0.016250
# 2022-04-06 	Buy and hold balance:	 91647.64 	Strategy balance:	 90070.93 	Delta:	 -0.017204
# 2022-04-07 	Buy and hold balance:	 92081.39 	Strategy balance:	 90461.33 	Delta:	 -0.017594
# 2022-04-08 	Buy and hold balance:	 90056.43 	Strategy balance:	 88350.20 	Delta:	 -0.018946
# 2022-04-11 	Buy and hold balance:	 86576.47 	Strategy balance:	 84850.23 	Delta:	 -0.019939
# 2022-04-12 	Buy and hold balance:	 86618.56 	Strategy balance:	 84542.56 	Delta:	 -0.023967
# 2022-04-13 	Buy and hold balance:	 88797.40 	Strategy balance:	 86756.93 	Delta:	 -0.022979
# 2022-04-14 	Buy and hold balance:	 85831.64 	Strategy balance:	 83664.29 	Delta:	 -0.025251
# 2022-04-18 	Buy and hold balance:	 86599.39 	Strategy balance:	 84468.69 	Delta:	 -0.024604
# 2022-04-19 	Buy and hold balance:	 88286.86 	Strategy balance:	 86285.27 	Delta:	 -0.022671
# 2022-04-20 	Buy and hold balance:	 86526.36 	Strategy balance:	 84389.99 	Delta:	 -0.024690
# 2022-04-21 	Buy and hold balance:	 86134.95 	Strategy balance:	 83520.84 	Delta:	 -0.030349
# 2022-04-22 	Buy and hold balance:	 84524.29 	Strategy balance:	 81961.30 	Delta:	 -0.030323
# 2022-04-25 	Buy and hold balance:	 85295.03 	Strategy balance:	 82979.16 	Delta:	 -0.027151
# 2022-04-26 	Buy and hold balance:	 79598.59 	Strategy balance:	 77812.65 	Delta:	 -0.022437
# 2022-04-27 	Buy and hold balance:	 80527.31 	Strategy balance:	 78222.51 	Delta:	 -0.028621
# 2022-04-28 	Buy and hold balance:	 82696.80 	Strategy balance:	 80313.86 	Delta:	 -0.028815
# 2022-04-29 	Buy and hold balance:	 80058.02 	Strategy balance:	 77692.61 	Delta:	 -0.029546
# 2022-05-02 	Buy and hold balance:	 82112.69 	Strategy balance:	 79570.90 	Delta:	 -0.030955
# 2022-05-03 	Buy and hold balance:	 82419.36 	Strategy balance:	 79809.14 	Delta:	 -0.031670
# 2022-05-04 	Buy and hold balance:	 85976.57 	Strategy balance:	 82896.43 	Delta:	 -0.035825
# 2022-05-05 	Buy and hold balance:	 80682.12 	Strategy balance:	 77936.06 	Delta:	 -0.034036
# 2022-05-06 	Buy and hold balance:	 80407.94 	Strategy balance:	 77436.84 	Delta:	 -0.036950
# 2022-05-09 	Buy and hold balance:	 75580.80 	Strategy balance:	 73814.82 	Delta:	 -0.023365
# 2022-05-10 	Buy and hold balance:	 77026.28 	Strategy balance:	 74989.15 	Delta:	 -0.026447
# 2022-05-11 	Buy and hold balance:	 73052.33 	Strategy balance:	 71921.24 	Delta:	 -0.015483
# 2022-05-12 	Buy and hold balance:	 71726.71 	Strategy balance:	 70891.95 	Delta:	 -0.011638
# 2022-05-13 	Buy and hold balance:	 75006.61 	Strategy balance:	 73438.80 	Delta:	 -0.020902
# 2022-05-16 	Buy and hold balance:	 73381.34 	Strategy balance:	 71985.34 	Delta:	 -0.019024
# 2022-05-17 	Buy and hold balance:	 76201.72 	Strategy balance:	 74052.41 	Delta:	 -0.028206
# 2022-05-18 	Buy and hold balance:	 71797.30 	Strategy balance:	 70213.04 	Delta:	 -0.022066
# 2022-05-19 	Buy and hold balance:	 71301.66 	Strategy balance:	 69517.63 	Delta:	 -0.025021
# 2022-05-20 	Buy and hold balance:	 69698.66 	Strategy balance:	 68225.25 	Delta:	 -0.021140
# 2022-05-23 	Buy and hold balance:	 71573.04 	Strategy balance:	 70029.80 	Delta:	 -0.021562
# 2022-05-24 	Buy and hold balance:	 69316.49 	Strategy balance:	 67584.03 	Delta:	 -0.024993
# 2022-05-25 	Buy and hold balance:	 70751.57 	Strategy balance:	 68527.96 	Delta:	 -0.031428
# 2022-05-26 	Buy and hold balance:	 73515.02 	Strategy balance:	 70726.96 	Delta:	 -0.037925
# 2022-05-27 	Buy and hold balance:	 76869.10 	Strategy balance:	 73854.51 	Delta:	 -0.039217
# 2022-05-31 	Buy and hold balance:	 76541.45 	Strategy balance:	 73925.83 	Delta:	 -0.034172
# 2022-06-01 	Buy and hold balance:	 75921.55 	Strategy balance:	 73593.48 	Delta:	 -0.030664
# 2022-06-02 	Buy and hold balance:	 78316.58 	Strategy balance:	 75518.39 	Delta:	 -0.035729
# 2022-06-03 	Buy and hold balance:	 74760.72 	Strategy balance:	 72424.99 	Delta:	 -0.031243
# 2022-06-06 	Buy and hold balance:	 75056.09 	Strategy balance:	 73097.80 	Delta:	 -0.026091
# 2022-06-07 	Buy and hold balance:	 75773.54 	Strategy balance:	 73675.56 	Delta:	 -0.027688
# 2022-06-08 	Buy and hold balance:	 75419.19 	Strategy balance:	 73575.32 	Delta:	 -0.024448
# 2022-06-09 	Buy and hold balance:	 73641.75 	Strategy balance:	 71983.40 	Delta:	 -0.022519
# 2022-06-10 	Buy and hold balance:	 70733.75 	Strategy balance:	 69334.87 	Delta:	 -0.019777
# 2022-06-13 	Buy and hold balance:	 66854.12 	Strategy balance:	 65980.66 	Delta:	 -0.013065
# 2022-06-14 	Buy and hold balance:	 67624.64 	Strategy balance:	 66604.49 	Delta:	 -0.015086
# 2022-06-15 	Buy and hold balance:	 69918.12 	Strategy balance:	 68853.15 	Delta:	 -0.015232
# 2022-06-16 	Buy and hold balance:	 66206.79 	Strategy balance:	 65727.10 	Delta:	 -0.007245
# 2022-06-17 	Buy and hold balance:	 66973.79 	Strategy balance:	 66555.70 	Delta:	 -0.006243
# 2022-06-21 	Buy and hold balance:	 70071.17 	Strategy balance:	 69532.65 	Delta:	 -0.007685
# 2022-06-22 	Buy and hold balance:	 69804.88 	Strategy balance:	 69380.48 	Delta:	 -0.006080
# 2022-06-23 	Buy and hold balance:	 70431.71 	Strategy balance:	 70173.98 	Delta:	 -0.003659
# 2022-06-24 	Buy and hold balance:	 73062.11 	Strategy balance:	 72973.41 	Delta:	 -0.001214
# 2022-06-27 	Buy and hold balance:	 72641.97 	Strategy balance:	 72328.49 	Delta:	 -0.004315
# 2022-06-28 	Buy and hold balance:	 69743.74 	Strategy balance:	 69642.97 	Delta:	 -0.001445
# 2022-06-29 	Buy and hold balance:	 69603.29 	Strategy balance:	 69761.68 	Delta:	 0.002276
# 2022-06-30 	Buy and hold balance:	 68428.17 	Strategy balance:	 68446.40 	Delta:	 0.000266
# 2022-07-01 	Buy and hold balance:	 68772.99 	Strategy balance:	 69018.62 	Delta:	 0.003572
# 2022-07-05 	Buy and hold balance:	 70117.67 	Strategy balance:	 70796.46 	Delta:	 0.009681
# 2022-07-06 	Buy and hold balance:	 70519.43 	Strategy balance:	 71332.11 	Delta:	 0.011524
# 2022-07-07 	Buy and hold balance:	 72733.81 	Strategy balance:	 73447.83 	Delta:	 0.009817
# 2022-07-08 	Buy and hold balance:	 73280.12 	Strategy balance:	 74004.84 	Delta:	 0.009890
# 2022-07-11 	Buy and hold balance:	 71010.03 	Strategy balance:	 71773.88 	Delta:	 0.010757
# 2022-07-12 	Buy and hold balance:	 70183.40 	Strategy balance:	 70656.74 	Delta:	 0.006744
# 2022-07-13 	Buy and hold balance:	 70490.78 	Strategy balance:	 70389.35 	Delta:	 -0.001439
# 2022-07-14 	Buy and hold balance:	 71270.98 	Strategy balance:	 70758.24 	Delta:	 -0.007194
# 2022-07-15 	Buy and hold balance:	 72160.38 	Strategy balance:	 71536.79 	Delta:	 -0.008642
# 2022-07-18 	Buy and hold balance:	 71698.50 	Strategy balance:	 70599.78 	Delta:	 -0.015324
# 2022-07-19 	Buy and hold balance:	 73668.24 	Strategy balance:	 72628.02 	Delta:	 -0.014120
# 2022-07-20 	Buy and hold balance:	 74842.77 	Strategy balance:	 73287.06 	Delta:	 -0.020786
# 2022-07-21 	Buy and hold balance:	 77525.92 	Strategy balance:	 75399.86 	Delta:	 -0.027424
# 2022-07-22 	Buy and hold balance:	 76605.97 	Strategy balance:	 73773.78 	Delta:	 -0.036971
# 2022-07-25 	Buy and hold balance:	 75884.12 	Strategy balance:	 73246.22 	Delta:	 -0.034762
# 2022-07-26 	Buy and hold balance:	 74078.11 	Strategy balance:	 71378.07 	Delta:	 -0.036449
# 2022-07-27 	Buy and hold balance:	 78100.86 	Strategy balance:	 75720.25 	Delta:	 -0.030481
# 2022-07-28 	Buy and hold balance:	 79437.40 	Strategy balance:	 76952.51 	Delta:	 -0.031281
# 2022-07-29 	Buy and hold balance:	 82081.15 	Strategy balance:	 79422.51 	Delta:	 -0.032390
# 2022-08-01 	Buy and hold balance:	 81999.67 	Strategy balance:	 78967.13 	Delta:	 -0.036982
# 2022-08-02 	Buy and hold balance:	 82022.14 	Strategy balance:	 78882.98 	Delta:	 -0.038272
# 2022-08-03 	Buy and hold balance:	 84058.29 	Strategy balance:	 81057.48 	Delta:	 -0.035699
# 2022-08-04 	Buy and hold balance:	 84721.46 	Strategy balance:	 81325.76 	Delta:	 -0.040081
# 2022-08-05 	Buy and hold balance:	 82754.95 	Strategy balance:	 79726.58 	Delta:	 -0.036594
# 2022-08-08 	Buy and hold balance:	 82132.21 	Strategy balance:	 79573.62 	Delta:	 -0.031152
# 2022-08-09 	Buy and hold balance:	 81159.29 	Strategy balance:	 79072.62 	Delta:	 -0.025711
# 2022-08-10 	Buy and hold balance:	 83762.46 	Strategy balance:	 81382.21 	Delta:	 -0.028417
# 2022-08-11 	Buy and hold balance:	 82752.93 	Strategy balance:	 80459.57 	Delta:	 -0.027713
# 2022-08-12 	Buy and hold balance:	 85164.20 	Strategy balance:	 82615.63 	Delta:	 -0.029925
# 2022-08-15 	Buy and hold balance:	 86306.50 	Strategy balance:	 83484.21 	Delta:	 -0.032701
# 2022-08-16 	Buy and hold balance:	 85896.49 	Strategy balance:	 83182.57 	Delta:	 -0.031595
# 2022-08-17 	Buy and hold balance:	 85493.09 	Strategy balance:	 82626.01 	Delta:	 -0.033536
# 2022-08-18 	Buy and hold balance:	 85555.13 	Strategy balance:	 82548.46 	Delta:	 -0.035143
# 2022-08-19 	Buy and hold balance:	 83754.87 	Strategy balance:	 81002.30 	Delta:	 -0.032865
# 2022-08-22 	Buy and hold balance:	 81528.78 	Strategy balance:	 78915.12 	Delta:	 -0.032058
# 2022-08-23 	Buy and hold balance:	 81934.12 	Strategy balance:	 79164.30 	Delta:	 -0.033805
# 2022-08-24 	Buy and hold balance:	 82012.03 	Strategy balance:	 79181.82 	Delta:	 -0.034510
# 2022-08-25 	Buy and hold balance:	 83059.33 	Strategy balance:	 80204.62 	Delta:	 -0.034369
# 2022-08-26 	Buy and hold balance:	 79726.30 	Strategy balance:	 76991.36 	Delta:	 -0.034304
# 2022-08-29 	Buy and hold balance:	 78584.43 	Strategy balance:	 76133.16 	Delta:	 -0.031193
# 2022-08-30 	Buy and hold balance:	 77264.16 	Strategy balance:	 75146.41 	Delta:	 -0.027409
# 2022-08-31 	Buy and hold balance:	 76470.10 	Strategy balance:	 74547.24 	Delta:	 -0.025145
# 2022-09-01 	Buy and hold balance:	 76070.65 	Strategy balance:	 74866.03 	Delta:	 -0.015836
# 2022-09-02 	Buy and hold balance:	 74631.51 	Strategy balance:	 73528.12 	Delta:	 -0.014784
# 2022-09-06 	Buy and hold balance:	 74411.30 	Strategy balance:	 73226.18 	Delta:	 -0.015927
# 2022-09-07 	Buy and hold balance:	 75872.25 	Strategy balance:	 74906.09 	Delta:	 -0.012734
# 2022-09-08 	Buy and hold balance:	 76453.49 	Strategy balance:	 75017.37 	Delta:	 -0.018784
# 2022-09-09 	Buy and hold balance:	 78478.30 	Strategy balance:	 76914.02 	Delta:	 -0.019933
# 2022-09-12 	Buy and hold balance:	 79882.44 	Strategy balance:	 78040.46 	Delta:	 -0.023059
# 2022-09-13 	Buy and hold balance:	 75423.96 	Strategy balance:	 73847.68 	Delta:	 -0.020899
# 2022-09-14 	Buy and hold balance:	 76532.29 	Strategy balance:	 74824.05 	Delta:	 -0.022320
# 2022-09-15 	Buy and hold balance:	 75571.61 	Strategy balance:	 73722.95 	Delta:	 -0.024462
# 2022-09-16 	Buy and hold balance:	 75324.98 	Strategy balance:	 73394.97 	Delta:	 -0.025622
# 2022-09-19 	Buy and hold balance:	 76397.72 	Strategy balance:	 74185.84 	Delta:	 -0.028952
# 2022-09-20 	Buy and hold balance:	 76392.54 	Strategy balance:	 73851.20 	Delta:	 -0.033267
# 2022-09-21 	Buy and hold balance:	 75001.87 	Strategy balance:	 72383.52 	Delta:	 -0.034910
# 2022-09-22 	Buy and hold balance:	 73438.42 	Strategy balance:	 71652.12 	Delta:	 -0.024324
# 2022-09-23 	Buy and hold balance:	 71677.69 	Strategy balance:	 70017.39 	Delta:	 -0.023163
# 2022-09-26 	Buy and hold balance:	 71535.61 	Strategy balance:	 69672.55 	Delta:	 -0.026044
# 2022-09-27 	Buy and hold balance:	 72285.37 	Strategy balance:	 70397.45 	Delta:	 -0.026118
# 2022-09-28 	Buy and hold balance:	 72935.32 	Strategy balance:	 71376.06 	Delta:	 -0.021379
# 2022-09-29 	Buy and hold balance:	 69547.38 	Strategy balance:	 68301.22 	Delta:	 -0.017918
# 2022-09-30 	Buy and hold balance:	 68264.54 	Strategy balance:	 67196.91 	Delta:	 -0.015639
# 2022-10-03 	Buy and hold balance:	 67927.46 	Strategy balance:	 67279.09 	Delta:	 -0.009545
# 2022-10-04 	Buy and hold balance:	 69967.79 	Strategy balance:	 69688.89 	Delta:	 -0.003986
# 2022-10-05 	Buy and hold balance:	 69352.26 	Strategy balance:	 69231.22 	Delta:	 -0.001745
# 2022-10-06 	Buy and hold balance:	 68784.43 	Strategy balance:	 68663.50 	Delta:	 -0.001758
# 2022-10-07 	Buy and hold balance:	 64846.77 	Strategy balance:	 64594.96 	Delta:	 -0.003883
# 2022-10-10 	Buy and hold balance:	 64341.17 	Strategy balance:	 63682.09 	Delta:	 -0.010243
# 2022-10-11 	Buy and hold balance:	 63285.11 	Strategy balance:	 62694.03 	Delta:	 -0.009340
# 2022-10-12 	Buy and hold balance:	 63265.73 	Strategy balance:	 62601.26 	Delta:	 -0.010503
# 2022-10-13 	Buy and hold balance:	 65156.80 	Strategy balance:	 64612.65 	Delta:	 -0.008351
# 2022-10-14 	Buy and hold balance:	 62262.34 	Strategy balance:	 61527.86 	Delta:	 -0.011797
# 2022-10-17 	Buy and hold balance:	 65030.59 	Strategy balance:	 64553.01 	Delta:	 -0.007344
# 2022-10-18 	Buy and hold balance:	 65387.11 	Strategy balance:	 64957.34 	Delta:	 -0.006573
# 2022-10-19 	Buy and hold balance:	 65380.63 	Strategy balance:	 65025.81 	Delta:	 -0.005427
# 2022-10-20 	Buy and hold balance:	 64177.14 	Strategy balance:	 64188.85 	Delta:	 0.000182
# 2022-10-21 	Buy and hold balance:	 65924.12 	Strategy balance:	 65925.61 	Delta:	 0.000023
# 2022-10-24 	Buy and hold balance:	 66395.37 	Strategy balance:	 66489.37 	Delta:	 0.001416
# 2022-10-25 	Buy and hold balance:	 68382.81 	Strategy balance:	 68699.65 	Delta:	 0.004633
# 2022-10-26 	Buy and hold balance:	 66455.84 	Strategy balance:	 66557.78 	Delta:	 0.001534
# 2022-10-27 	Buy and hold balance:	 65502.60 	Strategy balance:	 66107.29 	Delta:	 0.009232
# 2022-10-28 	Buy and hold balance:	 68497.69 	Strategy balance:	 68876.13 	Delta:	 0.005525
# 2022-10-31 	Buy and hold balance:	 67545.31 	Strategy balance:	 67824.92 	Delta:	 0.004140
# 2022-11-01 	Buy and hold balance:	 66870.82 	Strategy balance:	 67261.99 	Delta:	 0.005850
# 2022-11-02 	Buy and hold balance:	 64240.86 	Strategy balance:	 64719.86 	Delta:	 0.007456
# 2022-11-03 	Buy and hold balance:	 63114.14 	Strategy balance:	 63930.84 	Delta:	 0.012940
# 2022-11-04 	Buy and hold balance:	 63319.92 	Strategy balance:	 64889.29 	Delta:	 0.024785
# 2022-11-07 	Buy and hold balance:	 63146.63 	Strategy balance:	 64898.52 	Delta:	 0.027743
# 2022-11-08 	Buy and hold balance:	 62988.31 	Strategy balance:	 65031.55 	Delta:	 0.032438
# 2022-11-09 	Buy and hold balance:	 60336.53 	Strategy balance:	 62137.08 	Delta:	 0.029842
# 2022-11-10 	Buy and hold balance:	 65754.12 	Strategy balance:	 68415.45 	Delta:	 0.040474
# 2022-11-11 	Buy and hold balance:	 67360.78 	Strategy balance:	 70202.89 	Delta:	 0.042192
# 2022-11-14 	Buy and hold balance:	 66410.10 	Strategy balance:	 69228.71 	Delta:	 0.042443
# 2022-11-15 	Buy and hold balance:	 67300.65 	Strategy balance:	 70179.77 	Delta:	 0.042780
# 2022-11-16 	Buy and hold balance:	 65987.98 	Strategy balance:	 68475.78 	Delta:	 0.037701
# 2022-11-17 	Buy and hold balance:	 65972.22 	Strategy balance:	 68057.39 	Delta:	 0.031607
# 2022-11-18 	Buy and hold balance:	 65669.93 	Strategy balance:	 67502.93 	Delta:	 0.027912
# 2022-11-21 	Buy and hold balance:	 64148.47 	Strategy balance:	 66244.89 	Delta:	 0.032681
# 2022-11-22 	Buy and hold balance:	 65280.48 	Strategy balance:	 67804.74 	Delta:	 0.038668
# 2022-11-23 	Buy and hold balance:	 66911.44 	Strategy balance:	 69656.62 	Delta:	 0.041027
# 2022-11-25 	Buy and hold balance:	 66277.64 	Strategy balance:	 68986.50 	Delta:	 0.040871
# 2022-11-28 	Buy and hold balance:	 65012.27 	Strategy balance:	 67591.34 	Delta:	 0.039671
# 2022-11-29 	Buy and hold balance:	 64249.15 	Strategy balance:	 66763.29 	Delta:	 0.039131
# 2022-11-30 	Buy and hold balance:	 68179.42 	Strategy balance:	 71285.42 	Delta:	 0.045556
# 2022-12-01 	Buy and hold balance:	 68243.76 	Strategy balance:	 71550.45 	Delta:	 0.048454
# 2022-12-02 	Buy and hold balance:	 67945.76 	Strategy balance:	 71166.12 	Delta:	 0.047396
# 2022-12-05 	Buy and hold balance:	 66229.73 	Strategy balance:	 69435.32 	Delta:	 0.048401
# 2022-12-06 	Buy and hold balance:	 64660.82 	Strategy balance:	 67628.06 	Delta:	 0.045889
# 2022-12-07 	Buy and hold balance:	 63884.69 	Strategy balance:	 67163.61 	Delta:	 0.051326
# 2022-12-08 	Buy and hold balance:	 64667.70 	Strategy balance:	 68960.55 	Delta:	 0.066383
# 2022-12-09 	Buy and hold balance:	 64715.42 	Strategy balance:	 68904.65 	Delta:	 0.064733
# 2022-12-12 	Buy and hold balance:	 64988.94 	Strategy balance:	 69632.50 	Delta:	 0.071451
# 2022-12-13 	Buy and hold balance:	 65143.31 	Strategy balance:	 70338.66 	Delta:	 0.079753
# 2022-12-14 	Buy and hold balance:	 64178.46 	Strategy balance:	 69301.36 	Delta:	 0.079823
# 2022-12-15 	Buy and hold balance:	 62264.60 	Strategy balance:	 67067.23 	Delta:	 0.077133
# 2022-12-16 	Buy and hold balance:	 60851.17 	Strategy balance:	 65516.84 	Delta:	 0.076674
# 2022-12-19 	Buy and hold balance:	 60037.47 	Strategy balance:	 64512.82 	Delta:	 0.074543
# 2022-12-20 	Buy and hold balance:	 59128.59 	Strategy balance:	 63556.81 	Delta:	 0.074891
# 2022-12-21 	Buy and hold balance:	 60083.81 	Strategy balance:	 64618.56 	Delta:	 0.075474
# 2022-12-22 	Buy and hold balance:	 57518.45 	Strategy balance:	 61400.99 	Delta:	 0.067501
# 2022-12-23 	Buy and hold balance:	 57331.52 	Strategy balance:	 61097.08 	Delta:	 0.065681
# 2022-12-27 	Buy and hold balance:	 55359.94 	Strategy balance:	 58201.69 	Delta:	 0.051332
# 2022-12-28 	Buy and hold balance:	 54816.38 	Strategy balance:	 57799.27 	Delta:	 0.054416
# 2022-12-29 	Buy and hold balance:	 56894.90 	Strategy balance:	 60123.02 	Delta:	 0.056738
# 2022-12-30 	Buy and hold balance:	 56963.32 	Strategy balance:	 60189.76 	Delta:	 0.056641
#
# high_buy_and_hold 105072.29780578613
# low_buy_and_hold 54816.378479003906
#
# high_strategy 105072.29780578613
# low_strategy 57799.2704731781
#
# biggest_delta 0.0798227304413915
# biggest_delta_day 2022-12-14 00:00:00
#
# final_delta_usd 3226.4469130821235
# final_delta_percent 0.056640782878298934
