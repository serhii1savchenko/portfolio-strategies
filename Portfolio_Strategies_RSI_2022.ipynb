# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from math import sqrt
from pypfopt.expected_returns import mean_historical_return
from pypfopt.risk_models import CovarianceShrinkage
from pypfopt.efficient_frontier import EfficientFrontier
from pypfopt.discrete_allocation import get_latest_prices
from dateutil.relativedelta import relativedelta
import copy
import warnings
warnings.filterwarnings('ignore')

tickers = ['AAPL', 'GOOG', 'MSFT', 'AMZN', 'INTC', 'AMD', 'NVDA', 'F', 'TSLA', 'JPM', 'MS', 'VOO']
data_for_portfolio_5y = yf.download(tickers, start='2017-01-01', end='2022-01-01')['Close'].dropna()
data_for_portfolio_5y.tail()
# Out:
# [*********************100%***********************]  12 of 12 completed
#                   AAPL         AMD        AMZN          F        GOOG  \
# Date
# 2021-12-27  180.330002  154.360001  169.669495  20.799999  148.063995
# 2021-12-28  179.289993  153.149994  170.660995  20.760000  146.447998
# 2021-12-29  179.380005  148.259995  169.201004  20.559999  146.504501
# 2021-12-30  178.199997  145.149994  168.644501  20.469999  146.002502
# 2021-12-31  177.570007  143.899994  166.716995  20.770000  144.679504
#
#                  INTC         JPM          MS        MSFT        NVDA  \
# Date
# 2021-12-27  51.939999  158.160004  100.400002  342.450012  309.450012
# 2021-12-28  51.759998  158.639999   99.970001  341.250000  303.220001
# 2021-12-29  51.830002  158.559998   98.730003  341.950012  300.010010
# 2021-12-30  51.740002  158.479996   98.800003  339.320007  295.859985
# 2021-12-31  51.500000  158.350006   98.160004  336.320007  294.109985
#
#                   TSLA         VOO
# Date
# 2021-12-27  364.646667  438.809998
# 2021-12-28  362.823334  438.480011
# 2021-12-29  362.063324  439.010010
# 2021-12-30  356.779999  437.769989
# 2021-12-31  352.260010  436.570007

# %%
# Create initial portfolio
mu = mean_historical_return(data_for_portfolio_5y)
S = CovarianceShrinkage(data_for_portfolio_5y).ledoit_wolf()
ef = EfficientFrontier(mu, S, weight_bounds=(0,1))
weights = ef.max_sharpe()
initial_weights = ef.clean_weights()
print(initial_weights, '\n')

# Initial buy stocks
balance_usd = 100_000
balance_remain = balance_usd
stocks_initial = {}
latest_prices_data_dec_2021 = get_latest_prices(data_for_portfolio_5y)
for ticker in initial_weights:
    to_spend_usd = balance_usd * initial_weights[ticker]
    one_stock_price = latest_prices_data_dec_2021[ticker]
    stocks_number = to_spend_usd // one_stock_price
    stocks_initial[ticker] = stocks_number
    balance_remain = balance_remain - (stocks_number * one_stock_price)
print('Portfolio:', stocks_initial)
print('Remaining balance: USD', balance_remain)
# Out:
# OrderedDict([('AAPL', 0.25899), ('AMD', 0.10384), ('AMZN', 0.0), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.25217), ('NVDA', 0.09699), ('TSLA', 0.288), ('VOO', 0.0)])
#
# Portfolio: {'AAPL': 145.0, 'AMD': 72.0, 'AMZN': 0.0, 'F': 0.0, 'GOOG': 0.0, 'INTC': 0.0, 'JPM': 0.0, 'MS': 0.0, 'MSFT': 74.0, 'NVDA': 32.0, 'TSLA': 81.0, 'VOO': 0.0}
# Remaining balance: USD 1059.2885131835938

# %%
# Calculate MACD, RSI, and S&R signals.
data_2022 = yf.download(tickers, start='2021-12-14', end='2023-01-01')['Close'].dropna()

short_ma = 5                                       # 5 минулих днів для "короткого" МА 
long_ma = 12                                       # 12 минулих днів для "довгого" МА 
rsi_period = 14                                    # RSI рахується за 14 минулих днів 
rsi_oversold = 30                                  # Параметри для індикатора RSI 
rsi_overbought = 70 
sr_sell = 0.7                                      # Параметри для індикатора S&R
sr_buy = 0.3 
start = max(long_ma, rsi_period)

for ticker in data_2022.columns:
    data_2022['MA_' + ticker + str(short_ma)] = data_2022[ticker].rolling(short_ma).mean()
    data_2022['MA_' + ticker + str(long_ma)] = data_2022[ticker].rolling(long_ma).mean() 
    data_2022['return_' + ticker] = data_2022[ticker].pct_change() 
    data_2022['Up_' + ticker] = np.maximum(data_2022[ticker].diff(),0) 
    data_2022['Down_' + ticker] = np.maximum(-data_2022[ticker].diff(),0) 
    data_2022['RS_' + ticker] = data_2022['Up_' + ticker].rolling(rsi_period).mean()/data_2022['Down_' + ticker].rolling(rsi_period).mean() 
    data_2022['RSI_' + ticker] = 100 - 100/(1 + data_2022['RS_' + ticker]) 
    data_2022['S&R_' + ticker] = (data_2022[ticker]/(10**np.floor(np.log10(data_2022[ticker]))))%1 
    data_2022['MACD_signal_' + ticker] = 2*(data_2022['MA_' + ticker + str(short_ma)] > data_2022['MA_' + ticker + str(long_ma)]) -1 
    data_2022['RSI_signal_' + ticker] = 1*(data_2022['RSI_' + ticker] < rsi_oversold) -1*(data_2022['RSI_' + ticker] > rsi_overbought) 
    data_2022['S&R_signal_' + ticker] = 1*(data_2022['S&R_' + ticker] < sr_buy) -1*(data_2022['S&R_' + ticker] > sr_sell) 

data = data_2022.drop(data_2022.index[range(14)])
#print(data.to_string())
data.head(3)
# Out:
# [*********************100%***********************]  12 of 12 completed
#                   AAPL         AMD        AMZN          F        GOOG  \
# Date
# 2022-01-03  182.009995  150.240005  170.404495  21.770000  145.074493
# 2022-01-04  179.699997  144.419998  167.522003  24.309999  144.416504
# 2022-01-05  174.919998  136.149994  164.356995  23.660000  137.653503
#
#                  INTC         JPM          MS        MSFT        NVDA  ...  \
# Date                                                                   ...
# 2022-01-03  53.209999  161.699997  100.190002  334.750000  301.209991  ...
# 2022-01-04  53.139999  167.830002  104.260002  329.010010  292.899994  ...
# 2022-01-05  53.869999  163.779999  101.680000  316.380005  276.040009  ...
#
#               MA_VOO12  return_VOO    Up_VOO  Down_VOO    RS_VOO    RSI_VOO  \
# Date
# 2022-01-03  432.603335    0.006139  2.679993  0.000000  1.549355  60.774396
# 2022-01-04  433.455836   -0.000410  0.000000  0.179993  1.816353  64.493090
# 2022-01-05  433.978335   -0.019154  0.000000  8.410004  0.914027  47.754141
#
#             S&R_VOO  MACD_signal_VOO  RSI_signal_VOO  S&R_signal_VOO
# Date
# 2022-01-03   0.3925                1               0               0
# 2022-01-04   0.3907                1               0               0
# 2022-01-05   0.3066                1               0               0
#
# [3 rows x 144 columns]

# %%
data.tail(3)
# Out:
#                   AAPL        AMD   AMZN      F       GOOG       INTC  \
# Date
# 2022-12-28  126.040001  62.570000  81.82  10.95  86.459999  25.540001
# 2022-12-29  129.610001  64.820000  84.18  11.54  88.949997  26.209999
# 2022-12-30  129.929993  64.769997  84.00  11.63  88.730003  26.430000
#
#                    JPM         MS        MSFT        NVDA  ...    MA_VOO12  \
# Date                                                       ...
# 2022-12-28  132.460007  84.459999  234.529999  140.360001  ...  355.751668
# 2022-12-29  133.220001  85.239998  241.009995  146.029999  ...  354.554169
# 2022-12-30  134.100006  85.019997  239.820007  146.139999  ...  353.050001
#
#             return_VOO    Up_VOO  Down_VOO    RS_VOO    RSI_VOO  S&R_VOO  \
# Date
# 2022-12-28   -0.012269  0.000000  4.299988  0.541579  35.131445   0.4617
# 2022-12-29    0.017737  6.139984  0.000000  0.641064  39.063936   0.5231
# 2022-12-30   -0.002753  0.000000  0.970001  0.675590  40.319512   0.5134
#
#             MACD_signal_VOO  RSI_signal_VOO  S&R_signal_VOO
# Date
# 2022-12-28               -1               0               0
# 2022-12-29               -1               0               0
# 2022-12-30               -1               0               0
#
# [3 rows x 144 columns]

# %%
def check_tickers_for_sell(tickers_sell, now, current_weights):
    ticker_percent_sell = {}
    end_date = now.strftime('%Y-%m-%d')
    start_date = (now - relativedelta(years=5)).strftime('%Y-%m-%d')
    # Get data for all tickers for last 5 years
    data_for_tickers = yf.download(tickers, start_date, end_date, progress=False)['Close'].dropna()
    
    # Generate portfolio on this data
    mu = mean_historical_return(data_for_tickers)
    S = CovarianceShrinkage(data_for_tickers).ledoit_wolf()
    ef = EfficientFrontier(mu, S, weight_bounds=(0,1))
    weights = ef.max_sharpe()
    new_weights = ef.clean_weights()
    
    for ticker in tickers_sell:
        if new_weights[ticker] == 0:
            ticker_percent_sell[ticker] = 100
        elif new_weights[ticker] < current_weights[ticker]:
            delta = current_weights[ticker] - new_weights[ticker]
            sell_percent = (delta * 100) // current_weights[ticker]
            ticker_percent_sell[ticker] = sell_percent
    return ticker_percent_sell

# %%
def select_ticker_for_sell(data, date, filtered_sell_tickers_with_percents, stocks_current):
    sell_ticker = ''
    sell_profit = 0
    stocks_to_sell = 0
    for ticker in filtered_sell_tickers_with_percents:
        no_of_stocks = stocks_current[ticker]
        #print(ticker, 'no_of_stocks', no_of_stocks)
        cur_price = data[ticker][date]
        #print(ticker, 'cur_price', cur_price)
        sell_percent = (filtered_sell_tickers_with_percents[ticker] / 100)
        #print(ticker, 'sell_percent', sell_percent)
        potentail_profit = no_of_stocks * cur_price * sell_percent
        #print(ticker, 'potentail_profit', potentail_profit)
        if potentail_profit > sell_profit:
            sell_profit = potentail_profit
            sell_ticker = ticker
            stocks_to_sell = no_of_stocks * sell_percent
    return [sell_ticker, sell_profit, stocks_to_sell]

# %%
def select_ticker_for_buy(tickers_buy, now):
    if len(tickers_buy) == 1:
        return tickers_buy[0]
    end_date = now.strftime('%Y-%m-%d')
    start_date = (now - relativedelta(years=5)).strftime('%Y-%m-%d')
    # Get data for all tickers for last 5 years period
    data_for_tickers_last_year = yf.download(tickers_buy, start_date, end_date, progress=False)['Close'].dropna()
    ticker_percent_delta = {}
    for t in tickers_buy:
        first_price = data_for_tickers_last_year[t][0]
        last_price = data_for_tickers_last_year[t][len(data_for_tickers_last_year[t]) - 1]
        delta = last_price - first_price
        delta_abs = abs(delta)
        percent = (delta_abs * 100) / first_price
        if delta > 0:
            ticker_percent_delta[t] = percent
        else:
            ticker_percent_delta[t] = -1 * percent
    sorted_by_delta = dict(sorted(ticker_percent_delta.items(), key=lambda x:x[1], reverse=True))
    return list(sorted_by_delta.keys())[0]

# %%
print('Start weights:', initial_weights)
clean_result = balance_remain
for stock in initial_weights:
    clean_result = clean_result + (stocks_initial[stock] * data[stock][len(data[stock]) - 1])
print('Without any changes balance on the end of 2022 would be', clean_result)
print('------------------------------------')
# Out:
# Start weights: OrderedDict([('AAPL', 0.25899), ('AMD', 0.10384), ('AMZN', 0.0), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.25217), ('NVDA', 0.09699), ('TSLA', 0.288), ('VOO', 0.0)])
# Without any changes balance on the end of 2022 would be 56963.31775665283
# ------------------------------------

# %%
strategy = 'RSI_signal_'                  # MACD_signal_        or        RSI_signal_        or        S&R_signal_
strategy_weights = copy.deepcopy(initial_weights)
stocks_strategy = copy.deepcopy(stocks_initial)
balance_strategy = balance_remain

balance_buy_and_hold_dict = {}
balance_strategy_dict = {}

for d in data.index: 
    if d.weekday() == 4:                   # every Friday
        tickers_sell = []
        tickers_buy = []
        for t in strategy_weights:
            if data[strategy + t][d] == -1:
                tickers_sell.append(t)
            if data[strategy + t][d] == 1:
                tickers_buy.append(t)
        print(d, 'Sell candidates:', tickers_sell, 'Buy candidates:', tickers_buy)
        if len(tickers_sell) > 0 and len(tickers_buy) > 0:
            filtered_sell_tickers_with_percents = check_tickers_for_sell(tickers_sell, d, strategy_weights)
            print('Filtered sell candidates:', filtered_sell_tickers_with_percents)
            if len(filtered_sell_tickers_with_percents) > 0:
                ticker_for_sell_data = select_ticker_for_sell(data, d, filtered_sell_tickers_with_percents, stocks_strategy)
                will_receive_usd = ticker_for_sell_data[1]
                # If this ticker is present in current portfolio
                if will_receive_usd > 0:
                    ticker_for_sell = ticker_for_sell_data[0]
                    stocks_to_sell = ticker_for_sell_data[2]
                    sell_percents = filtered_sell_tickers_with_percents[ticker_for_sell]
                    ticker_for_buy = select_ticker_for_buy(tickers_buy, d)
                    # If we can buy other ticker on that money
                    if (will_receive_usd + balance_strategy) > data[ticker_for_buy][d]:
                        print('Will sell',ticker_for_sell,'and get',will_receive_usd,'$ after selling (',sell_percents,'% )')
                        print('Will buy', ticker_for_buy)
                        # Sell percent of ticker_for_sell and add that money to balance
                        stocks_strategy[ticker_for_sell] = stocks_strategy[ticker_for_sell] - stocks_to_sell
                        balance_strategy = balance_strategy + will_receive_usd
                        # Buy ticker_for_buy on all balance
                        no_of_buy_stocks = balance_strategy // data[ticker_for_buy][d]
                        stocks_strategy[ticker_for_buy] = stocks_strategy[ticker_for_buy] + no_of_buy_stocks
                        balance_strategy = balance_strategy - (data[ticker_for_buy][d] * no_of_buy_stocks)
                        # Recalculate new weights for all portfolio
                        # calculate all prices for now + balance - потом высчитать сколько в процентах сейчас каждый ФИ
                        cur_balance = balance_strategy
                        stock_usd = {}
                        for stock in stocks_strategy:
                            stock_usd[stock] = stocks_strategy[stock] * data[stock][d]
                            cur_balance = cur_balance + stock_usd[stock]
                        for stock in stocks_strategy:
                            strategy_weights[stock] = stock_usd[stock] / cur_balance
                        print('Current weights are', strategy_weights)
                        print('Current balance =', cur_balance)
                    else:
                        print("No changes because sell profit is not enough for buying at least one stock.")
                else:
                    print("No changes because all sell candidates are not present in current portfolio.")
            else:
                print("No changes because all sell candidates failed check.")
        else:
            print("No changes because no sell candidates or no buy candidates.")
        print('------------------------------------')
    # Calculate current balance for stocks_initial
    today_balance_buy_and_hold = balance_remain
    for stock in stocks_initial:
        today_balance_buy_and_hold = today_balance_buy_and_hold + (data[stock][d] * stocks_initial[stock])
    balance_buy_and_hold_dict[d] = today_balance_buy_and_hold
    # Calculate current balance for stocks_strategy
    today_balance_strategy = balance_strategy
    for stock in stocks_strategy:
        today_balance_strategy = today_balance_strategy + (data[stock][d] * stocks_strategy[stock])
    balance_strategy_dict[d] = today_balance_strategy

print('\nWith strategy final weights are:', strategy_weights)        
clean_result = balance_strategy
for stock in strategy_weights:
    clean_result = clean_result + (stocks_strategy[stock] * data[stock][len(data[stock]) - 1])
print('\nWith strategy balance on the end of 2022 would be', clean_result)
# Out:
# 2022-01-07 00:00:00 Sell candidates: ['F', 'JPM'] Buy candidates: []
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-01-14 00:00:00 Sell candidates: ['F', 'INTC'] Buy candidates: ['GOOG', 'MSFT', 'NVDA', 'VOO']
# Filtered sell candidates: {'F': 100, 'INTC': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2022-01-21 00:00:00 Sell candidates: [] Buy candidates: ['AAPL', 'AMD', 'AMZN', 'GOOG', 'MSFT', 'NVDA', 'VOO']
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-01-28 00:00:00 Sell candidates: [] Buy candidates: ['AMD', 'AMZN', 'F', 'INTC', 'JPM', 'NVDA', 'TSLA', 'VOO']
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-02-04 00:00:00 Sell candidates: [] Buy candidates: ['F', 'INTC']
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-02-11 00:00:00 Sell candidates: [] Buy candidates: ['F']
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-02-18 00:00:00 Sell candidates: [] Buy candidates: []
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-02-25 00:00:00 Sell candidates: [] Buy candidates: []
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-03-04 00:00:00 Sell candidates: [] Buy candidates: ['JPM', 'MS']
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-03-11 00:00:00 Sell candidates: [] Buy candidates: ['JPM', 'MS']
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-03-18 00:00:00 Sell candidates: [] Buy candidates: []
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-03-25 00:00:00 Sell candidates: ['AMZN', 'GOOG', 'JPM', 'NVDA', 'TSLA', 'VOO'] Buy candidates: []
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-04-01 00:00:00 Sell candidates: ['AAPL', 'AMZN', 'GOOG', 'MSFT', 'NVDA', 'TSLA', 'VOO'] Buy candidates: []
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-04-08 00:00:00 Sell candidates: [] Buy candidates: ['MS']
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-04-22 00:00:00 Sell candidates: [] Buy candidates: ['AMD', 'GOOG', 'MSFT', 'NVDA', 'VOO']
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-04-29 00:00:00 Sell candidates: [] Buy candidates: ['AMZN', 'GOOG', 'JPM', 'NVDA', 'VOO']
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-05-06 00:00:00 Sell candidates: [] Buy candidates: ['AMZN']
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-05-13 00:00:00 Sell candidates: [] Buy candidates: ['AMZN', 'TSLA']
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-05-20 00:00:00 Sell candidates: [] Buy candidates: ['TSLA']
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-05-27 00:00:00 Sell candidates: [] Buy candidates: []
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-06-03 00:00:00 Sell candidates: [] Buy candidates: []
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-06-10 00:00:00 Sell candidates: [] Buy candidates: []
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-06-17 00:00:00 Sell candidates: [] Buy candidates: ['AAPL', 'AMD', 'F', 'INTC', 'JPM', 'MS', 'MSFT', 'VOO']
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-06-24 00:00:00 Sell candidates: [] Buy candidates: ['AMD', 'INTC', 'JPM']
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-07-01 00:00:00 Sell candidates: [] Buy candidates: ['AMD']
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-07-08 00:00:00 Sell candidates: ['AAPL', 'GOOG', 'MSFT', 'TSLA', 'VOO'] Buy candidates: []
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-07-15 00:00:00 Sell candidates: [] Buy candidates: []
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-07-22 00:00:00 Sell candidates: ['AAPL', 'AMD', 'AMZN', 'F', 'NVDA', 'TSLA'] Buy candidates: []
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-07-29 00:00:00 Sell candidates: ['AAPL', 'AMD', 'AMZN', 'F', 'MS', 'NVDA', 'TSLA', 'VOO'] Buy candidates: []
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-08-05 00:00:00 Sell candidates: ['AAPL', 'AMD', 'AMZN', 'F', 'MS', 'MSFT', 'NVDA', 'TSLA', 'VOO'] Buy candidates: []
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-08-12 00:00:00 Sell candidates: ['AAPL', 'AMZN', 'F', 'GOOG', 'MS', 'MSFT', 'VOO'] Buy candidates: []
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-08-19 00:00:00 Sell candidates: ['AAPL', 'MS'] Buy candidates: []
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-08-26 00:00:00 Sell candidates: [] Buy candidates: []
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-09-02 00:00:00 Sell candidates: [] Buy candidates: ['AAPL', 'AMD', 'AMZN', 'GOOG', 'INTC', 'JPM', 'MS', 'MSFT', 'NVDA', 'TSLA', 'VOO']
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-09-09 00:00:00 Sell candidates: [] Buy candidates: ['AAPL', 'INTC', 'MSFT', 'NVDA']
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-09-16 00:00:00 Sell candidates: [] Buy candidates: ['AMD', 'INTC', 'MSFT', 'NVDA']
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-09-23 00:00:00 Sell candidates: [] Buy candidates: ['AMD', 'F', 'GOOG', 'INTC']
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-09-30 00:00:00 Sell candidates: [] Buy candidates: ['AAPL', 'AMD', 'AMZN', 'F', 'GOOG', 'INTC', 'JPM', 'MS', 'MSFT', 'NVDA', 'VOO']
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-10-07 00:00:00 Sell candidates: [] Buy candidates: ['AMD', 'F', 'INTC', 'MS', 'TSLA']
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-10-14 00:00:00 Sell candidates: [] Buy candidates: ['TSLA']
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-10-21 00:00:00 Sell candidates: [] Buy candidates: []
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-10-28 00:00:00 Sell candidates: ['F', 'INTC', 'JPM', 'NVDA'] Buy candidates: []
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-11-04 00:00:00 Sell candidates: ['F', 'JPM', 'MS', 'NVDA'] Buy candidates: ['AMZN']
# Filtered sell candidates: {'F': 100, 'JPM': 100, 'MS': 100, 'NVDA': 100}
# Will sell NVDA and get 4529.919921875 $ after selling ( 100 % )
# Will buy AMZN
# Current weights are OrderedDict([('AAPL', 0.31688449691454434), ('AMD', 0.07071518670451872), ('AMZN', 0.08764667238744107), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.2587315364301724), ('NVDA', 0.0), ('TSLA', 0.26539942467226224), ('VOO', 0.0)])
# Current balance = 63319.91909790039
# ------------------------------------
# 2022-11-11 00:00:00 Sell candidates: ['AMD', 'F', 'JPM', 'MS', 'NVDA'] Buy candidates: []
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-11-18 00:00:00 Sell candidates: ['AMD', 'JPM'] Buy candidates: ['TSLA']
# Filtered sell candidates: {'JPM': 100}
# No changes because all sell candidates are not present in current portfolio.
# ------------------------------------
# 2022-11-25 00:00:00 Sell candidates: ['GOOG', 'MSFT', 'VOO'] Buy candidates: []
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-12-02 00:00:00 Sell candidates: [] Buy candidates: []
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-12-09 00:00:00 Sell candidates: [] Buy candidates: ['F']
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-12-16 00:00:00 Sell candidates: [] Buy candidates: ['F', 'TSLA']
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-12-23 00:00:00 Sell candidates: [] Buy candidates: ['AAPL', 'F', 'GOOG', 'INTC', 'TSLA']
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
# 2022-12-30 00:00:00 Sell candidates: [] Buy candidates: ['TSLA']
# No changes because no sell candidates or no buy candidates.
# ------------------------------------
#
# With strategy final weights are: OrderedDict([('AAPL', 0.31688449691454434), ('AMD', 0.07071518670451872), ('AMZN', 0.08764667238744107), ('F', 0.0), ('GOOG', 0.0), ('INTC', 0.0), ('JPM', 0.0), ('MS', 0.0), ('MSFT', 0.2587315364301724), ('NVDA', 0.0), ('TSLA', 0.26539942467226224), ('VOO', 0.0)])
#
# With strategy balance on the end of 2022 would be 56390.97749328613

# %%
high_buy_and_hold = 0
low_buy_and_hold = 1_000_000_000
high_strategy = 0
low_strategy = 1_000_000_000
biggest_delta = 0
biggest_delta_day = ''
final_delta_usd = 0
final_delta_percent = 0

for d in balance_buy_and_hold_dict:
    if balance_buy_and_hold_dict[d] > high_buy_and_hold:
        high_buy_and_hold = balance_buy_and_hold_dict[d]
    if balance_buy_and_hold_dict[d] < low_buy_and_hold:
        low_buy_and_hold = balance_buy_and_hold_dict[d]
    if balance_strategy_dict[d] > high_strategy:
        high_strategy = balance_strategy_dict[d]
    if balance_strategy_dict[d] < low_strategy:
        low_strategy = balance_strategy_dict[d]
    delta = balance_strategy_dict[d] - balance_buy_and_hold_dict[d]
    delta_abs = abs(delta)
    percent = delta_abs / balance_buy_and_hold_dict[d]
    percent_change = percent
    if delta < 0:
        percent_change = -1 * percent_change
    if percent > abs(biggest_delta):
        biggest_delta = percent_change
        biggest_delta_day = d
    final_delta_usd = balance_strategy_dict[d] - balance_buy_and_hold_dict[d]
    final_delta_percent = percent_change
    print(d.strftime('%Y-%m-%d'), '\tBuy and hold balance:\t', "{:.2f}".format(balance_buy_and_hold_dict[d]), 
          '\tStrategy balance:\t', "{:.2f}".format(balance_strategy_dict[d]), 
          '\tDelta:\t', "{:.6f}".format(percent_change))

print('\nhigh_buy_and_hold', high_buy_and_hold)
print('low_buy_and_hold', low_buy_and_hold)
print('\nhigh_strategy', high_strategy)
print('low_strategy', low_strategy)
print('\nbiggest_delta', biggest_delta)
print('biggest_delta_day', biggest_delta_day)
print('\nfinal_delta_usd', final_delta_usd)
print('final_delta_percent', final_delta_percent)
# Out:
# 2022-01-03 	Buy and hold balance:	 105072.30 	Strategy balance:	 105072.30 	Delta:	 0.000000
# 2022-01-04 	Buy and hold balance:	 102272.50 	Strategy balance:	 102272.50 	Delta:	 0.000000
# 2022-01-05 	Buy and hold balance:	 97850.13 	Strategy balance:	 97850.13 	Delta:	 0.000000
# 2022-01-06 	Buy and hold balance:	 96798.83 	Strategy balance:	 96798.83 	Delta:	 0.000000
# 2022-01-07 	Buy and hold balance:	 95213.86 	Strategy balance:	 95213.86 	Delta:	 0.000000
# 2022-01-10 	Buy and hold balance:	 96124.06 	Strategy balance:	 96124.06 	Delta:	 0.000000
# 2022-01-11 	Buy and hold balance:	 97280.97 	Strategy balance:	 97280.97 	Delta:	 0.000000
# 2022-01-12 	Buy and hold balance:	 98788.58 	Strategy balance:	 98788.58 	Delta:	 0.000000
# 2022-01-13 	Buy and hold balance:	 94495.44 	Strategy balance:	 94495.44 	Delta:	 0.000000
# 2022-01-14 	Buy and hold balance:	 95925.51 	Strategy balance:	 95925.51 	Delta:	 0.000000
# 2022-01-18 	Buy and hold balance:	 93688.08 	Strategy balance:	 93688.08 	Delta:	 0.000000
# 2022-01-19 	Buy and hold balance:	 91748.49 	Strategy balance:	 91748.49 	Delta:	 0.000000
# 2022-01-20 	Buy and hold balance:	 90635.01 	Strategy balance:	 90635.01 	Delta:	 0.000000
# 2022-01-21 	Buy and hold balance:	 88034.26 	Strategy balance:	 88034.26 	Delta:	 0.000000
# 2022-01-24 	Buy and hold balance:	 87404.77 	Strategy balance:	 87404.77 	Delta:	 0.000000
# 2022-01-25 	Buy and hold balance:	 85517.49 	Strategy balance:	 85517.49 	Delta:	 0.000000
# 2022-01-26 	Buy and hold balance:	 86739.11 	Strategy balance:	 86739.11 	Delta:	 0.000000
# 2022-01-27 	Buy and hold balance:	 83129.33 	Strategy balance:	 83129.33 	Delta:	 0.000000
# 2022-01-28 	Buy and hold balance:	 86305.91 	Strategy balance:	 86305.91 	Delta:	 0.000000
# 2022-01-31 	Buy and hold balance:	 90767.87 	Strategy balance:	 90767.87 	Delta:	 0.000000
# 2022-02-01 	Buy and hold balance:	 90662.05 	Strategy balance:	 90662.05 	Delta:	 0.000000
# 2022-02-02 	Buy and hold balance:	 91121.11 	Strategy balance:	 91121.11 	Delta:	 0.000000
# 2022-02-03 	Buy and hold balance:	 88792.19 	Strategy balance:	 88792.19 	Delta:	 0.000000
# 2022-02-04 	Buy and hold balance:	 90306.32 	Strategy balance:	 90306.32 	Delta:	 0.000000
# 2022-02-07 	Buy and hold balance:	 89535.67 	Strategy balance:	 89535.67 	Delta:	 0.000000
# 2022-02-08 	Buy and hold balance:	 91108.20 	Strategy balance:	 91108.20 	Delta:	 0.000000
# 2022-02-09 	Buy and hold balance:	 92924.23 	Strategy balance:	 92924.23 	Delta:	 0.000000
# 2022-02-10 	Buy and hold balance:	 90134.78 	Strategy balance:	 90134.78 	Delta:	 0.000000
# 2022-02-11 	Buy and hold balance:	 86377.69 	Strategy balance:	 86377.69 	Delta:	 0.000000
# 2022-02-14 	Buy and hold balance:	 87015.29 	Strategy balance:	 87015.29 	Delta:	 0.000000
# 2022-02-15 	Buy and hold balance:	 90478.47 	Strategy balance:	 90478.47 	Delta:	 0.000000
# 2022-02-16 	Buy and hold balance:	 90130.77 	Strategy balance:	 90130.77 	Delta:	 0.000000
# 2022-02-17 	Buy and hold balance:	 86655.24 	Strategy balance:	 86655.24 	Delta:	 0.000000
# 2022-02-18 	Buy and hold balance:	 85524.27 	Strategy balance:	 85524.27 	Delta:	 0.000000
# 2022-02-22 	Buy and hold balance:	 84169.88 	Strategy balance:	 84169.88 	Delta:	 0.000000
# 2022-02-23 	Buy and hold balance:	 80705.06 	Strategy balance:	 80705.06 	Delta:	 0.000000
# 2022-02-24 	Buy and hold balance:	 84072.32 	Strategy balance:	 84072.32 	Delta:	 0.000000
# 2022-02-25 	Buy and hold balance:	 85276.53 	Strategy balance:	 85276.53 	Delta:	 0.000000
# 2022-02-28 	Buy and hold balance:	 87297.44 	Strategy balance:	 87297.44 	Delta:	 0.000000
# 2022-03-01 	Buy and hold balance:	 85595.98 	Strategy balance:	 85595.98 	Delta:	 0.000000
# 2022-03-02 	Buy and hold balance:	 87448.14 	Strategy balance:	 87448.14 	Delta:	 0.000000
# 2022-03-03 	Buy and hold balance:	 85372.59 	Strategy balance:	 85372.59 	Delta:	 0.000000
# 2022-03-04 	Buy and hold balance:	 83947.45 	Strategy balance:	 83947.45 	Delta:	 0.000000
# 2022-03-07 	Buy and hold balance:	 80765.83 	Strategy balance:	 80765.83 	Delta:	 0.000000
# 2022-03-08 	Buy and hold balance:	 81042.43 	Strategy balance:	 81042.43 	Delta:	 0.000000
# 2022-03-09 	Buy and hold balance:	 84588.31 	Strategy balance:	 84588.31 	Delta:	 0.000000
# 2022-03-10 	Buy and hold balance:	 82728.13 	Strategy balance:	 82728.13 	Delta:	 0.000000
# 2022-03-11 	Buy and hold balance:	 80275.65 	Strategy balance:	 80275.65 	Delta:	 0.000000
# 2022-03-14 	Buy and hold balance:	 78235.34 	Strategy balance:	 78235.34 	Delta:	 0.000000
# 2022-03-15 	Buy and hold balance:	 81670.59 	Strategy balance:	 81670.59 	Delta:	 0.000000
# 2022-03-16 	Buy and hold balance:	 84816.27 	Strategy balance:	 84816.27 	Delta:	 0.000000
# 2022-03-17 	Buy and hold balance:	 85695.47 	Strategy balance:	 85695.47 	Delta:	 0.000000
# 2022-03-18 	Buy and hold balance:	 88147.82 	Strategy balance:	 88147.82 	Delta:	 0.000000
# 2022-03-21 	Buy and hold balance:	 88949.67 	Strategy balance:	 88949.67 	Delta:	 0.000000
# 2022-03-22 	Buy and hold balance:	 91627.93 	Strategy balance:	 91627.93 	Delta:	 0.000000
# 2022-03-23 	Buy and hold balance:	 91283.09 	Strategy balance:	 91283.09 	Delta:	 0.000000
# 2022-03-24 	Buy and hold balance:	 93864.84 	Strategy balance:	 93864.84 	Delta:	 0.000000
# 2022-03-25 	Buy and hold balance:	 93630.97 	Strategy balance:	 93630.97 	Delta:	 0.000000
# 2022-03-28 	Buy and hold balance:	 96680.13 	Strategy balance:	 96680.13 	Delta:	 0.000000
# 2022-03-29 	Buy and hold balance:	 98079.70 	Strategy balance:	 98079.70 	Delta:	 0.000000
# 2022-03-30 	Buy and hold balance:	 97043.95 	Strategy balance:	 97043.95 	Delta:	 0.000000
# 2022-03-31 	Buy and hold balance:	 94891.88 	Strategy balance:	 94891.88 	Delta:	 0.000000
# 2022-04-01 	Buy and hold balance:	 94852.77 	Strategy balance:	 94852.77 	Delta:	 0.000000
# 2022-04-04 	Buy and hold balance:	 97881.38 	Strategy balance:	 97881.38 	Delta:	 0.000000
# 2022-04-05 	Buy and hold balance:	 94901.09 	Strategy balance:	 94901.09 	Delta:	 0.000000
# 2022-04-06 	Buy and hold balance:	 91647.64 	Strategy balance:	 91647.64 	Delta:	 0.000000
# 2022-04-07 	Buy and hold balance:	 92081.39 	Strategy balance:	 92081.39 	Delta:	 0.000000
# 2022-04-08 	Buy and hold balance:	 90056.43 	Strategy balance:	 90056.43 	Delta:	 0.000000
# 2022-04-11 	Buy and hold balance:	 86576.47 	Strategy balance:	 86576.47 	Delta:	 0.000000
# 2022-04-12 	Buy and hold balance:	 86618.56 	Strategy balance:	 86618.56 	Delta:	 0.000000
# 2022-04-13 	Buy and hold balance:	 88797.40 	Strategy balance:	 88797.40 	Delta:	 0.000000
# 2022-04-14 	Buy and hold balance:	 85831.64 	Strategy balance:	 85831.64 	Delta:	 0.000000
# 2022-04-18 	Buy and hold balance:	 86599.39 	Strategy balance:	 86599.39 	Delta:	 0.000000
# 2022-04-19 	Buy and hold balance:	 88286.86 	Strategy balance:	 88286.86 	Delta:	 0.000000
# 2022-04-20 	Buy and hold balance:	 86526.36 	Strategy balance:	 86526.36 	Delta:	 0.000000
# 2022-04-21 	Buy and hold balance:	 86134.95 	Strategy balance:	 86134.95 	Delta:	 0.000000
# 2022-04-22 	Buy and hold balance:	 84524.29 	Strategy balance:	 84524.29 	Delta:	 0.000000
# 2022-04-25 	Buy and hold balance:	 85295.03 	Strategy balance:	 85295.03 	Delta:	 0.000000
# 2022-04-26 	Buy and hold balance:	 79598.59 	Strategy balance:	 79598.59 	Delta:	 0.000000
# 2022-04-27 	Buy and hold balance:	 80527.31 	Strategy balance:	 80527.31 	Delta:	 0.000000
# 2022-04-28 	Buy and hold balance:	 82696.80 	Strategy balance:	 82696.80 	Delta:	 0.000000
# 2022-04-29 	Buy and hold balance:	 80058.02 	Strategy balance:	 80058.02 	Delta:	 0.000000
# 2022-05-02 	Buy and hold balance:	 82112.69 	Strategy balance:	 82112.69 	Delta:	 0.000000
# 2022-05-03 	Buy and hold balance:	 82419.36 	Strategy balance:	 82419.36 	Delta:	 0.000000
# 2022-05-04 	Buy and hold balance:	 85976.57 	Strategy balance:	 85976.57 	Delta:	 0.000000
# 2022-05-05 	Buy and hold balance:	 80682.12 	Strategy balance:	 80682.12 	Delta:	 0.000000
# 2022-05-06 	Buy and hold balance:	 80407.94 	Strategy balance:	 80407.94 	Delta:	 0.000000
# 2022-05-09 	Buy and hold balance:	 75580.80 	Strategy balance:	 75580.80 	Delta:	 0.000000
# 2022-05-10 	Buy and hold balance:	 77026.28 	Strategy balance:	 77026.28 	Delta:	 0.000000
# 2022-05-11 	Buy and hold balance:	 73052.33 	Strategy balance:	 73052.33 	Delta:	 0.000000
# 2022-05-12 	Buy and hold balance:	 71726.71 	Strategy balance:	 71726.71 	Delta:	 0.000000
# 2022-05-13 	Buy and hold balance:	 75006.61 	Strategy balance:	 75006.61 	Delta:	 0.000000
# 2022-05-16 	Buy and hold balance:	 73381.34 	Strategy balance:	 73381.34 	Delta:	 0.000000
# 2022-05-17 	Buy and hold balance:	 76201.72 	Strategy balance:	 76201.72 	Delta:	 0.000000
# 2022-05-18 	Buy and hold balance:	 71797.30 	Strategy balance:	 71797.30 	Delta:	 0.000000
# 2022-05-19 	Buy and hold balance:	 71301.66 	Strategy balance:	 71301.66 	Delta:	 0.000000
# 2022-05-20 	Buy and hold balance:	 69698.66 	Strategy balance:	 69698.66 	Delta:	 0.000000
# 2022-05-23 	Buy and hold balance:	 71573.04 	Strategy balance:	 71573.04 	Delta:	 0.000000
# 2022-05-24 	Buy and hold balance:	 69316.49 	Strategy balance:	 69316.49 	Delta:	 0.000000
# 2022-05-25 	Buy and hold balance:	 70751.57 	Strategy balance:	 70751.57 	Delta:	 0.000000
# 2022-05-26 	Buy and hold balance:	 73515.02 	Strategy balance:	 73515.02 	Delta:	 0.000000
# 2022-05-27 	Buy and hold balance:	 76869.10 	Strategy balance:	 76869.10 	Delta:	 0.000000
# 2022-05-31 	Buy and hold balance:	 76541.45 	Strategy balance:	 76541.45 	Delta:	 0.000000
# 2022-06-01 	Buy and hold balance:	 75921.55 	Strategy balance:	 75921.55 	Delta:	 0.000000
# 2022-06-02 	Buy and hold balance:	 78316.58 	Strategy balance:	 78316.58 	Delta:	 0.000000
# 2022-06-03 	Buy and hold balance:	 74760.72 	Strategy balance:	 74760.72 	Delta:	 0.000000
# 2022-06-06 	Buy and hold balance:	 75056.09 	Strategy balance:	 75056.09 	Delta:	 0.000000
# 2022-06-07 	Buy and hold balance:	 75773.54 	Strategy balance:	 75773.54 	Delta:	 0.000000
# 2022-06-08 	Buy and hold balance:	 75419.19 	Strategy balance:	 75419.19 	Delta:	 0.000000
# 2022-06-09 	Buy and hold balance:	 73641.75 	Strategy balance:	 73641.75 	Delta:	 0.000000
# 2022-06-10 	Buy and hold balance:	 70733.75 	Strategy balance:	 70733.75 	Delta:	 0.000000
# 2022-06-13 	Buy and hold balance:	 66854.12 	Strategy balance:	 66854.12 	Delta:	 0.000000
# 2022-06-14 	Buy and hold balance:	 67624.64 	Strategy balance:	 67624.64 	Delta:	 0.000000
# 2022-06-15 	Buy and hold balance:	 69918.12 	Strategy balance:	 69918.12 	Delta:	 0.000000
# 2022-06-16 	Buy and hold balance:	 66206.79 	Strategy balance:	 66206.79 	Delta:	 0.000000
# 2022-06-17 	Buy and hold balance:	 66973.79 	Strategy balance:	 66973.79 	Delta:	 0.000000
# 2022-06-21 	Buy and hold balance:	 70071.17 	Strategy balance:	 70071.17 	Delta:	 0.000000
# 2022-06-22 	Buy and hold balance:	 69804.88 	Strategy balance:	 69804.88 	Delta:	 0.000000
# 2022-06-23 	Buy and hold balance:	 70431.71 	Strategy balance:	 70431.71 	Delta:	 0.000000
# 2022-06-24 	Buy and hold balance:	 73062.11 	Strategy balance:	 73062.11 	Delta:	 0.000000
# 2022-06-27 	Buy and hold balance:	 72641.97 	Strategy balance:	 72641.97 	Delta:	 0.000000
# 2022-06-28 	Buy and hold balance:	 69743.74 	Strategy balance:	 69743.74 	Delta:	 0.000000
# 2022-06-29 	Buy and hold balance:	 69603.29 	Strategy balance:	 69603.29 	Delta:	 0.000000
# 2022-06-30 	Buy and hold balance:	 68428.17 	Strategy balance:	 68428.17 	Delta:	 0.000000
# 2022-07-01 	Buy and hold balance:	 68772.99 	Strategy balance:	 68772.99 	Delta:	 0.000000
# 2022-07-05 	Buy and hold balance:	 70117.67 	Strategy balance:	 70117.67 	Delta:	 0.000000
# 2022-07-06 	Buy and hold balance:	 70519.43 	Strategy balance:	 70519.43 	Delta:	 0.000000
# 2022-07-07 	Buy and hold balance:	 72733.81 	Strategy balance:	 72733.81 	Delta:	 0.000000
# 2022-07-08 	Buy and hold balance:	 73280.12 	Strategy balance:	 73280.12 	Delta:	 0.000000
# 2022-07-11 	Buy and hold balance:	 71010.03 	Strategy balance:	 71010.03 	Delta:	 0.000000
# 2022-07-12 	Buy and hold balance:	 70183.40 	Strategy balance:	 70183.40 	Delta:	 0.000000
# 2022-07-13 	Buy and hold balance:	 70490.78 	Strategy balance:	 70490.78 	Delta:	 0.000000
# 2022-07-14 	Buy and hold balance:	 71270.98 	Strategy balance:	 71270.98 	Delta:	 0.000000
# 2022-07-15 	Buy and hold balance:	 72160.38 	Strategy balance:	 72160.38 	Delta:	 0.000000
# 2022-07-18 	Buy and hold balance:	 71698.50 	Strategy balance:	 71698.50 	Delta:	 0.000000
# 2022-07-19 	Buy and hold balance:	 73668.24 	Strategy balance:	 73668.24 	Delta:	 0.000000
# 2022-07-20 	Buy and hold balance:	 74842.77 	Strategy balance:	 74842.77 	Delta:	 0.000000
# 2022-07-21 	Buy and hold balance:	 77525.92 	Strategy balance:	 77525.92 	Delta:	 0.000000
# 2022-07-22 	Buy and hold balance:	 76605.97 	Strategy balance:	 76605.97 	Delta:	 0.000000
# 2022-07-25 	Buy and hold balance:	 75884.12 	Strategy balance:	 75884.12 	Delta:	 0.000000
# 2022-07-26 	Buy and hold balance:	 74078.11 	Strategy balance:	 74078.11 	Delta:	 0.000000
# 2022-07-27 	Buy and hold balance:	 78100.86 	Strategy balance:	 78100.86 	Delta:	 0.000000
# 2022-07-28 	Buy and hold balance:	 79437.40 	Strategy balance:	 79437.40 	Delta:	 0.000000
# 2022-07-29 	Buy and hold balance:	 82081.15 	Strategy balance:	 82081.15 	Delta:	 0.000000
# 2022-08-01 	Buy and hold balance:	 81999.67 	Strategy balance:	 81999.67 	Delta:	 0.000000
# 2022-08-02 	Buy and hold balance:	 82022.14 	Strategy balance:	 82022.14 	Delta:	 0.000000
# 2022-08-03 	Buy and hold balance:	 84058.29 	Strategy balance:	 84058.29 	Delta:	 0.000000
# 2022-08-04 	Buy and hold balance:	 84721.46 	Strategy balance:	 84721.46 	Delta:	 0.000000
# 2022-08-05 	Buy and hold balance:	 82754.95 	Strategy balance:	 82754.95 	Delta:	 0.000000
# 2022-08-08 	Buy and hold balance:	 82132.21 	Strategy balance:	 82132.21 	Delta:	 0.000000
# 2022-08-09 	Buy and hold balance:	 81159.29 	Strategy balance:	 81159.29 	Delta:	 0.000000
# 2022-08-10 	Buy and hold balance:	 83762.46 	Strategy balance:	 83762.46 	Delta:	 0.000000
# 2022-08-11 	Buy and hold balance:	 82752.93 	Strategy balance:	 82752.93 	Delta:	 0.000000
# 2022-08-12 	Buy and hold balance:	 85164.20 	Strategy balance:	 85164.20 	Delta:	 0.000000
# 2022-08-15 	Buy and hold balance:	 86306.50 	Strategy balance:	 86306.50 	Delta:	 0.000000
# 2022-08-16 	Buy and hold balance:	 85896.49 	Strategy balance:	 85896.49 	Delta:	 0.000000
# 2022-08-17 	Buy and hold balance:	 85493.09 	Strategy balance:	 85493.09 	Delta:	 0.000000
# 2022-08-18 	Buy and hold balance:	 85555.13 	Strategy balance:	 85555.13 	Delta:	 0.000000
# 2022-08-19 	Buy and hold balance:	 83754.87 	Strategy balance:	 83754.87 	Delta:	 0.000000
# 2022-08-22 	Buy and hold balance:	 81528.78 	Strategy balance:	 81528.78 	Delta:	 0.000000
# 2022-08-23 	Buy and hold balance:	 81934.12 	Strategy balance:	 81934.12 	Delta:	 0.000000
# 2022-08-24 	Buy and hold balance:	 82012.03 	Strategy balance:	 82012.03 	Delta:	 0.000000
# 2022-08-25 	Buy and hold balance:	 83059.33 	Strategy balance:	 83059.33 	Delta:	 0.000000
# 2022-08-26 	Buy and hold balance:	 79726.30 	Strategy balance:	 79726.30 	Delta:	 0.000000
# 2022-08-29 	Buy and hold balance:	 78584.43 	Strategy balance:	 78584.43 	Delta:	 0.000000
# 2022-08-30 	Buy and hold balance:	 77264.16 	Strategy balance:	 77264.16 	Delta:	 0.000000
# 2022-08-31 	Buy and hold balance:	 76470.10 	Strategy balance:	 76470.10 	Delta:	 0.000000
# 2022-09-01 	Buy and hold balance:	 76070.65 	Strategy balance:	 76070.65 	Delta:	 0.000000
# 2022-09-02 	Buy and hold balance:	 74631.51 	Strategy balance:	 74631.51 	Delta:	 0.000000
# 2022-09-06 	Buy and hold balance:	 74411.30 	Strategy balance:	 74411.30 	Delta:	 0.000000
# 2022-09-07 	Buy and hold balance:	 75872.25 	Strategy balance:	 75872.25 	Delta:	 0.000000
# 2022-09-08 	Buy and hold balance:	 76453.49 	Strategy balance:	 76453.49 	Delta:	 0.000000
# 2022-09-09 	Buy and hold balance:	 78478.30 	Strategy balance:	 78478.30 	Delta:	 0.000000
# 2022-09-12 	Buy and hold balance:	 79882.44 	Strategy balance:	 79882.44 	Delta:	 0.000000
# 2022-09-13 	Buy and hold balance:	 75423.96 	Strategy balance:	 75423.96 	Delta:	 0.000000
# 2022-09-14 	Buy and hold balance:	 76532.29 	Strategy balance:	 76532.29 	Delta:	 0.000000
# 2022-09-15 	Buy and hold balance:	 75571.61 	Strategy balance:	 75571.61 	Delta:	 0.000000
# 2022-09-16 	Buy and hold balance:	 75324.98 	Strategy balance:	 75324.98 	Delta:	 0.000000
# 2022-09-19 	Buy and hold balance:	 76397.72 	Strategy balance:	 76397.72 	Delta:	 0.000000
# 2022-09-20 	Buy and hold balance:	 76392.54 	Strategy balance:	 76392.54 	Delta:	 0.000000
# 2022-09-21 	Buy and hold balance:	 75001.87 	Strategy balance:	 75001.87 	Delta:	 0.000000
# 2022-09-22 	Buy and hold balance:	 73438.42 	Strategy balance:	 73438.42 	Delta:	 0.000000
# 2022-09-23 	Buy and hold balance:	 71677.69 	Strategy balance:	 71677.69 	Delta:	 0.000000
# 2022-09-26 	Buy and hold balance:	 71535.61 	Strategy balance:	 71535.61 	Delta:	 0.000000
# 2022-09-27 	Buy and hold balance:	 72285.37 	Strategy balance:	 72285.37 	Delta:	 0.000000
# 2022-09-28 	Buy and hold balance:	 72935.32 	Strategy balance:	 72935.32 	Delta:	 0.000000
# 2022-09-29 	Buy and hold balance:	 69547.38 	Strategy balance:	 69547.38 	Delta:	 0.000000
# 2022-09-30 	Buy and hold balance:	 68264.54 	Strategy balance:	 68264.54 	Delta:	 0.000000
# 2022-10-03 	Buy and hold balance:	 67927.46 	Strategy balance:	 67927.46 	Delta:	 0.000000
# 2022-10-04 	Buy and hold balance:	 69967.79 	Strategy balance:	 69967.79 	Delta:	 0.000000
# 2022-10-05 	Buy and hold balance:	 69352.26 	Strategy balance:	 69352.26 	Delta:	 0.000000
# 2022-10-06 	Buy and hold balance:	 68784.43 	Strategy balance:	 68784.43 	Delta:	 0.000000
# 2022-10-07 	Buy and hold balance:	 64846.77 	Strategy balance:	 64846.77 	Delta:	 0.000000
# 2022-10-10 	Buy and hold balance:	 64341.17 	Strategy balance:	 64341.17 	Delta:	 0.000000
# 2022-10-11 	Buy and hold balance:	 63285.11 	Strategy balance:	 63285.11 	Delta:	 0.000000
# 2022-10-12 	Buy and hold balance:	 63265.73 	Strategy balance:	 63265.73 	Delta:	 0.000000
# 2022-10-13 	Buy and hold balance:	 65156.80 	Strategy balance:	 65156.80 	Delta:	 0.000000
# 2022-10-14 	Buy and hold balance:	 62262.34 	Strategy balance:	 62262.34 	Delta:	 0.000000
# 2022-10-17 	Buy and hold balance:	 65030.59 	Strategy balance:	 65030.59 	Delta:	 0.000000
# 2022-10-18 	Buy and hold balance:	 65387.11 	Strategy balance:	 65387.11 	Delta:	 0.000000
# 2022-10-19 	Buy and hold balance:	 65380.63 	Strategy balance:	 65380.63 	Delta:	 0.000000
# 2022-10-20 	Buy and hold balance:	 64177.14 	Strategy balance:	 64177.14 	Delta:	 0.000000
# 2022-10-21 	Buy and hold balance:	 65924.12 	Strategy balance:	 65924.12 	Delta:	 0.000000
# 2022-10-24 	Buy and hold balance:	 66395.37 	Strategy balance:	 66395.37 	Delta:	 0.000000
# 2022-10-25 	Buy and hold balance:	 68382.81 	Strategy balance:	 68382.81 	Delta:	 0.000000
# 2022-10-26 	Buy and hold balance:	 66455.84 	Strategy balance:	 66455.84 	Delta:	 0.000000
# 2022-10-27 	Buy and hold balance:	 65502.60 	Strategy balance:	 65502.60 	Delta:	 0.000000
# 2022-10-28 	Buy and hold balance:	 68497.69 	Strategy balance:	 68497.69 	Delta:	 0.000000
# 2022-10-31 	Buy and hold balance:	 67545.31 	Strategy balance:	 67545.31 	Delta:	 0.000000
# 2022-11-01 	Buy and hold balance:	 66870.82 	Strategy balance:	 66870.82 	Delta:	 0.000000
# 2022-11-02 	Buy and hold balance:	 64240.86 	Strategy balance:	 64240.86 	Delta:	 0.000000
# 2022-11-03 	Buy and hold balance:	 63114.14 	Strategy balance:	 63114.14 	Delta:	 0.000000
# 2022-11-04 	Buy and hold balance:	 63319.92 	Strategy balance:	 63319.92 	Delta:	 0.000000
# 2022-11-07 	Buy and hold balance:	 63146.63 	Strategy balance:	 63072.78 	Delta:	 -0.001170
# 2022-11-08 	Buy and hold balance:	 62988.31 	Strategy balance:	 62784.59 	Delta:	 -0.003234
# 2022-11-09 	Buy and hold balance:	 60336.53 	Strategy balance:	 60162.89 	Delta:	 -0.002878
# 2022-11-10 	Buy and hold balance:	 65754.12 	Strategy balance:	 65588.69 	Delta:	 -0.002516
# 2022-11-11 	Buy and hold balance:	 67360.78 	Strategy balance:	 67264.47 	Delta:	 -0.001430
# 2022-11-14 	Buy and hold balance:	 66410.10 	Strategy balance:	 66183.73 	Delta:	 -0.003409
# 2022-11-15 	Buy and hold balance:	 67300.65 	Strategy balance:	 66983.01 	Delta:	 -0.004720
# 2022-11-16 	Buy and hold balance:	 65987.98 	Strategy balance:	 65801.24 	Delta:	 -0.002830
# 2022-11-17 	Buy and hold balance:	 65972.22 	Strategy balance:	 65721.57 	Delta:	 -0.003799
# 2022-11-18 	Buy and hold balance:	 65669.93 	Strategy balance:	 65461.73 	Delta:	 -0.003170
# 2022-11-21 	Buy and hold balance:	 64148.47 	Strategy balance:	 63867.23 	Delta:	 -0.004384
# 2022-11-22 	Buy and hold balance:	 65280.48 	Strategy balance:	 64813.66 	Delta:	 -0.007151
# 2022-11-23 	Buy and hold balance:	 66911.44 	Strategy balance:	 66347.43 	Delta:	 -0.008429
# 2022-11-25 	Buy and hold balance:	 66277.64 	Strategy balance:	 65749.39 	Delta:	 -0.007970
# 2022-11-28 	Buy and hold balance:	 65012.27 	Strategy balance:	 64658.72 	Delta:	 -0.005438
# 2022-11-29 	Buy and hold balance:	 64249.15 	Strategy balance:	 63862.43 	Delta:	 -0.006019
# 2022-11-30 	Buy and hold balance:	 68179.42 	Strategy balance:	 67633.14 	Delta:	 -0.008012
# 2022-12-01 	Buy and hold balance:	 68243.76 	Strategy balance:	 67566.20 	Delta:	 -0.009929
# 2022-12-02 	Buy and hold balance:	 67945.76 	Strategy balance:	 67267.51 	Delta:	 -0.009982
# 2022-12-05 	Buy and hold balance:	 66229.73 	Strategy balance:	 65446.28 	Delta:	 -0.011829
# 2022-12-06 	Buy and hold balance:	 64660.82 	Strategy balance:	 63908.37 	Delta:	 -0.011637
# 2022-12-07 	Buy and hold balance:	 63884.69 	Strategy balance:	 63102.49 	Delta:	 -0.012244
# 2022-12-08 	Buy and hold balance:	 64667.70 	Strategy balance:	 63665.11 	Delta:	 -0.015504
# 2022-12-09 	Buy and hold balance:	 64715.42 	Strategy balance:	 63689.73 	Delta:	 -0.015849
# 2022-12-12 	Buy and hold balance:	 64988.94 	Strategy balance:	 63881.43 	Delta:	 -0.017042
# 2022-12-13 	Buy and hold balance:	 65143.31 	Strategy balance:	 63982.30 	Delta:	 -0.017822
# 2022-12-14 	Buy and hold balance:	 64178.46 	Strategy balance:	 63089.30 	Delta:	 -0.016971
# 2022-12-15 	Buy and hold balance:	 62264.60 	Strategy balance:	 61215.55 	Delta:	 -0.016848
# 2022-12-16 	Buy and hold balance:	 60851.17 	Strategy balance:	 59888.05 	Delta:	 -0.015827
# 2022-12-19 	Buy and hold balance:	 60037.47 	Strategy balance:	 58996.45 	Delta:	 -0.017340
# 2022-12-20 	Buy and hold balance:	 59128.59 	Strategy balance:	 58158.12 	Delta:	 -0.016413
# 2022-12-21 	Buy and hold balance:	 60083.81 	Strategy balance:	 59076.60 	Delta:	 -0.016763
# 2022-12-22 	Buy and hold balance:	 57518.45 	Strategy balance:	 56701.30 	Delta:	 -0.014207
# 2022-12-23 	Buy and hold balance:	 57331.52 	Strategy balance:	 56645.99 	Delta:	 -0.011957
# 2022-12-27 	Buy and hold balance:	 55359.94 	Strategy balance:	 54886.80 	Delta:	 -0.008547
# 2022-12-28 	Buy and hold balance:	 54816.38 	Strategy balance:	 54296.02 	Delta:	 -0.009493
# 2022-12-29 	Buy and hold balance:	 56894.90 	Strategy balance:	 56337.06 	Delta:	 -0.009805
# 2022-12-30 	Buy and hold balance:	 56963.32 	Strategy balance:	 56390.98 	Delta:	 -0.010048
#
# high_buy_and_hold 105072.29780578613
# low_buy_and_hold 54816.378479003906
#
# high_strategy 105072.29780578613
# low_strategy 54296.018157958984
#
# biggest_delta -0.017822405088974206
# biggest_delta_day 2022-12-13 00:00:00
#
# final_delta_usd -572.3402633666992
# final_delta_percent -0.010047523316877987
